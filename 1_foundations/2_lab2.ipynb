# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key not set (and this is optional)
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# Imagine you are advising the government of a low-lying island nation of 350,000 people that faces an expected 1.5–2.0 m sea-level rise within 80 years; the government has an immediate one-time budget of $3 billion and can commit up to $150 million per year thereafter. Propose a detailed, prioritized 50-year climate adaptation and development plan that balances coastal protection, managed retreat, housing, livelihoods, cultural preservation, ecosystem services, and intergenerational equity — and for that plan: (1) clearly state and justify your assumptions and the main uncertainties; (2) explain the key trade-offs and opportunity costs behind your priorities; (3) provide quantitative projections (with ranges) for population displacement, GDP change, ecosystem loss, and cumulative costs under three scenarios (high-, medium-, and low-emissions) and describe how those projections were derived; (4) specify monitoring metrics, decision triggers, and an adaptive-update schedule for when and how to change course; (5) identify potential moral, social, and cultural harms (including distributional harms) and propose concrete mitigation, compensation, and governance mechanisms to address them; (6) describe how you would stress-test and simulate the robustness of the plan (what models or counterfactuals you would run and why); and (7) provide a confidence level for each major element and list the specific additional data that would most reduce critical uncertainties — do this for three alternative strategies (A: prioritize protection and in-place adaptation; B: prioritize large-scale, planned relocation; C: a hybrid approach), then recommend one strategy, explaining in detail why it is superior to the other two under realistic political, economic, and ethical constraints?

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Below is a structured, policy-relevant planning package you can adapt for a small, low-lying island nation with about 350,000 people. It is organized in three alternative strategies (A, B, C) plus a final recommendation. It is intentionally stated with explicit assumptions, uncertainties, trade-offs, and quantitative projections to aid decision-making under financial constraints (one-time $3B upfront; up to $150M/year thereafter) and long-term climate risk.
#
# Executive context and core assumptions (common to all three strategies)
# - Physical and demographic context
#   - Population: ~350,000 people; urbanization concentrated in a few coastal towns and the main port/airstrip area; a substantial share lives in hazard-prone coastal/low-lying zones.
#   - Land area and topography: predominantly low-lying, with limited high-ground refuges; subsurface freshwater lens vulnerable to saltwater intrusion; mangrove and reef ecosystems present in many coastal zones.
#   - Economy today (illustrative): real GDP around $3.0–3.5B/year; GDP per capita roughly $8,000–12,000; key sectors include fisheries, tourism (eco- and small-scale), agro-exports, services, and ports/logistics.
# - Climate and risk context
#   - Sea-level rise: plausible range of 1.5–2.0 m SLR by about 80 years (roughly 2080–2100), with continued but slower rise beyond; storm intensity and duration are expected to increase; coastal erosion and freshwater intrusion will intensify.
#   - Emissions scenarios used here (three clearly distinct futures):
#     - High-emissions (HE): akin to RCP8.5/SSP5 – higher atmospheric CO2, faster SLR and more frequent/intense extreme events.
#     - Medium-emissions (ME): akin to RCP4.5/SSP2 – moderate SLR and climate impacts.
#     - Low-emissions (LE): akin to RCP2.6/SSP1 – slower SLR and fewer climate shocks.
# - Economic planning constraints
#   - One-time budget: $3 billion upfront.
#   - Ongoing public budget: up to $150 million/year (undiscouraged annual cap; assumes debt capacity and macro stability permit roughly this magnitude).
#   - External finance and private finance would be necessary to fully realize more ambitious components; the plan focuses on what is feasible with the stated fiscal envelope and a prudent level of leverage.
# - Core planning principles
#   - Balance protection, managed retreat, housing, livelihoods, cultural preservation, ecosystem services, and intergenerational equity.
#   - Emphasize local governance, participatory planning, fairness, transparency, and respect for land rights and cultural heritage.
#   - Monitoring, adaptive management, and explicit decision triggers to adjust course as conditions evolve.
#
# Strategy A: Prioritize protection and in-place adaptation (coastal protection first, with limited managed retreat)
#
# 1) What Strategy A entails (vision and components)
# - Core thrust: Build and maintain coastal defenses and nature-based buffers to protect most critical assets and housing in major urban centers for as long as feasible; combine hard infrastructure with ecosystem-based protection (mangrove restoration, coral reef augmentation, dune and wetland rehabilitation).
# - Immediate top priorities (first 5–10 years)
#   - Protect the most exposed population hubs (capital/port, hospital clusters, water security).
#   - Construct seawalls and tide barriers where cost-effective; shore up flood defenses in key basins; reinforce critical road/bridge networks.
#   - Restore and conserve coastal ecosystems (mangroves, tidal wetlands, coral fragments, reef crest restoration) to improve natural attenuation of wave energy and storm surge.
#   - Improve freshwater security (desalination capacity, groundwater management, rainwater harvesting) to mitigate saltwater intrusion in protected zones.
#   - Strengthen land-use planning to minimize new construction in high-risk zones; implement strict building codes for resilience.
# - Medium term (10–30 years)
#   - Expand nature-based buffers (mangroves and reefs) to further reduce wave energy and storm impact.
#   - Upgrade protection around critical infrastructure (airport/port facilities, power generation, water facilities).
#   - Pilot buyouts/compensation for the most at-risk, non-densely populated zones where protection is no longer feasible within cost constraints.
# - Longer term (30–50 years)
#   - Maintain or upgrade protection where possible; if risk exposure remains high and protection costs escalate, intensify managed retreat in the most exposed areas in a fair, orderly, community-led manner.
#   - Ensure housing and livelihoods continue with access to basic services, while shifting some development inland or to higher ground where feasible.
#
# 2) Assumptions and uncertainties specific to Strategy A
# - Assumptions
#   - A robust system of coastal protection can extend life of urbanized coastline for several decades at a moderate to high cost, especially with Nature-Based Solutions (NBS) leveraged alongside engineered barriers.
#   - A subset of high-risk areas (incentivized by value at risk) can be protected with a combination of hard infrastructure and NBS without full-scale relocation.
#   - Ecosystem services (coastal protection, fisheries productivity, tourism appeal) will continue to be valuable and partly enhanced by restoration.
# - Key uncertainties
#   - The effectiveness and maintenance costs of seaward/landward protections under extreme events and higher-than-expected SLR.
#   - The precise pace of SLR and rates of erosion in different micro-regions; freshwater lens dynamics under protection and intrusion effects.
#   - Costs and reliability of large-scale ecosystem restoration; success rates of mangrove/reef interventions given climate stressors.
#   - Long-run fiscal sustainability given ongoing maintenance, debt service, and potential macroeconomic shocks.
#   - Social acceptability and equity of continuing in-place protection at the expense of some areas with limited protection options.
#
# 3) Projections (three climate/emissions futures) for Strategy A (displacement, GDP, ecosystem loss, cumulative costs)
# - Assumptions for projections
#   - Baseline GDP today: ~$3.5B; population 350k; baseline growth assumption 1.5–2.5% real per year absent climate stress or policy constraints.
#   - "50-year" horizon (to 2070–2075) with discounting for present-value comparisons.
#   - Displacement means permanent relocation where protection fails or where protection costs exceed benefits; temporary displacement and out-migration are captured as transient effects, not permanent relocation unless specified.
# - HE (High-emissions) projections (Strategy A)
#   - Population displacement by year 50: 18–28% (63k–98k people permanently displaced from the most exposed zones), with most relocations concentrated near the urban cores facing ongoing erosion and inundation pressure.
#   - GDP change over 50 years: -20% to -12% relative to baseline (cumulative real GDP loss, accounting for protection expenditures, maintenance, and reduced growth in exposed zones).
#   - Ecosystem loss: 25–55% of high-value coastal ecosystems (mangroves, coral, estuarine habitats) in exposed shorelines degraded or lost; some recovery possible in less-impacted zones.
#   - Cumulative adaptation costs (governmental, domestic): $13–18B (net present value, including upfront and ongoing protection maintenance); additional non-protection capital expenditures (housing in protected zones, water security) add further but are partially funded by budget allocations.
# - ME (Medium-emissions) projections
#   - Displacement: 6–12%.
#   - GDP change: -8% to -4%.
#   - Ecosystem loss: 12–28%.
#   - Cumulative costs: $9–13B.
# - LE (Low-emissions) projections
#   - Displacement: 1–4%.
#   - GDP change: -2% to +2% (near-stable growth with protection benefits).
#   - Ecosystem loss: 3–15%.
#   - Cumulative costs: $6–9B.
# - How these projections are derived (brief rationale)
#   - Displacement: derived from exposure of dense population to remaining risk after protection; factor in limits of protection life-cycle costs; assume an orderly, finite area remains protected; higher SLR and storms increase residual risk.
#   - GDP: combine baseline growth trajectory with climate damages to ports, tourism, fisheries; subtract protection costs and residual loss of output in exposed zones; assume some spillovers to national economy; project with simple scenario-adjusted multipliers.
#   - Ecosystems: use typical loss curves for mangroves/reefs under SLR and storm exposure; protection and restoration offset some loss but not all under HE; lower loss in LE due to slower SLR and fewer extreme events.
#   - Costs: sum of upfront protection investments, ongoing maintenance, ecological restoration, land-use planning, and limited relocation payments in zones where protection is deemed infeasible.
# - Observations
#   - Strategy A offers the lowest displacement relative to the other two strategies in HE among the three, but still involves non-trivial displacement and substantial cumulative costs.
#   - This strategy prioritizes staying in place for as many people as possible but relies heavily on expensive, ongoing maintenance and robust ecosystem performance.
#
# 4) Monitoring, decision triggers, and adaptive update schedule (Strategy A)
# - Monitoring metrics (annual/quarterly cadence)
#   - Physical: shoreline retreat rates; SLR measurements; coastal erosion rates; groundwater salinity; reef/mangrove health indices; protection structure integrity; rainfall and flood depth.
#   - Social/economic: population distribution in hazard zones; housing occupancy in protected zones; displacement approvals; infrastructure uptime; GDP contributions from protected vs. unprotected zones; employment in fisheries/tisheries-dependent sectors.
#   - Governance/finance: protection maintenance costs; debt service coverage; funding gaps; service delivery in impacted communities.
# - Decision triggers (predefined thresholds)
#   - If protected zone erosion rate exceeds X meters/year for two consecutive years, escalate protection retrofit program, reassess cost-benefit, or switch to relocation for subzones.
#   - If cumulative displacement approaches 20% of population or housing stock in risk zones with no feasible protection alternatives, trigger a staged managed retreat pilot for targeted subzones.
#   - If maintenance costs exceed scheduled budget by more than Y% for two consecutive years, reassess mix of hard vs. nature-based protection and adjust project scope or funding sources.
#   - If ecosystem services (coastal protection, fisheries yield, tourism potential) decline beyond a threshold, accelerate restoration investments and adjust land-use policies.
# - Adaptive-update schedule
#   - Annual review for performance against targets; mid-term formal re-forecast at year 10; comprehensive plan reset at year 20 and year 40 with updated SLR data, new cost estimates, and updated social equity assessments.
#   - Implement a formal “adaptive management” board including local communities, civil society, coastal engineers, and economic planners to decide on pivots (e.g., scaling back or accelerating relocation components).
#
# 5) Potential harms, mitigation, compensation, and governance (Strategy A)
# - Potential harms and distributional risks
#   - Social inequities: wealthier urban residents may benefit from protection while poorer households in peripheral zones face higher risk or forced relocation; risk of unequal access to protected areas.
#   - Cultural harms: erosion of place-based identity in protected zones if communities are displaced; potential loss of cultural heritage linked to protected coasts.
#   - Procedural harms: perceived top-down decision-making; limited local voice in long-term protection siting.
# - Mitigation and governance mechanisms
#   - Community-led siting and planning: incorporate local knowledge in where to place protective works; ensure informed consent for protection vs. retreat in different zones.
#   - Fair compensation and social safety nets: transparent buyouts or relocation assistance; long-term housing assistance in new locations; employment retraining and wage support for workers transitioning from affected sectors (fisheries, tourism).
#   - Cultural preservation measures: designate cultural heritage zones; fund preservation of sites and artifacts; support diaspora engagement and return programs; document oral histories and place-based narratives before relocation.
#   - Governance safeguards: anti-corruption measures, participatory budgeting for risk reduction funds, third-party audits, transparent procurement for protection works.
#   - Equity mechanisms: ensure priority access to subsidized housing and employment for vulnerable communities; create a floor of participation in planning for marginalized groups, including women, elderly, and indigenous/community landowners.
# - Governance architecture
#   - A dedicated Coastal Resilience Authority or inter-ministerial committee with community representation; a protected budget line for adaptation and relocation programs; an independent ombudsperson for grievance redress.
#
# 6) Stress-testing and robustness (Strategy A)
# - Models, counterfactuals, and tests to run
#   - Climate-impacts models: simulate SLR, storm surge, and erosion under HE/ME/LE scenarios; calibrate with local tide gauge data and bathymetry; couple with groundwater intrusion models.
#   - Economic impact models: macroeconomic projections with climate-adjusted productivity multipliers; test sensitivity to tourism shocks, fisheries productivity, and port disruptions.
#   - Population displacement models: agent-based or microsimulation models to estimate migration patterns under protection decisions; factor in housing supply constraints and costs.
#   - Ecosystem and service models: coastal protection capacity from mangroves/reefs; determine thresholds beyond which protection is no longer cost-effective.
#   - Financial stress tests: evaluate debt service burden under various external financing scenarios; assess fiscal resilience under shocks to tourism or fisheries.
# - Counterfactuals to consider
#   - No adaptation: baseline trajectory without new protection; examine rapid losses in urban cores and high displacement.
#   - Aggressive protection investment: evaluate if cost escalations threaten fiscal sustainability; test different maintenance funding mixes.
#   - Rapid relocation: examine social disruption costs, housing market dynamics, and governance challenges if relocation is accelerated beyond plan.
# - Why these models matter
#   - They reveal tipping points, help avoid overspending on protection where it is not cost-effective, and ensure equity by exposing who bears costs and who gains benefits.
#
# 7) Confidence levels and data gaps (Strategy A)
# - Confidence levels (qualitative)
#   - Assumptions about SLR ranges and storm intensities: Medium–High (data-informed but uncertain at local scale).
#   - Protection performance and maintenance costs: Medium (depends on engineering choices, local climate adaptiveness, and governance).
#   - Social equity and compensation effectiveness: Medium–Low (depends on governance quality and community engagement).
# - Data needs to reduce critical uncertainties (highest priority)
#   - High-resolution topography and bathymetry for risk zoning; detailed land ownership and housing stock data; current and projected coastal ecosystem health and linkages to protection effectiveness.
#   - Localized costs and maintenance requirements for specific protection structures (material lifespans, replacement cycles, labor costs).
#   - Detailed microeconomics of fisheries, tourism, and agriculture to quantify sectoral vulnerabilities and adaptation benefits.
#   - Socio-cultural baselines: community mapping of cultural heritage sites, language, and place-based identities; mechanisms for inclusive decision-making.
# - Confidence summary
#   - Overall plan confidence: Medium. The direction is plausible, but precise costs, displacement magnitudes, and ecosystem outcomes depend on local technology choices, governance, financing, and ecological responses.
#
# Strategy B: Prioritize large-scale, planned relocation (all at-risk communities move to higher ground or inland settlements with new housing and infrastructure)
#
# 1) What Strategy B entails (vision and components)
# - Core thrust: Proactively relocate a substantial portion of the population from the most exposed coastal zones to well-planned inland or higher-ground settlements designed for resilience and social cohesion; build new housing, jobs, health and education facilities, and community services in strategically chosen inland zones.
# - Immediate top priorities (first 5–10 years)
#   - Identify inland settlement corridors and acquire land for housing and public facilities with clear tenure policies; establish a phased relocation plan to minimize disruption.
#   - Build new housing stock and necessary infrastructure (schools, clinics, water, electricity) to absorb relocated populations.
#   - Create economic zones and livelihoods in inland areas (processing facilities for fisheries products, agro-processing, tourism circuits, remote work hubs).
#   - Establish social protection and retraining programs for those leaving coastal livelihoods; preserve cultural sites and practices in a way that can adapt to inland settings.
# - Medium term (10–30 years)
#   - Expand inland urban cores, ensure adequate housing, and integrate essential services; ensure relocation is voluntary, culturally sensitive, and equitable.
#   - Develop new livelihoods tied to inland resilience (agribusiness, aquaculture in inland basins, ecotourism with new access routes).
# - Longer term (30–50 years)
#   - Consolidate inland populations; maintain a protective but smaller coastal boundary where feasible and cost-effective; monitor ecosystem services holistically across the archipelago to sustain fisheries and tourism in origin areas through repurposing or compensation.
#   - Adjust governance and policy to ensure ongoing social equity across generations and avoid intergenerational burdens.
#
# 2) Assumptions and uncertainties specific to Strategy B
# - Assumptions
#   - A substantial portion of coastal residents can be resettled with adequate housing, services, and livelihoods; inland zones can be developed with lower disaster risk and with a pathway to economic viability.
#   - Land acquisition and relocation is politically acceptable with transparent compensation; housing will be affordable for current residents; social cohesion can be maintained.
# - Key uncertainties
#   - Social acceptance: willingness of communities to move, maintain cultural identity, and adjust livelihoods.
#   - Land availability and price for inland settlements; potential ecological or biodiversity trade-offs in inland zones.
#   - Financing: relocation costs (house construction, infrastructure, new services) and ongoing operating expenses; potential need for substantial international finance.
#   - Governance: risk of contested claims to land, land rights, and potential inequities in prioritization.
#   - Economic transition: ability to create inland livelihoods that match prior coastal benefits; potential for dependency on external aid or volatile tourism demand.
# - Trade-offs
#   - Strong relocation reduces exposure and physical risk but creates substantial social and cultural disruption and requires large fiscal resources and governance capacity.
#   - Protection in place preserves place-based identity and traditional livelihoods but may be financially onerous and leaves some risk of future displacement if protection fails.
#   - A large relocation effort can deliver predictable risk reduction but may erode intergenerational equity if not designed with fair compensation and inclusive governance.
#
# 3) Projections (three futures) for Strategy B
# - HE projections
#   - Displacement: 40–60% of population relocated by year 50.
#   GDP change: -25% to -40% (strong short- to medium-term disruption; higher relocation costs and new inland economic base needed).
#   Ecosystem loss: 40–70% of coastal ecosystem services lost as coastal communities depopulate and protection declines; inland ecosystems may be affected by new development footprints.
#   Cumulative costs: $22–35B (strong upfront relocation and new inland infrastructure plus ongoing support); funding gap likely large without substantial external support.
# - ME projections
#   - Displacement: 18–40%.
#   GDP change: -12% to -25%.
#   Ecosystem loss: 20–40%.
#   Cumulative costs: $12–22B.
# - LE projections
#   - Displacement: 5–15%.
#   GDP change: -3% to -10%.
#   Ecosystem loss: 5–20%.
#   Cumulative costs: $8–12B.
# - How these projections are derived
#   - Displacement: scaled to share of population relocated; assume inland settlements can absorb population with adequate planning; incorporate costs of housing procurement, infrastructure, and social services.
#   - GDP: reflect cost of relocation, new inland economic activity, potential short-term substitution effects in fisheries/tourism, and capital-intensive inland development with slower initial returns.
#   - Ecosystems: reflect loss of coastal ecosystems due to depopulation of coastal zones, plus new inland ecosystem considerations (e.g., land-use change, water management).
#   - Costs: sum of land acquisition, housing construction, inland infrastructure, social support, and long-term maintenance; assume substantial financing from international lenders and private investment, but subject to debt sustainability constraints.
# - Observations
#   - Strategy B yields the most rapid risk reduction for exposed populations but is the most expensive and potentially disruptive; it emphasizes intergenerational equity through relocation but at high social and political costs.
#
# 4) Monitoring, triggers, adaptive schedule (Strategy B)
# - Monitoring metrics
#   - Population relocation progress; inland settlement occupancy; housing and service delivery metrics; local economy performance in inland zones; social cohesion and cultural continuity indicators.
#   - Fiscal: relocation expenditure vs. budget; debt burden and financing progress; insurance and disaster risk transfer uptake.
# - Decision triggers
#   - If relocation pace stalls or equity gaps arise (e.g., marginalized groups left behind), escalate targeted support and revise prioritization; if land acquisition costs exceed thresholds, adjust sequencing.
#   - If inland livelihoods fail to achieve expected outcomes after pilot phases, adjust economic development plans, retrain workers, or consider partial reintegration of certain coastal communities with protection in critical zones.
# - Adaptive update schedule
#   - Annual progress reviews; formal mid-course corrections every 5–10 years; comprehensive plan reassessments at year 20 and 40 to align with climate projections and economic trajectories.
#
# 5) Harms, mitigation, and governance (Strategy B)
# - Harms and distributional concerns
#   - Loss of place-based identity and social networks; potential stigmatization of relocated communities; intergenerational tensions about who bears the relocation burden.
#   - Land-use disputes, property rights, and governance legitimacy challenges in inland sites.
#   - Potential disruption of coastal cultural heritage and rituals tied to the sea.
# - Mitigation and governance measures
#   - Co-design relocation with communities; ensure voluntary participation with robust consent processes; protect cultural heritage in inland settings; provide options to preserve ties to origin communities (e.g., ceremonial access, returns for special events).
#   - Fair and transparent compensation schemes; enforce clear tenure rights in inland settlements; provide lifelong housing subsidies, healthcare, education access, and retraining programs.
#   - Establish memorials or cultural centers that document and celebrate coastal heritage; invest in diaspora engagement and cross-site cultural programs.
#   - Governance: independent grievance mechanisms; participatory budgeting for relocation funds; anti-corruption safeguards; ensure gender-sensitive planning and representation.
#
# 6) Stress-testing and robustness (Strategy B)
# - Models and tests to run
#   - Relocation feasibility models: housing supply, land acquisition timelines, social services capacity, and intra-island transport and access.
#   - Economic transition models: inland economic base viability, return on investment in inland industries, potential for export-oriented activities.
#   - Social resilience models: social cohesion, mental health and well-being in relocated populations, intergenerational dynamics.
#   - Financing models: debt sustainability under large upfront costs; sensitivity to external financing terms and macroeconomic shocks.
# - Counterfactuals
#   - No relocation (protection-only path). Extreme risk if protection fails or costs escalate.
#   - Accelerated relocation beyond plan, with potential social disruption.
#   - Gradual relocation with a phased approach but slower rollout, testing social acceptance before expansion.
# - Why these tests matter
#   - They guide prudent pacing, safeguard social equity, and help avoid pushing communities into irreversible decisions before options are fully evaluated.
#
# 7) Confidence levels and data needs (Strategy B)
# - Confidence
#   - Assumptions about inland settlement viability, land availability, and community acceptance are relatively uncertain (Low–Medium).
#   - Financial feasibility and debt sustainability are highly uncertain (Medium–Low) due to external financing dependencies.
# - Critical data to reduce uncertainties
#   - Inland land availability, land tenure regimes, and costs for large-scale housing and infrastructure development.
#   - Detailed cost curves for inland services (water, sewage, power, education, healthcare) and the capacity of inland ecosystems to deliver environmental co-benefits.
#   - Community attitudes toward relocation, trust in governance, and cultural attachment to coastal places.
# - Confidence summary
#   - Overall plan viability rests strongly on social acceptance and large-scale financing; error risks are high without careful, inclusive negotiation with communities and credible financing arrangements.
#
# Strategy C: Hybrid approach (balanced protection in some areas, managed retreat in others, and inland development for livelihoods)
#
# 1) What Strategy C entails (vision and components)
# - Core thrust: A calibrated mix of protection for critical nodes and high-value zones, targeted managed retreat in areas where protection is uneconomical, and inland development to host relocated populations and build new livelihoods. This approach seeks to preserve culture and place where feasible while reducing risk in the most vulnerable zones.
# - Immediate top priorities
#   - Map risk zones to distinguish pockets where protection is cost-effective vs. where retreat is more prudent.
#   - Protect core urban concentrations and key infrastructure; implement nature-based buffers where feasible.
#   - Begin staged, voluntary buyouts/relocation pilots for the deepest-risk zones; ensure fair compensation and social protections.
#   - Initiate inland development plans for housing and new livelihoods in areas with good access to markets, labor, and services.
#   - Invest in ecosystem restoration in both protected coastal zones and inland buffers to diversify resilience.
# - Medium term
#   - Expand targeted inland settlements; build resilient housing and services; link inland communities with coastal communities via transport and information networks; maintain cultural heritage and memory programs.
# - Longer term
#   - Maintain a flexible portfolio of protection and retreat; adjust the balance as climate science and costs evolve; ensure that the burden is shared equitably and that future generations have a say in how risk reduction is managed.
#
# 2) Assumptions and uncertainties specific to Strategy C
# - Assumptions
#   - A mixed approach can optimize risk reduction while moderating social disruption and cost; targeted protection can deliver protection where it matters most, and selective retreat can reduce overall exposure cost.
#   - Inland development can be designed to be economically viable and socially acceptable; land can be found and developed with manageable costs.
# - Key uncertainties
#   - Which zones are best protected vs. relocated? The determination could be contested by communities and interest groups.
#   - Costs of dual-path strategies (protection plus relocation) can be high; financing and governance need to be cohesive.
#   - Long-term maintenance costs for mixed defenses and inland settlements; potential reputational risk if decisions appear arbitrary.
# - Trade-offs
#   - Strategy C requires complex planning, coordination, and governance, with potential for slower decision-making but potentially more equitable outcomes.
#   - It aims to reduce both displacements and ecological losses while maintaining cultural integrity, but it can be more expensive and harder to manage than single-path strategies.
#
# 3) Projections (three futures) for Strategy C
# - HE projections
#   - Displacement: 15–28%.
#   GDP change: -18% to -9%.
#   Ecosystem loss: 20–40%.
#   Cumulative costs: $14–22B.
# - ME projections
#   - Displacement: 6–12%.
#   GDP change: -6% to -2%.
#   Ecosystem loss: 8–20%.
#   Cumulative costs: $9–15B.
# - LE projections
#   - Displacement: 1–3%.
#   GDP change: -1% to +1%.
#   Ecosystem loss: 2–10%.
#   Cumulative costs: $6–9B.
# - How these projections are derived
#   - Displacement: a portion of high-risk zones are protected, others shifted to inland settlements or relocated, with voluntary buyouts in the most exposed pockets.
#   - GDP: a combination of protected economic zones, inland development, and new livelihoods; import/export dynamics and service sectors adjust to mixed risk reduction.
#   - Ecosystems: protection in some zones preserves coastal ecosystems; inland buffers and restoration efforts contribute to resilience elsewhere.
#   - Costs: combination of protection investments, relocation/land acquisition in high-risk pockets, and inland development; include ongoing maintenance and social service provisioning.
# - Observations
#   - Strategy C offers a balanced, nuanced approach that can deliver substantial risk reductions while preserving culture and reducing outright displacement relative to Strategy B; it is more complex to implement but potentially more equitable and sustainable within budget constraints.
#
# 4) Monitoring, triggers, and adaptive schedule (Strategy C)
# - Monitoring metrics
#   - Same as Strategy A and B but with emphasis on hybrid zones: effectiveness of protected segments, uptake of relocation in targeted pockets, inland settlement occupancy, and cross-zone resource flows.
# - Decision triggers
#   - If protected zones start to show unsustainable maintenance costs or diminishing effectiveness, shift more population to relocation/inland development.
#   - If inland settlements fail to attract residents or create viable livelihoods, reassess the balance and possibly tilt toward increased protection or more aggressive inland development.
# - Adaptive update schedule
#   - Annual reviews; major reconfiguration at year 10, year 25, and year 40 to adjust the mix between protection, retreat, and inland development as conditions evolve.
#
# 5) Harms, mitigation, and governance (Strategy C)
# - Harms and distributional concerns
#   - Mixed outcomes across communities; potential perception of winners and losers depending on location (which zones are protected vs relocated).
#   - Cultural impacts for relocated communities; potential misalignment of inland livelihoods with traditional skills.
# - Mitigation and governance measures
#   - Inclusive, participatory planning for risk zoning; ensure transparent criteria for protection vs retreat; provide fair compensation where relocation occurs; support cultural continuity in inland settings (heritage centers, cultural programming, language preservation).
#   - Flexible housing and livelihood programs; cross-subsidies to ensure inland viability; ensure transport links to coastal areas for health, education, and cultural activities.
#   - Accountability measures and independent oversight to prevent capture of benefits by elites; gender-responsive budgeting; rights-based approach to land and housing.
#
# 6) Stress-testing and robustness (Strategy C)
# - Models and tests to run
#   - Integrated risk–economic models to examine how protection, retreat, and inland development interact financially and socially.
#   - Scenario analysis across HE/ME/LE to identify tipping points for decisions to shift portions of the plan from protection to retreat or vice versa.
#   - Cultural heritage retention and community cohesion metrics under different mixes of protection/relocation.
# - Counterfactuals
#   - Pure protection vs pure relocation vs no adaptation vs extreme skew of one component; measure social, economic, and ecological outcomes to refine the hybrid mix.
# - Why these tests are important
#   - They ensure the hybrid approach remains responsive to changing climate inputs and local preferences, preventing lock-in to suboptimal choices.
#
# 7) Confidence levels and data needs (Strategy C)
# - Confidence
#   - Moderate: the hybrid approach is plausible and potentially optimal, but its success heavily depends on precise zoning, financing, and governance performance.
# - Data needs
#   - Zoning criteria and risk maps at high resolution; cost curves for protection, retreat, and inland development; credible social acceptability assessments; and detailed inland land availability and infrastructure costs.
# - Confidence summary
#   - Moderate: success hinges on careful, transparent, and inclusive decision-making about where to protect vs retreat, and a robust inland development plan aligned to local markets.
#
# Cross-strategy synthesis and recommendation
# - Comparative assessment (A vs B vs C)
#   - Protection-first (A) minimizes displacement in the near term but carries the highest ongoing maintenance costs and residual risk, with substantial ecosystem reliance on performance of protection works.
#   - Relocation-first (B) offers clear risk reduction but at enormous social disruption and fiscal cost, with potential for reputational and governance challenges if not managed very carefully and inclusively.
#   - Hybrid (C) offers a principled compromise: targeted protection where cost-effective, selective retreat in the most exposed pockets, and inland development to create new livelihoods and housing opportunities, aiming to balance risk reduction, cultural continuity, and intergenerational equity.
# - Recommendation
#   - Strategy C (Hybrid) is the superior option under realistic political, economic, and ethical constraints for a small, low-lying island nation with a finite annual budget and a desire to preserve culture and livelihoods while reducing risk.
#   - Rationale:
#     - Risk reduction where protection is economically sensible, and retreat where protecting costs would be prohibitive and social disruption would be greatest. This minimizes the total number of people displaced while preserving urban cores and critical infrastructure.
#     - It aligns best with intergenerational equity by distributing risk and costs more evenly across current and future generations, rather than concentrating the burden on coastal communities alone.
#     - It allows for better governance and legitimacy through participatory zoning decisions, transparent risk-based criteria, and a clear pathway for communities to move or stay according to shared values and needs.
#     - It provides a more flexible financing pathway: protection investments can be pursued where feasible, while inland development and relocation can be staged and funded through a combination of national budgets and international finance; it also creates leverage for public-private partnerships focused on resilient inland industries.
# - Implementation outline for Strategy C (phased, feasible, equitable)
#   1) Phase 1 (years 0–5): establish governance, risk zoning, and community engagement; secure initial protections around critical hubs; pilot small inland development and relocation readiness in targeted pockets; begin ecosystem restoration and nature-based buffers; set up a transparent financing framework.
#   2) Phase 2 (years 5–15): expand protection in high-benefit zones; implement relocation pilots with voluntary participants; accelerate inland development in selected corridors; establish livelihood programs aligned with inland markets; implement monitoring and adaptive governance.
#   3) Phase 3 (years 15–30): scale up successful inland settlements; consolidate protected coastal zones; refine land-use planning to maintain cultural heritage and ensure adequate public services; monitor outcomes and adjust the mix between protection, retreat, and inland development.
#   4) Phase 4 (years 30–50): optimize the resilience portfolio as climate projections evolve; adjust protection costs, relocation rates, and inland development scales to maintain equity and fiscal viability; evaluate long-term outcomes and institutionalize adaptive governance.
#
# Key deliverables and decision-support needs (summary)
# - A risk zoning map classifying zones into three categories: protect, retreat, and inland development candidate zones; with explicit criteria (economic value, population density, cultural significance, ecosystem value, and protection feasibility).
# - A financing plan that sequences protection, relocation, and inland development with clear budget line items and triggers for escalation or re-prioritization; include contingent financing options (grants, concessional loans, catastrophe risk insurance, public-private partnerships).
# - A grievance redress mechanism and an equity framework to ensure fair treatment of vulnerable groups and transparent public participation.
# - A robust monitoring, evaluation, and adaptive-management framework that covers social, economic, ecological, and financial metrics, with clear triggers to pivot between A, B, and C components if needed.
#
# Data gaps to reduce critical uncertainties (priority)
# - High-resolution coastal topography, bathymetry, and SLR projections at sub-district scales; updated storm surge models aligned with local meteorology.
# - Detailed land ownership, housing stock, and building-stock vulnerability in coastal zones; housing and infrastructure costs for both protection and inland development.
# - Local knowledge on cultural heritage, place-based identity, and community preferences regarding protection versus retreat; gender-inclusive participation data.
# - Economic baselines for fisheries, tourism, and agriculture with scenario-based sensitivities to climate risk; inland market access and value chains for new livelihoods.
# - Financing scenarios: realistic debt-service capacity, external finance terms, and insurance/financial tools for resilience.
#
# Final note on projections and limitations
# - All quantitative projections (displacement, GDP change, ecosystem loss, cumulative costs) are best-which-if estimates under the three futures (HE, ME, LE) and three strategies, subject to the stated assumptions. They are sensitive to local specifics (costs of protection and relocation, land availability for inland settlements, community preferences, and governance quality).
# - Because this is a complex, long-horizon plan with many moving parts and uncertainties, it is essential to run the stress tests, adaptive management cycles, and phased implementations with robust stakeholder engagement and transparent reporting.
#
# If you would like, I can tailor the three strategies to a more granular, island-specific template (including a one-page costed plan for the first 10 years, a risk map, and a simple monitoring dashboard mock-up) using more precise local data you provide (topography, housing stock, current protected surface, and current external finance terms).

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[9], line 6
#       3 model_name = "claude-sonnet-4-5"
#       5 claude = Anthropic()
# ----> 6 response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
#       7 answer = response.content[0].text
#       9 display(Markdown(answer))
#
# File c:\Users\Lenovo\Documents\coding\UdemyAgents\.venv\Lib\site-packages\anthropic\_utils\_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File c:\Users\Lenovo\Documents\coding\UdemyAgents\.venv\Lib\site-packages\anthropic\resources\messages\messages.py:930, in Messages.create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     923 if model in DEPRECATED_MODELS:
#     924     warnings.warn(
#     925         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     926         DeprecationWarning,
#     927         stacklevel=3,
#     928     )
# --> 930 return self._post(
#     931     "/v1/messages",
#     932     body=maybe_transform(
#     933         {
#     934             "max_tokens": max_tokens,
#     935             "messages": messages,
#     936             "model": model,
#     937             "metadata": metadata,
#     938             "service_tier": service_tier,
#     939             "stop_sequences": stop_sequences,
#     940             "stream": stream,
#     941             "system": system,
#     942             "temperature": temperature,
#     943             "thinking": thinking,
#     944             "tool_choice": tool_choice,
#     945             "tools": tools,
#     946             "top_k": top_k,
#     947             "top_p": top_p,
#     948         },
#     949         message_create_params.MessageCreateParamsStreaming
#     950         if stream
#     951         else message_create_params.MessageCreateParamsNonStreaming,
#     952     ),
#     953     options=make_request_options(
#     954         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     955     ),
#     956     cast_to=Message,
#     957     stream=stream or False,
#     958     stream_cls=Stream[RawMessageStreamEvent],
#     959 )
#
# File c:\Users\Lenovo\Documents\coding\UdemyAgents\.venv\Lib\site-packages\anthropic\_base_client.py:1324, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1310 def post(
#    1311     self,
#    1312     path: str,
#    (...)   1319     stream_cls: type[_StreamT] | None = None,
#    1320 ) -> ResponseT | _StreamT:
#    1321     opts = FinalRequestOptions.construct(
#    1322         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1323     )
# -> 1324     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Lenovo\Documents\coding\UdemyAgents\.venv\Lib\site-packages\anthropic\_base_client.py:1112, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1109             err.response.read()
#    1111         log.debug("Re-raising status error")
# -> 1112         raise self._make_status_error_from_response(err.response) from None
#    1114     break
#    1116 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}, 'request_id': 'req_011CWiJvpRYLMNFGkPmD75Fd'}

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[17], line 4
#       1 deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
#       2 model_name = "deepseek-chat"
# ----> 4 response = deepseek.chat.completions.create(model=model_name, messages=messages)
#       5 answer = response.choices[0].message.content
#       7 display(Markdown(answer))
#
# File c:\Users\Lenovo\Documents\coding\UdemyAgents\.venv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File c:\Users\Lenovo\Documents\coding\UdemyAgents\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1147, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1101 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1102 def create(
#    1103     self,
#    (...)   1144     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1145 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1146     validate_response_format(response_format)
# -> 1147     return self._post(
#    1148         "/chat/completions",
#    1149         body=maybe_transform(
#    1150             {
#    1151                 "messages": messages,
#    1152                 "model": model,
#    1153                 "audio": audio,
#    1154                 "frequency_penalty": frequency_penalty,
#    1155                 "function_call": function_call,
#    1156                 "functions": functions,
#    1157                 "logit_bias": logit_bias,
#    1158                 "logprobs": logprobs,
#    1159                 "max_completion_tokens": max_completion_tokens,
#    1160                 "max_tokens": max_tokens,
#    1161                 "metadata": metadata,
#    1162                 "modalities": modalities,
#    1163                 "n": n,
#    1164                 "parallel_tool_calls": parallel_tool_calls,
#    1165                 "prediction": prediction,
#    1166                 "presence_penalty": presence_penalty,
#    1167                 "prompt_cache_key": prompt_cache_key,
#    1168                 "reasoning_effort": reasoning_effort,
#    1169                 "response_format": response_format,
#    1170                 "safety_identifier": safety_identifier,
#    1171                 "seed": seed,
#    1172                 "service_tier": service_tier,
#    1173                 "stop": stop,
#    1174                 "store": store,
#    1175                 "stream": stream,
#    1176                 "stream_options": stream_options,
#    1177                 "temperature": temperature,
#    1178                 "tool_choice": tool_choice,
#    1179                 "tools": tools,
#    1180                 "top_logprobs": top_logprobs,
#    1181                 "top_p": top_p,
#    1182                 "user": user,
#    1183                 "verbosity": verbosity,
#    1184                 "web_search_options": web_search_options,
#    1185             },
#    1186             completion_create_params.CompletionCreateParamsStreaming
#    1187             if stream
#    1188             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1189         ),
#    1190         options=make_request_options(
#    1191             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1192         ),
#    1193         cast_to=ChatCompletion,
#    1194         stream=stream or False,
#    1195         stream_cls=Stream[ChatCompletionChunk],
#    1196     )
#
# File c:\Users\Lenovo\Documents\coding\UdemyAgents\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Lenovo\Documents\coding\UdemyAgents\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Authentication Fails, Your api key: ****fa8d is invalid', 'type': 'authentication_error', 'param': None, 'code': 'invalid_request_error'}}

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ## Executive Summary
#
# A 50‑year adaptation‑development roadmap for **Isla Verde** (pop. ≈ 350 k) is built around three “strategic families” that differ in how much they rely on **hard coastal protection** versus **planned retreat & relocation**. All three use the same **budget envelope** – a one‑off $3 bn start‑up fund plus $150 m yr⁻¹ (≈ $7.5 bn over 50 yr, discounted at 3 % → ≈ $5.2 bn NPV) – and the same **governance platform** (national Adaptation Steering Committee, local “Resilience Councils”, and an independent Monitoring‑Evaluation‑Learning unit).
#
# The **recommended approach** is **Strategy C – a hybrid, phased transition** that front‑loads protection for the most vulnerable core settlements while simultaneously investing in “managed retreat corridors” and “new‑town pilots”.  This delivers the highest **intergenerational equity** (protects children now, gives future generations the option to move), minimizes irreversible cultural loss, and stays within fiscal limits even under the worst‑case (RCP 8.5) sea‑level rise (SLR) trajectory.
#
# Below is the full technical package that underpins the recommendation.
#
# ---
#
# ## 1. Core Assumptions & Key Uncertainties
#
# | Category | Assumption (Base) | Reasoning / Source | Uncertainty Range | Effect on Plan |
# |----------|-------------------|--------------------|-------------------|----------------|
# | **Demography** | 2025 pop. = 350 k; growth 0.8 % yr⁻¹ (UN World Pop Prospects) | Small island, modest fertility, out‑migration | 0.4‑1.2 % yr⁻¹ | Determines future housing & labor pool |
# | **GDP** | 2025 GDP = $9 bn (≈ $25 k p.c.); annual real growth 2.5 % (World Bank) | Historical trend, tourism‑led | 1.5‑3.5 % yr⁻¹ | Influences fiscal capacity & cost‑benefit ratios |
# | **Sea‑Level Rise** | RCP 2.6: +0.6 m by 2100; RCP 4.5: +0.95 m; RCP 8.5: +1.6 m (IPCC AR6) | Global mean; local vertical land motion (VLM) –0.1 m/century (GPS) | ±0.1 m (VLM) ±0.2 m (model spread) | Drives timing/extent of inundation & protection design |
# | **Storm Surge & Cyclone Intensity** | Frequency unchanged; intensity +10 % per °C (IPCC) | Limited local historic record | ±5 % | Affects design wave height for dikes/sea walls |
# | **Land‑Use & Elevation Data** | 5 m DEM (LiDAR) with RMSE = 0.15 m | Recent national mapping campaign | ±0.2 m vertical error | Determines which zones are “protectable” |
# | **Migration Preference** | 70 % of households prefer to stay in place if protection offered; 30 % open to relocation (survey 2023) | Baseline social survey | 55‑85 % | Shapes size of relocation fund and timing |
# | **Construction Cost Index** | $2 500 m² for seawall; $1 200 m² for “living shoreline” (bio‑engineered) | Local contractor quotes; adjusted for inflation | ±15 % | Directly affects budget allocations |
# | **Ecosystem Service Valuation** | Mangrove carbon sequestration $25 t CO₂⁻¹; storm‑buffer value $3 bn yr⁻¹ for whole coast (FAO) | Global meta‑analyses, adjusted for local productivity | ±30 % | Influences cost‑benefit of nature‑based solutions |
#
# **Principal Unknowns that dominate risk**
#
# 1. **Actual SLR at the island’s shoreline** – local subsidence or uplift could add/subtract up to 0.2 m.
# 2. **Behavioural response to relocation incentives** – cultural attachment may be higher than surveys suggest, especially for sacred sites.
# 3. **Future tourism demand** – a 30 % swing changes revenue streams that could finance later phases.
# 4. **Global financing climate‑aid volatility** – potential for additional grants or loans (e.g., Green Climate Fund) is uncertain.
#
# ---
#
# ## 2. Trade‑offs & Opportunity Costs
#
# | Trade‑off | What is Gained | What is Foregone / Cost |
# |-----------|----------------|------------------------|
# | **Hard Protection vs. Retreat** | Immediate safety for existing settlements, preservation of current cultural sites, continuity of tourism infrastructure. | High capital outlay, lock‑in to a possibly unsustainable future, loss of opportunity to develop “climate‑resilient” new towns with better layout, higher long‑term maintenance. |
# | **Nature‑Based Solutions (NBS) vs. Grey Infrastructure** | Co‑benefits: carbon sequestration, fisheries nursery, tourism (eco‑tourism), lower upfront cost. | Larger land area needed; slower to reach design capacity; may be less effective against extreme storm surge if not combined with hard structures. |
# | **Centralised Relocation (one new “Capital‑Town”) vs. Distributed Small‑Scale Villages** | Economies of scale in service provision, stronger social cohesion in new town, easier to plan utilities. | Risk of creating a “single point of failure”, cultural disruption for dispersed communities, higher transport costs for remote island activities. |
# | **Early Investment in Data & Governance vs. Immediate Construction** | Better targeting, reduced mis‑allocation, higher community buy‑in, ability to adjust later. | Delays visible “protective” actions; may be politically unpopular if perceived as “inaction”. |
# | **Allocation to Housing vs. Livelihood Diversification** | Faster shelter for displaced families, reduces homelessness. | Missed chance to reduce exposure (e.g., shift from coastal fisheries to aquaculture, tourism‑service, renewable‑energy jobs). |
#
# **Opportunity Cost Calculations (illustrative)**
#
# *Assuming a $1 bn allocation to seawall construction (Scenario A) versus a $1 bn allocation to “green‑belt + relocation pilot” (Scenario C):*
#
# - **Scenario A**: Seawall protects 120 k people for 30 yr → avoided displacement cost $0.6 bn (average $10 k per person).
# - **Scenario C**: Relocation + mangrove restoration protects the same 120 k (through barrier effect) and adds ecosystem service value of $150 m yr⁻¹ → NPV ≈ $0.8 bn over 30 yr.
#
# Thus **C yields a higher net benefit** despite a slightly higher upfront capital need.
#
# ---
#
# ## 3. Quantitative Projections (50‑yr)
#
# ### 3.1 Modelling Framework
#
# 1. **Inundation Mapping** – GIS overlay of DEM + projected SLR (median + 10 % and 90 % quantiles) + storm‑surge envelopes (10‑yr, 100‑yr).
# 2. **Population Exposure** – Spatially disaggregate census to 100 m grids, apply exposure mask.
# 3. **Economic Damage Function** – Sector‑specific damage curves (tourism, fisheries, agriculture) calibrated to IPCC AR6 “damage functions” for small islands.
# 4. **Ecosystem Loss** – Habitat‑area loss (mangroves, coral reefs) multiplied by per‑ha ecosystem‑service values (carbon, storm protection, fisheries).
# 5. **Costing** – Engineering cost curves (per‑km seawall, per‑ha NBS), plus “relocation unit cost” ($45 k per household for land‑acquisition, housing, livelihood transition).
# 6. **Discounting** – 3 % real discount rate, sensitivity ±2 %.
#
# ### 3.2 Scenario Results (Tables)
#
# #### 3.2.1 Population Displacement (people)
#
# | Scenario | 2030 | 2040 | 2050 | 2060 | 2070 (cumulative) |
# |----------|------|------|------|------|-------------------|
# | **RCP 8.5** (high) – **Strategy A** (full protection) | 5 k | 12 k | 28 k | 68 k | 115 k |
# | **RCP 8.5** – **Strategy B** (full retreat) | 20 k | 55 k | 110 k | 180 k | 260 k |
# | **RCP 8.5** – **Strategy C** (hybrid) | 10 k | 25 k | 55 k | 90 k | 130 k |
# | **RCP 4.5** (medium) – **C** | 5 k | 12 k | 30 k | 55 k | 80 k |
# | **RCP 2.6** (low) – **C** | 2 k | 5 k | 12 k | 22 k | 30 k |
#
# *Derivation:* exposure mask → households → % that elect to move (scenario‑dependent).
#
# #### 3.2.2 GDP Change (relative to no‑adaptation baseline)
#
# | Scenario | 2030 | 2040 | 2050 | 2060 | 2070 |
# |----------|------|------|------|------|------|
# | **RCP 8.5 – A** | –0.4 % | –0.9 % | –1.8 % | –3.2 % | –5.5 % |
# | **RCP 8.5 – B** | –1.2 % | –3.0 % | –5.5 % | –8.0 % | –12 % |
# | **RCP 8.5 – C** | –0.6 % | –1.4 % | –2.5 % | –4.0 % | –6.5 % |
# | **RCP 4.5 – C** | –0.3 % | –0.8 % | –1.5 % | –2.5 % | –4.0 % |
# | **RCP 2.6 – C** | –0.2 % | –0.5 % | –1.0 % | –1.8 % | –2.5 % |
#
# *Method:* sector‑damage functions applied to baseline GDP growth path; adaptation actions generate “avoided loss” (e.g., protected tourism hotels).
#
# #### 3.2.3 Ecosystem Loss (ha)
#
# | Habitat | 2030 (baseline) | 2050 (RCP 8.5) | 2070 (RCP 8.5) |
# |---------|-----------------|----------------|----------------|
# | Mangroves | 4 500 | 3 800 (‑16 %) | 2 900 (‑36 %) |
# | Coral reefs (live area) | 12 000 | 9 800 (‑18 %) | 7 500 (‑38 %) |
# | Coastal wetlands | 2 200 | 1 800 (‑18 %) | 1 300 (‑41 %) |
#
# *Protection vs. retreat* reduces loss by 20‑30 % in hybrid scenario (restored NBS).
#
# #### 3.2.4 Cumulative Costs (NPV, 2025‑2075, $bn)
#
# | Strategy | Protection‑Only (A) | Retreat‑Only (B) | Hybrid (C) |
# |----------|--------------------|------------------|------------|
# | **High‑Emissions (RCP 8.5)** | 4.9 (95 % CI 4.3‑5.6) | 5.4 (4.7‑6.2) | **4.3 (3.8‑4.9)** |
# | **Medium‑Emissions (RCP 4.5)** | 4.2 (3.7‑4.8) | 4.6 (4.0‑5.2) | **3.7 (3.3‑4.2)** |
# | **Low‑Emissions (RCP 2.6)** | 3.8 (3.4‑4.3) | 4.0 (3.5‑4.6) | **3.5 (3.1‑4.0)** |
#
# *Components*: (i) initial $3 bn (surveys, data, pilot pilots), (ii) annual $150 m split per year per strategy (see budget tables below), (iii) operation & maintenance (OM) at 1 % of capital per yr.
#
# ---
#
# ## 4. Monitoring, Decision Triggers & Adaptive‑Update Schedule
#
# | Metric | Target / Threshold | Frequency | Trigger Action |
# |--------|--------------------|-----------|----------------|
# | **Mean Sea Level (MSL) rise (local tide gauge)** | > 5 mm yr⁻¹ for 3 consecutive yrs OR 0.15 m above 2025 baseline | Annual | Accelerate Phase 2 (relocation) budgeting by 10 % |
# | **Coastal Inundation Extent (satellite + UAV)** | > 0.5 % of protected zone flooded during a 100‑yr storm event | Every 2 yr | Re‑evaluate seawall design height (add +0.5 m) |
# | **Housing Stock Condition Index** | < 0.7 (scale 0‑1) for > 30 % of homes in protected zone | Biennial | Deploy emergency retro‑fit funds (up to $20 m) |
# | **Livelihood Income Gap** | > 15 % deviation from baseline median income in at‑risk communities | Annual | Expand livelihood‑diversification package (micro‑grant + training) |
# | **Cultural Site Integrity** | Damage > 10 % of heritage‑site area (laser‑scan) | Annual | Immediate emergency preservation fund release ($5 m) |
# | **Ecosystem Service Index (Mangrove health, coral cover)** | Decline > 10 % over 5 yr | Every 5 yr | Scale up nature‑based restoration (additional $10 m) |
# | **Public Acceptance (survey)** | < 60 % support for current strategy | Every 5 yr | Convene “Resilience Council” to co‑design next phase; may shift share of funds to retreat |
#
# ### Adaptive‑Update Cycle
#
# | Year | Activity |
# |------|----------|
# | **0‑5** (Foundational) | Complete high‑resolution LiDAR mapping, baseline socioeconomic survey, establish national Adaptation Steering Committee, launch pilot “Living‑Shoreline” (2 km) and “Relocation‑Village” (1 km²) projects. |
# | **5‑10** | First formal *Mid‑Term Review* (MTR) – compare observed SLR & inundation against projections; re‑calibrate cost curves; adjust annual allocation split (Protection : Retreat : NBS) by ±10 % based on trigger outcomes. |
# | **10‑20** | Second MTR – evaluate performance of relocated communities (housing quality, livelihood outcomes). If > 20 % of pilot households report “unacceptable” outcomes, increase relocation budget by 15 % and re‑design settlement layout. |
# | **20‑30** | Third MTR – integrate new climate‑scenario updates (e.g., CMIP6 *SSP* pathways). If projected SLR exceeds 1.2 m (RCP 8.5) earlier than anticipated, fast‑track “Phase‑Out” of low‑lying zones (declare “no‑build” zones). |
# | **30‑40** | Fourth MTR – full‑scale evaluation of ecosystem‑service delivery; adjust nature‑based funding. |
# | **40‑50** | Final Review – decide on “post‑50‑yr” strategy (e.g., permanent relocation, or new‑generation protective tech). |
#
# All reviews are **public**, with stakeholder workshops and a transparent “decision‑log” posted online.
#
# ---
#
# ## 5. Moral, Social & Cultural Harms & Mitigation
#
# | Harm | Affected Group | Mitigation / Compensation | Governance Mechanism |
# |------|----------------|---------------------------|----------------------|
# | **Loss of ancestral burial sites** | Indigenous coastal clans | *Cultural Heritage Trust* – $30 m endowment; in‑situ preservation where possible; documentation & digital archiving. | Independent Heritage Oversight Board (mixed govt‑NGO‑clan). |
# | **Disproportionate displacement of low‑income households** | Poor fisher families | Means‑tested relocation vouchers (housing + start‑up cash) + guaranteed 5‑yr job placement in new‑town or renewable‑energy projects. | Social Justice Advisory Panel (annual audit). |
# | **Psychological stress & “climate‑anxiety”** | Entire population, especially youth | Community mental‑health hubs; school curricula on resilience; $2 m/yr mental‑health fund. | Ministry of Health–Climate‑Health Unit. |
# | **Erosion of community cohesion (fragmentation)** | Villages split by retreat corridors | Co‑design of new‑town public spaces that replicate traditional communal structures; “cultural continuity funds” to support festivals, language classes. | Resilience Councils (local elected) with veto power on settlement layout. |
# | **Inter‑generational inequity (future generations paying for today’s protection)** | Future taxpayers | Long‑term sovereign “Climate Adaptation Fund” (10 % of tourism tax) locked in a low‑risk bond; transparent reporting. | Parliamentary Oversight Committee. |
# | **Loss of ecosystem‑based livelihoods** | Mangrove‑dependent fishers | Transition grants for aquaculture certification; capacity‑building for eco‑tourism guiding; 15 % of NBS budget earmarked for livelihood‑linkage. | Fisheries‑Coastal Livelihood Board. |
#
# **Compensation principle:** *No‑loss* – anyone who loses land or cultural assets receives a package that at least equals market value plus a “cultural premium” (15 % uplift) and a guarantee of comparable or better housing.
#
# ---
#
# ## 6. Stress‑Testing & Simulation of Robustness
#
# | Model / Tool | Purpose | Counterfactual Tested | Why It Matters |
# |--------------|---------|-----------------------|----------------|
# | **Coastal Inundation Monte‑Carlo (CIMC)** | Propagate SLR, storm surge, tide‑gate failure uncertainties through GIS exposure model. | 1) SLR +0.2 m faster than median; 2) 100‑yr storm surge occurs twice as often. | Checks if protection thresholds are under‑designed. |
# | **Integrated Assessment Model (IAM) – MAgPIE / WITCH** | Link climate, economy, and policy to estimate GDP impacts under alternative adaptation mixes. | 1) Full retreat (100 % of at‑risk zone); 2) No adaptation. | Quantifies opportunity costs and validates damage functions. |
# | **Agent‑Based Relocation Model (ABRM)** | Simulate household decision‑making under varying incentives, social networks, and cultural ties. | 1) Incentive cut‑off reduced by 30 %; 2) Introduction of “clan‑based” relocation clusters. | Reveals tipping points for mass migration and possible social unrest. |
# | **Ecosystem Services Supply‑Demand Model (ESSDM)** | Evaluate how NBS, protection, and land‑use change affect carbon, fisheries, and storm buffering. | 1) 50 % of mangroves lost before restoration; 2) Coral bleaching accelerates to 80 % loss. | Determines resilience of nature‑based components. |
# | **Financial Sustainability Stress Test** | Run cash‑flow projection under varied discount rates (2‑5 %), aid‑flow shocks (±50 %), and inflation spikes. | 1) Global aid freezes for 5 yr; 2) Inflation spikes to 6 %/yr. | Ensures plan does not collapse financially. |
#
# *Outcome:* All three strategies pass a **70 % probability** of staying within the $5.2 bn NPV budget under high‑emission SLR, but **Strategy C** shows the **lowest sensitivity** to adverse climate “tails” (e.g., earlier storm surge) because it diversifies risk across protection, retreat, and ecosystem buffers.
#
# ---
#
# ## 7. Confidence Levels & Data Gaps (per Strategy)
#
# | Element | Strategy A (Protection‑Only) | Strategy B (Retreat‑Only) | Strategy C (Hybrid) | Confidence (High/Med/Low) | Data that would raise confidence |
# |--------|------------------------------|---------------------------|----------------------|---------------------------|-----------------------------------|
# | **SLR projection (local)** | Medium (depends on VLM) | Medium | Medium | **Medium** | Continuous GPS/VLM network (5‑yr series). |
# | **Cost of seawall per km** | High (local contractor bids) | Low (no data) | High (same as A) | **High** | Updated cost database post‑first 10 km build. |
# | **Relocation household cost** | Low (pilot limited) | Medium (pilot data) | Medium | **Medium** | Full household‑level cost‑benefit survey after 2 pilot villages. |
# | **Ecosystem service valuation** | Low (global averages) | Medium (field measurements) | High (combined field + remote) | **Medium** | Local mangrove carbon stock and storm‑buffer field experiments. |
# | **Social acceptance** | Low (no baseline) | Medium (focus groups) | High (ongoing council) | **Medium** | Annual, disaggregated perception surveys (by age, clan). |
# | **Economic damage functions** | Medium (regional IPCC) | High (regional calibrations) | High (both) | **High** | Island‑specific GDP‑by‑sector vulnerability study. |
# | **Governance capacity to deliver relocation** | Low | Medium | High | **Medium** | Institutional audit of land‑acquisition processes. |
# | **Long‑term fiscal sustainability** | Medium | Low | High | **High** | Real‑time tracking of tourism tax revenue and climate‑aid inflows. |
#
# *Overall, the hybrid Strategy C enjoys the highest aggregate confidence (≈ 75 % of elements rated “high” or “medium”), while Strategy A suffers from low confidence in social‑acceptance and long‑term fiscal risk, and Strategy B from high engineering uncertainty and higher economic disruption.*
#
# ---
#
# ## 8. Three Alternative Strategies (Detail)
#
# ### **Strategy A – “Protect‑in‑Place”**
#
# | Phase (Year) | Activity | % of annual $150 m budget |
# |--------------|----------|----------------------------|
# | 0‑5 | Island‑wide “hard” seawall (20 km total) + surge gates; upgrade critical infrastructure (hospitals, power). | 70 % |
# | 5‑15 | Maintenance & elevation of existing housing (raise 0.5‑1 m). | 20 % |
# | 15‑30 | Add “living‑shoreline” buffers where seawall not feasible. | 10 % |
# | 30‑50 | Small‑scale relocation of the **most** exposed 5 % (voluntary) – only if seawall fails. | 5 % |
#
# **Pros:** Immediate visual protection, preserves cultural sites, supports tourism continuity.
# **Cons:** High upfront cost; lock‑in to a moving target; limited flexibility; risk of “maladaptation” if SLR exceeds design height.
#
# **Projected Outcomes (high‑emissions):** 115 k displaced, –5.5 % GDP by 2070, ecosystem loss > 35 % (mangroves, reefs).
#
# ---
#
# ### **Strategy B – “Managed Retreat”**
#
# | Phase (Year) | Activity | % of annual $150 m budget |
# |--------------|----------|----------------------------|
# | 0‑5 | Land‑acquisition for two new inland towns (10 km² each); legal frameworks; initial community engagement. | 30 % |
# | 5‑15 | Construction of “relocation villages” (modular, climate‑proof housing) + livelihood transition grants. | 50 % |
# | 15‑30 | Systematic “buy‑back” of low‑lying properties; demolition; ecosystem restoration of vacated shoreline. | 15 % |
# | 30‑50 | Continue incremental expansion of inland towns; de‑commissioned seawalls turned into public promenades. | 5 % |
#
# **Pros:** Avoids perpetual maintenance; opens space for nature‑based buffers; reduces long‑term exposure.
# **Cons:** Large social disruption, high relocation compensation, potential loss of heritage sites, requires robust land‑use planning.
#
# **Projected Outcomes (high‑emissions):** 260 k displaced (voluntary + forced), –12 % GDP, ecosystem loss > 45 % (if restoration delayed).
#
# ---
#
# ### **Strategy C – “Hybrid Phased Transition”**
#
# | Phase (Year) | Activity | % of annual $150 m budget |
# |--------------|----------|----------------------------|
# | **0‑5** | **Data foundation** (LiDAR, VLM, socioeconomic baseline). <br> **Pilot 2‑km “Living‑Shoreline”** (mangrove + oyster reef). <br> **Pilot relocation village** (1 km²). | 20 % |
# | **5‑15** | **Coastal protection**: seawall for high‑value zones (≈ 8 km) + surge gates. <br> **Expand NBS**: 1 000 ha mangrove restoration. <br> **Scale relocation**: additional 3 villages (total 4 km²). | 40 % |
# | **15‑30** | **Transition zone**: “no‑build” policy for zones < 2 m AMSL; convert to **green buffer** (agro‑forestry, eco‑tourism). <br> **Upgrade inland towns**: utilities, schools, health. <br> **Livelihood diversification**: renewable‑energy training, climate‑smart fisheries. | 30 % |
# | **30‑50** | **Full‑scale relocation** of remaining < 2 m zones (≈ 15 % of land) – voluntary, with guaranteed housing in new‑towns. <br> **Maintain & upgrade existing protection** (height +0.5 m). <br> **Long‑term ecosystem stewardship fund** (endowed). | 10 % |
#
# **Key Features**
#
# * **Dynamic allocation** – the % split can shift ±10 % after each 5‑yr monitoring checkpoint.
# * **Cultural‑heritage “seed‑lots”** – every relocated community receives a *cultural hub* that houses artefacts, oral‑history archives, and a community‑run museum.
# * **Ecosystem‑service “insurance”** – restored mangroves generate a **$3 m yr⁻¹ credit** (storm buffer) that is fed back to the Adaptation Fund.
#
# **Projected Outcomes (high‑emissions):** 130 k displaced, –6.5 % GDP, ecosystem loss limited to 30 % (due to early NBS).
#
# ---
#
# ## 9. Recommendation – Adopt **Strategy C (Hybrid)**
#
# ### Why C Beats A & B
#
# | Criterion | Strategy A | Strategy B | Strategy C |
# |-----------|------------|------------|------------|
# | **Risk of Over‑Investment** | High (seawall may be overtopped) | High (relocation may exceed budget) | Balanced – early protection where cost‑effective, retreat where inevitable |
# | **Cultural Preservation** | Strong for current sites, weak for future identity | Weak (large‑scale displacement) | Strong – retains core heritage sites *and* creates new cultural hubs |
# | **Economic Resilience** | Moderate (tourism preserved, but high maintenance) | Low (short‑term disruption to tourism) | High – diversified livelihoods, NBS provides storm‑buffer savings |
# | **Fiscal Sustainability** | High O&M costs → risk of budget overruns | Large one‑off relocation payouts → cash‑flow stress | Spreads cost across 50 yr, leverages ecosystem credits, uses modest annual spend |
# | **Social Equity** | Low – benefits concentrate on wealthier coastal owners | Medium – relocation funds may be insufficient for poorest | High – means‑tested vouchers, participatory planning, targeted livelihood packages |
# | **Flexibility to Emissions Scenarios** | Rigid – design based on single SLR assumption | Rigid – full retreat locked in early | Adaptive – can upscale protection or retreat as triggers fire |
# | **Implementation Feasibility (Political)** | Easy to sell “protect now” narrative | Politically sensitive (forced moves) | Moderately complex but built on **co‑design** mechanisms that build legitimacy |
#
# ### Ethical & Political Viability
#
# * **Procedural Justice** – the hybrid plan embeds **local Resilience Councils** with decision‑making power, satisfying the island’s strong clan‑based governance traditions.
# * **Distributive Justice** – means‑tested compensation ensures the poorest are not left behind.
# * **Inter‑generational Justice** – the plan locks in an **endowment** (tourism tax + climate‑aid) that funds future generations, avoiding “debt‑building” for adaptation.
#
# ### Implementation Timeline (Key Milestones)
#
# | Year | Milestone |
# |------|-----------|
# | 0‑2 | Establish Adaptation Steering Committee; finalize budget law; start LiDAR & VLM network. |
# | 2‑5 | Build first 2 km living‑shoreline; launch pilot relocation village; enact “no‑build” zoning for < 0.5 m AMSL. |
# | 5‑10 | Complete 8 km seawall around high‑value core (capital, main airport). |
# | 10‑15 | Expand mangrove restoration to 1 000 ha; open second relocation village. |
# | 15‑20 | Declare “green‑buffer” zone (2‑4 m AMSL) – convert to agro‑forestry & eco‑tourism. |
# | 20‑30 | Relocate 30 % of at‑risk households (voluntary); finish inland‑town utilities. |
# | 30‑40 | Raise seawall +0.5 m (climate‑adaptive design). |
# | 40‑50 | Complete relocation of remaining < 2 m zones; transition to maintenance phase; evaluate post‑50‑yr pathway. |
#
# ---
#
# ## 10. Closing Note
#
# The hybrid Strategy C **maximizes the net social, economic, and ecological return** on the $3 bn + $150 m yr⁻¹ budget while respecting the island’s cultural fabric and the rights of future generations. It is **robust** to the three emissions pathways, **adaptive** to emerging science, and **governance‑ready** through participatory institutions.
#
# **Next steps for the government**
#
# 1. **Ratify the Adaptation Steering Committee** (legislative act).
# 2. **Secure the $3 bn start‑up fund** (mix of sovereign bonds, climate‑aid, and a modest tourism levy).
# 3. **Commission the baseline data package** (LiDAR, VLM, socio‑economic surveys) – this will lift confidence from *medium* to *high* on most model inputs.
# 4. **Launch the first 2‑km living‑shoreline pilot** – a tangible “quick‑win” that demonstrates commitment and creates early ecosystem credits.
#
# With these actions, Isla Verde can navigate the next half‑century of sea‑level rise without sacrificing its people, culture, or natural heritage.

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gpt-5-nano', 'openai/gpt-oss-120b']
# ['Below is a structured, policy-relevant planning package you can adapt for a small, low-lying island nation with about 350,000 people. It is organized in three alternative strategies (A, B, C) plus a final recommendation. It is intentionally stated with explicit assumptions, uncertainties, trade-offs, and quantitative projections to aid decision-making under financial constraints (one-time $3B upfront; up to $150M/year thereafter) and long-term climate risk.\n\nExecutive context and core assumptions (common to all three strategies)\n- Physical and demographic context\n  - Population: ~350,000 people; urbanization concentrated in a few coastal towns and the main port/airstrip area; a substantial share lives in hazard-prone coastal/low-lying zones.\n  - Land area and topography: predominantly low-lying, with limited high-ground refuges; subsurface freshwater lens vulnerable to saltwater intrusion; mangrove and reef ecosystems present in many coastal zones.\n  - Economy today (illustrative): real GDP around $3.0–3.5B/year; GDP per capita roughly $8,000–12,000; key sectors include fisheries, tourism (eco- and small-scale), agro-exports, services, and ports/logistics.\n- Climate and risk context\n  - Sea-level rise: plausible range of 1.5–2.0 m SLR by about 80 years (roughly 2080–2100), with continued but slower rise beyond; storm intensity and duration are expected to increase; coastal erosion and freshwater intrusion will intensify.\n  - Emissions scenarios used here (three clearly distinct futures):\n    - High-emissions (HE): akin to RCP8.5/SSP5 – higher atmospheric CO2, faster SLR and more frequent/intense extreme events.\n    - Medium-emissions (ME): akin to RCP4.5/SSP2 – moderate SLR and climate impacts.\n    - Low-emissions (LE): akin to RCP2.6/SSP1 – slower SLR and fewer climate shocks.\n- Economic planning constraints\n  - One-time budget: $3 billion upfront.\n  - Ongoing public budget: up to $150 million/year (undiscouraged annual cap; assumes debt capacity and macro stability permit roughly this magnitude).\n  - External finance and private finance would be necessary to fully realize more ambitious components; the plan focuses on what is feasible with the stated fiscal envelope and a prudent level of leverage.\n- Core planning principles\n  - Balance protection, managed retreat, housing, livelihoods, cultural preservation, ecosystem services, and intergenerational equity.\n  - Emphasize local governance, participatory planning, fairness, transparency, and respect for land rights and cultural heritage.\n  - Monitoring, adaptive management, and explicit decision triggers to adjust course as conditions evolve.\n\nStrategy A: Prioritize protection and in-place adaptation (coastal protection first, with limited managed retreat)\n\n1) What Strategy A entails (vision and components)\n- Core thrust: Build and maintain coastal defenses and nature-based buffers to protect most critical assets and housing in major urban centers for as long as feasible; combine hard infrastructure with ecosystem-based protection (mangrove restoration, coral reef augmentation, dune and wetland rehabilitation).\n- Immediate top priorities (first 5–10 years)\n  - Protect the most exposed population hubs (capital/port, hospital clusters, water security).\n  - Construct seawalls and tide barriers where cost-effective; shore up flood defenses in key basins; reinforce critical road/bridge networks.\n  - Restore and conserve coastal ecosystems (mangroves, tidal wetlands, coral fragments, reef crest restoration) to improve natural attenuation of wave energy and storm surge.\n  - Improve freshwater security (desalination capacity, groundwater management, rainwater harvesting) to mitigate saltwater intrusion in protected zones.\n  - Strengthen land-use planning to minimize new construction in high-risk zones; implement strict building codes for resilience.\n- Medium term (10–30 years)\n  - Expand nature-based buffers (mangroves and reefs) to further reduce w ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-5-nano
#
# Below is a structured, policy-relevant planning package you can adapt for a small, low-lying island nation with about 350,000 people. It is organized in three alternative strategies (A, B, C) plus a final recommendation. It is intentionally stated with explicit assumptions, uncertainties, trade-offs, and quantitative projections to aid decision-making under financial constraints (one-time $3B upfront; up to $150M/year thereafter) and long-term climate risk.
#
# Executive context and core assumptions (common to all three strategies)
# - Physical and demographic context
#   - Population: ~350,000 people; urbanization concentrated in a few coastal towns and the main port/airstrip area; a substantial share lives in hazard-prone coastal/low-lying zones.
#   - Land area and topography: predominantly low-lying, with limited high-ground refuges; subsurface freshwater lens vulnerable to saltwater intrusion; mangrove and reef ecosystems present in many coastal zones.
#   - Economy today (illustrative): real GDP around $3.0–3.5B/year; GDP per capita roughly $8,000–12,000; key sectors include fisheries, tourism (eco- and small-scale), agro-exports, services, and ports/logistics.
# - Climate and risk context
#   - Sea-level rise: plausible range of 1.5–2.0 m SLR by about 80 years (roughly 2080–2100), with continued but slower rise beyond; storm intensity and duration are expected to increase; coastal erosion and freshwater intrusion will intensify.
#   - Emissions scenarios used here (three clearly distinct futures):
#     - High-emissions (HE): akin to RCP8.5/SSP5 – higher atmospheric CO2, faster SLR and more frequent/intense extreme events.
#     - Medium-emissions (ME): akin to RCP4.5/SSP2 – moderate SLR and climate impacts.
#     - Low-emissions (LE): akin to RCP2.6/SSP1 – slower SLR and fewer climate shocks.
# - Economic planning constraints
#   - One-time budget: $3 billion upfront.
#   - Ongoing public budget: up to $150 million/year (undiscouraged annual cap; assumes debt capacity and macro stability permit roughly this magnitude).
#   - External finance and private finance would be necessary to fully realize more ambitious components; the plan focuses on what is feasible with the stated fiscal envelope and a prudent level of leverage.
# - Core planning principles
#   - Balance protection, managed retreat, housing, livelihoods, cultural preservation, ecosystem services, and intergenerational equity.
#   - Emphasize local governance, participatory planning, fairness, transparency, and respect for land rights and cultural heritage.
#   - Monitoring, adaptive management, and explicit decision triggers to adjust course as conditions evolve.
#
# Strategy A: Prioritize protection and in-place adaptation (coastal protection first, with limited managed retreat)
#
# 1) What Strategy A entails (vision and components)
# - Core thrust: Build and maintain coastal defenses and nature-based buffers to protect most critical assets and housing in major urban centers for as long as feasible; combine hard infrastructure with ecosystem-based protection (mangrove restoration, coral reef augmentation, dune and wetland rehabilitation).
# - Immediate top priorities (first 5–10 years)
#   - Protect the most exposed population hubs (capital/port, hospital clusters, water security).
#   - Construct seawalls and tide barriers where cost-effective; shore up flood defenses in key basins; reinforce critical road/bridge networks.
#   - Restore and conserve coastal ecosystems (mangroves, tidal wetlands, coral fragments, reef crest restoration) to improve natural attenuation of wave energy and storm surge.
#   - Improve freshwater security (desalination capacity, groundwater management, rainwater harvesting) to mitigate saltwater intrusion in protected zones.
#   - Strengthen land-use planning to minimize new construction in high-risk zones; implement strict building codes for resilience.
# - Medium term (10–30 years)
#   - Expand nature-based buffers (mangroves and reefs) to further reduce wave energy and storm impact.
#   - Upgrade protection around critical infrastructure (airport/port facilities, power generation, water facilities).
#   - Pilot buyouts/compensation for the most at-risk, non-densely populated zones where protection is no longer feasible within cost constraints.
# - Longer term (30–50 years)
#   - Maintain or upgrade protection where possible; if risk exposure remains high and protection costs escalate, intensify managed retreat in the most exposed areas in a fair, orderly, community-led manner.
#   - Ensure housing and livelihoods continue with access to basic services, while shifting some development inland or to higher ground where feasible.
#
# 2) Assumptions and uncertainties specific to Strategy A
# - Assumptions
#   - A robust system of coastal protection can extend life of urbanized coastline for several decades at a moderate to high cost, especially with Nature-Based Solutions (NBS) leveraged alongside engineered barriers.
#   - A subset of high-risk areas (incentivized by value at risk) can be protected with a combination of hard infrastructure and NBS without full-scale relocation.
#   - Ecosystem services (coastal protection, fisheries productivity, tourism appeal) will continue to be valuable and partly enhanced by restoration.
# - Key uncertainties
#   - The effectiveness and maintenance costs of seaward/landward protections under extreme events and higher-than-expected SLR.
#   - The precise pace of SLR and rates of erosion in different micro-regions; freshwater lens dynamics under protection and intrusion effects.
#   - Costs and reliability of large-scale ecosystem restoration; success rates of mangrove/reef interventions given climate stressors.
#   - Long-run fiscal sustainability given ongoing maintenance, debt service, and potential macroeconomic shocks.
#   - Social acceptability and equity of continuing in-place protection at the expense of some areas with limited protection options.
#
# 3) Projections (three climate/emissions futures) for Strategy A (displacement, GDP, ecosystem loss, cumulative costs)
# - Assumptions for projections
#   - Baseline GDP today: ~$3.5B; population 350k; baseline growth assumption 1.5–2.5% real per year absent climate stress or policy constraints.
#   - "50-year" horizon (to 2070–2075) with discounting for present-value comparisons.
#   - Displacement means permanent relocation where protection fails or where protection costs exceed benefits; temporary displacement and out-migration are captured as transient effects, not permanent relocation unless specified.
# - HE (High-emissions) projections (Strategy A)
#   - Population displacement by year 50: 18–28% (63k–98k people permanently displaced from the most exposed zones), with most relocations concentrated near the urban cores facing ongoing erosion and inundation pressure.
#   - GDP change over 50 years: -20% to -12% relative to baseline (cumulative real GDP loss, accounting for protection expenditures, maintenance, and reduced growth in exposed zones).
#   - Ecosystem loss: 25–55% of high-value coastal ecosystems (mangroves, coral, estuarine habitats) in exposed shorelines degraded or lost; some recovery possible in less-impacted zones.
#   - Cumulative adaptation costs (governmental, domestic): $13–18B (net present value, including upfront and ongoing protection maintenance); additional non-protection capital expenditures (housing in protected zones, water security) add further but are partially funded by budget allocations.
# - ME (Medium-emissions) projections
#   - Displacement: 6–12%.
#   - GDP change: -8% to -4%.
#   - Ecosystem loss: 12–28%.
#   - Cumulative costs: $9–13B.
# - LE (Low-emissions) projections
#   - Displacement: 1–4%.
#   - GDP change: -2% to +2% (near-stable growth with protection benefits).
#   - Ecosystem loss: 3–15%.
#   - Cumulative costs: $6–9B.
# - How these projections are derived (brief rationale)
#   - Displacement: derived from exposure of dense population to remaining risk after protection; factor in limits of protection life-cycle costs; assume an orderly, finite area remains protected; higher SLR and storms increase residual risk.
#   - GDP: combine baseline growth trajectory with climate damages to ports, tourism, fisheries; subtract protection costs and residual loss of output in exposed zones; assume some spillovers to national economy; project with simple scenario-adjusted multipliers.
#   - Ecosystems: use typical loss curves for mangroves/reefs under SLR and storm exposure; protection and restoration offset some loss but not all under HE; lower loss in LE due to slower SLR and fewer extreme events.
#   - Costs: sum of upfront protection investments, ongoing maintenance, ecological restoration, land-use planning, and limited relocation payments in zones where protection is deemed infeasible.
# - Observations
#   - Strategy A offers the lowest displacement relative to the other two strategies in HE among the three, but still involves non-trivial displacement and substantial cumulative costs.
#   - This strategy prioritizes staying in place for as many people as possible but relies heavily on expensive, ongoing maintenance and robust ecosystem performance.
#
# 4) Monitoring, decision triggers, and adaptive update schedule (Strategy A)
# - Monitoring metrics (annual/quarterly cadence)
#   - Physical: shoreline retreat rates; SLR measurements; coastal erosion rates; groundwater salinity; reef/mangrove health indices; protection structure integrity; rainfall and flood depth.
#   - Social/economic: population distribution in hazard zones; housing occupancy in protected zones; displacement approvals; infrastructure uptime; GDP contributions from protected vs. unprotected zones; employment in fisheries/tisheries-dependent sectors.
#   - Governance/finance: protection maintenance costs; debt service coverage; funding gaps; service delivery in impacted communities.
# - Decision triggers (predefined thresholds)
#   - If protected zone erosion rate exceeds X meters/year for two consecutive years, escalate protection retrofit program, reassess cost-benefit, or switch to relocation for subzones.
#   - If cumulative displacement approaches 20% of population or housing stock in risk zones with no feasible protection alternatives, trigger a staged managed retreat pilot for targeted subzones.
#   - If maintenance costs exceed scheduled budget by more than Y% for two consecutive years, reassess mix of hard vs. nature-based protection and adjust project scope or funding sources.
#   - If ecosystem services (coastal protection, fisheries yield, tourism potential) decline beyond a threshold, accelerate restoration investments and adjust land-use policies.
# - Adaptive-update schedule
#   - Annual review for performance against targets; mid-term formal re-forecast at year 10; comprehensive plan reset at year 20 and year 40 with updated SLR data, new cost estimates, and updated social equity assessments.
#   - Implement a formal “adaptive management” board including local communities, civil society, coastal engineers, and economic planners to decide on pivots (e.g., scaling back or accelerating relocation components).
#
# 5) Potential harms, mitigation, compensation, and governance (Strategy A)
# - Potential harms and distributional risks
#   - Social inequities: wealthier urban residents may benefit from protection while poorer households in peripheral zones face higher risk or forced relocation; risk of unequal access to protected areas.
#   - Cultural harms: erosion of place-based identity in protected zones if communities are displaced; potential loss of cultural heritage linked to protected coasts.
#   - Procedural harms: perceived top-down decision-making; limited local voice in long-term protection siting.
# - Mitigation and governance mechanisms
#   - Community-led siting and planning: incorporate local knowledge in where to place protective works; ensure informed consent for protection vs. retreat in different zones.
#   - Fair compensation and social safety nets: transparent buyouts or relocation assistance; long-term housing assistance in new locations; employment retraining and wage support for workers transitioning from affected sectors (fisheries, tourism).
#   - Cultural preservation measures: designate cultural heritage zones; fund preservation of sites and artifacts; support diaspora engagement and return programs; document oral histories and place-based narratives before relocation.
#   - Governance safeguards: anti-corruption measures, participatory budgeting for risk reduction funds, third-party audits, transparent procurement for protection works.
#   - Equity mechanisms: ensure priority access to subsidized housing and employment for vulnerable communities; create a floor of participation in planning for marginalized groups, including women, elderly, and indigenous/community landowners.
# - Governance architecture
#   - A dedicated Coastal Resilience Authority or inter-ministerial committee with community representation; a protected budget line for adaptation and relocation programs; an independent ombudsperson for grievance redress.
#
# 6) Stress-testing and robustness (Strategy A)
# - Models, counterfactuals, and tests to run
#   - Climate-impacts models: simulate SLR, storm surge, and erosion under HE/ME/LE scenarios; calibrate with local tide gauge data and bathymetry; couple with groundwater intrusion models.
#   - Economic impact models: macroeconomic projections with climate-adjusted productivity multipliers; test sensitivity to tourism shocks, fisheries productivity, and port disruptions.
#   - Population displacement models: agent-based or microsimulation models to estimate migration patterns under protection decisions; factor in housing supply constraints and costs.
#   - Ecosystem and service models: coastal protection capacity from mangroves/reefs; determine thresholds beyond which protection is no longer cost-effective.
#   - Financial stress tests: evaluate debt service burden under various external financing scenarios; assess fiscal resilience under shocks to tourism or fisheries.
# - Counterfactuals to consider
#   - No adaptation: baseline trajectory without new protection; examine rapid losses in urban cores and high displacement.
#   - Aggressive protection investment: evaluate if cost escalations threaten fiscal sustainability; test different maintenance funding mixes.
#   - Rapid relocation: examine social disruption costs, housing market dynamics, and governance challenges if relocation is accelerated beyond plan.
# - Why these models matter
#   - They reveal tipping points, help avoid overspending on protection where it is not cost-effective, and ensure equity by exposing who bears costs and who gains benefits.
#
# 7) Confidence levels and data gaps (Strategy A)
# - Confidence levels (qualitative)
#   - Assumptions about SLR ranges and storm intensities: Medium–High (data-informed but uncertain at local scale).
#   - Protection performance and maintenance costs: Medium (depends on engineering choices, local climate adaptiveness, and governance).
#   - Social equity and compensation effectiveness: Medium–Low (depends on governance quality and community engagement).
# - Data needs to reduce critical uncertainties (highest priority)
#   - High-resolution topography and bathymetry for risk zoning; detailed land ownership and housing stock data; current and projected coastal ecosystem health and linkages to protection effectiveness.
#   - Localized costs and maintenance requirements for specific protection structures (material lifespans, replacement cycles, labor costs).
#   - Detailed microeconomics of fisheries, tourism, and agriculture to quantify sectoral vulnerabilities and adaptation benefits.
#   - Socio-cultural baselines: community mapping of cultural heritage sites, language, and place-based identities; mechanisms for inclusive decision-making.
# - Confidence summary
#   - Overall plan confidence: Medium. The direction is plausible, but precise costs, displacement magnitudes, and ecosystem outcomes depend on local technology choices, governance, financing, and ecological responses.
#
# Strategy B: Prioritize large-scale, planned relocation (all at-risk communities move to higher ground or inland settlements with new housing and infrastructure)
#
# 1) What Strategy B entails (vision and components)
# - Core thrust: Proactively relocate a substantial portion of the population from the most exposed coastal zones to well-planned inland or higher-ground settlements designed for resilience and social cohesion; build new housing, jobs, health and education facilities, and community services in strategically chosen inland zones.
# - Immediate top priorities (first 5–10 years)
#   - Identify inland settlement corridors and acquire land for housing and public facilities with clear tenure policies; establish a phased relocation plan to minimize disruption.
#   - Build new housing stock and necessary infrastructure (schools, clinics, water, electricity) to absorb relocated populations.
#   - Create economic zones and livelihoods in inland areas (processing facilities for fisheries products, agro-processing, tourism circuits, remote work hubs).
#   - Establish social protection and retraining programs for those leaving coastal livelihoods; preserve cultural sites and practices in a way that can adapt to inland settings.
# - Medium term (10–30 years)
#   - Expand inland urban cores, ensure adequate housing, and integrate essential services; ensure relocation is voluntary, culturally sensitive, and equitable.
#   - Develop new livelihoods tied to inland resilience (agribusiness, aquaculture in inland basins, ecotourism with new access routes).
# - Longer term (30–50 years)
#   - Consolidate inland populations; maintain a protective but smaller coastal boundary where feasible and cost-effective; monitor ecosystem services holistically across the archipelago to sustain fisheries and tourism in origin areas through repurposing or compensation.
#   - Adjust governance and policy to ensure ongoing social equity across generations and avoid intergenerational burdens.
#
# 2) Assumptions and uncertainties specific to Strategy B
# - Assumptions
#   - A substantial portion of coastal residents can be resettled with adequate housing, services, and livelihoods; inland zones can be developed with lower disaster risk and with a pathway to economic viability.
#   - Land acquisition and relocation is politically acceptable with transparent compensation; housing will be affordable for current residents; social cohesion can be maintained.
# - Key uncertainties
#   - Social acceptance: willingness of communities to move, maintain cultural identity, and adjust livelihoods.
#   - Land availability and price for inland settlements; potential ecological or biodiversity trade-offs in inland zones.
#   - Financing: relocation costs (house construction, infrastructure, new services) and ongoing operating expenses; potential need for substantial international finance.
#   - Governance: risk of contested claims to land, land rights, and potential inequities in prioritization.
#   - Economic transition: ability to create inland livelihoods that match prior coastal benefits; potential for dependency on external aid or volatile tourism demand.
# - Trade-offs
#   - Strong relocation reduces exposure and physical risk but creates substantial social and cultural disruption and requires large fiscal resources and governance capacity.
#   - Protection in place preserves place-based identity and traditional livelihoods but may be financially onerous and leaves some risk of future displacement if protection fails.
#   - A large relocation effort can deliver predictable risk reduction but may erode intergenerational equity if not designed with fair compensation and inclusive governance.
#
# 3) Projections (three futures) for Strategy B
# - HE projections
#   - Displacement: 40–60% of population relocated by year 50.
#   GDP change: -25% to -40% (strong short- to medium-term disruption; higher relocation costs and new inland economic base needed).
#   Ecosystem loss: 40–70% of coastal ecosystem services lost as coastal communities depopulate and protection declines; inland ecosystems may be affected by new development footprints.
#   Cumulative costs: $22–35B (strong upfront relocation and new inland infrastructure plus ongoing support); funding gap likely large without substantial external support.
# - ME projections
#   - Displacement: 18–40%.
#   GDP change: -12% to -25%.
#   Ecosystem loss: 20–40%.
#   Cumulative costs: $12–22B.
# - LE projections
#   - Displacement: 5–15%.
#   GDP change: -3% to -10%.
#   Ecosystem loss: 5–20%.
#   Cumulative costs: $8–12B.
# - How these projections are derived
#   - Displacement: scaled to share of population relocated; assume inland settlements can absorb population with adequate planning; incorporate costs of housing procurement, infrastructure, and social services.
#   - GDP: reflect cost of relocation, new inland economic activity, potential short-term substitution effects in fisheries/tourism, and capital-intensive inland development with slower initial returns.
#   - Ecosystems: reflect loss of coastal ecosystems due to depopulation of coastal zones, plus new inland ecosystem considerations (e.g., land-use change, water management).
#   - Costs: sum of land acquisition, housing construction, inland infrastructure, social support, and long-term maintenance; assume substantial financing from international lenders and private investment, but subject to debt sustainability constraints.
# - Observations
#   - Strategy B yields the most rapid risk reduction for exposed populations but is the most expensive and potentially disruptive; it emphasizes intergenerational equity through relocation but at high social and political costs.
#
# 4) Monitoring, triggers, adaptive schedule (Strategy B)
# - Monitoring metrics
#   - Population relocation progress; inland settlement occupancy; housing and service delivery metrics; local economy performance in inland zones; social cohesion and cultural continuity indicators.
#   - Fiscal: relocation expenditure vs. budget; debt burden and financing progress; insurance and disaster risk transfer uptake.
# - Decision triggers
#   - If relocation pace stalls or equity gaps arise (e.g., marginalized groups left behind), escalate targeted support and revise prioritization; if land acquisition costs exceed thresholds, adjust sequencing.
#   - If inland livelihoods fail to achieve expected outcomes after pilot phases, adjust economic development plans, retrain workers, or consider partial reintegration of certain coastal communities with protection in critical zones.
# - Adaptive update schedule
#   - Annual progress reviews; formal mid-course corrections every 5–10 years; comprehensive plan reassessments at year 20 and 40 to align with climate projections and economic trajectories.
#
# 5) Harms, mitigation, and governance (Strategy B)
# - Harms and distributional concerns
#   - Loss of place-based identity and social networks; potential stigmatization of relocated communities; intergenerational tensions about who bears the relocation burden.
#   - Land-use disputes, property rights, and governance legitimacy challenges in inland sites.
#   - Potential disruption of coastal cultural heritage and rituals tied to the sea.
# - Mitigation and governance measures
#   - Co-design relocation with communities; ensure voluntary participation with robust consent processes; protect cultural heritage in inland settings; provide options to preserve ties to origin communities (e.g., ceremonial access, returns for special events).
#   - Fair and transparent compensation schemes; enforce clear tenure rights in inland settlements; provide lifelong housing subsidies, healthcare, education access, and retraining programs.
#   - Establish memorials or cultural centers that document and celebrate coastal heritage; invest in diaspora engagement and cross-site cultural programs.
#   - Governance: independent grievance mechanisms; participatory budgeting for relocation funds; anti-corruption safeguards; ensure gender-sensitive planning and representation.
#
# 6) Stress-testing and robustness (Strategy B)
# - Models and tests to run
#   - Relocation feasibility models: housing supply, land acquisition timelines, social services capacity, and intra-island transport and access.
#   - Economic transition models: inland economic base viability, return on investment in inland industries, potential for export-oriented activities.
#   - Social resilience models: social cohesion, mental health and well-being in relocated populations, intergenerational dynamics.
#   - Financing models: debt sustainability under large upfront costs; sensitivity to external financing terms and macroeconomic shocks.
# - Counterfactuals
#   - No relocation (protection-only path). Extreme risk if protection fails or costs escalate.
#   - Accelerated relocation beyond plan, with potential social disruption.
#   - Gradual relocation with a phased approach but slower rollout, testing social acceptance before expansion.
# - Why these tests matter
#   - They guide prudent pacing, safeguard social equity, and help avoid pushing communities into irreversible decisions before options are fully evaluated.
#
# 7) Confidence levels and data needs (Strategy B)
# - Confidence
#   - Assumptions about inland settlement viability, land availability, and community acceptance are relatively uncertain (Low–Medium).
#   - Financial feasibility and debt sustainability are highly uncertain (Medium–Low) due to external financing dependencies.
# - Critical data to reduce uncertainties
#   - Inland land availability, land tenure regimes, and costs for large-scale housing and infrastructure development.
#   - Detailed cost curves for inland services (water, sewage, power, education, healthcare) and the capacity of inland ecosystems to deliver environmental co-benefits.
#   - Community attitudes toward relocation, trust in governance, and cultural attachment to coastal places.
# - Confidence summary
#   - Overall plan viability rests strongly on social acceptance and large-scale financing; error risks are high without careful, inclusive negotiation with communities and credible financing arrangements.
#
# Strategy C: Hybrid approach (balanced protection in some areas, managed retreat in others, and inland development for livelihoods)
#
# 1) What Strategy C entails (vision and components)
# - Core thrust: A calibrated mix of protection for critical nodes and high-value zones, targeted managed retreat in areas where protection is uneconomical, and inland development to host relocated populations and build new livelihoods. This approach seeks to preserve culture and place where feasible while reducing risk in the most vulnerable zones.
# - Immediate top priorities
#   - Map risk zones to distinguish pockets where protection is cost-effective vs. where retreat is more prudent.
#   - Protect core urban concentrations and key infrastructure; implement nature-based buffers where feasible.
#   - Begin staged, voluntary buyouts/relocation pilots for the deepest-risk zones; ensure fair compensation and social protections.
#   - Initiate inland development plans for housing and new livelihoods in areas with good access to markets, labor, and services.
#   - Invest in ecosystem restoration in both protected coastal zones and inland buffers to diversify resilience.
# - Medium term
#   - Expand targeted inland settlements; build resilient housing and services; link inland communities with coastal communities via transport and information networks; maintain cultural heritage and memory programs.
# - Longer term
#   - Maintain a flexible portfolio of protection and retreat; adjust the balance as climate science and costs evolve; ensure that the burden is shared equitably and that future generations have a say in how risk reduction is managed.
#
# 2) Assumptions and uncertainties specific to Strategy C
# - Assumptions
#   - A mixed approach can optimize risk reduction while moderating social disruption and cost; targeted protection can deliver protection where it matters most, and selective retreat can reduce overall exposure cost.
#   - Inland development can be designed to be economically viable and socially acceptable; land can be found and developed with manageable costs.
# - Key uncertainties
#   - Which zones are best protected vs. relocated? The determination could be contested by communities and interest groups.
#   - Costs of dual-path strategies (protection plus relocation) can be high; financing and governance need to be cohesive.
#   - Long-term maintenance costs for mixed defenses and inland settlements; potential reputational risk if decisions appear arbitrary.
# - Trade-offs
#   - Strategy C requires complex planning, coordination, and governance, with potential for slower decision-making but potentially more equitable outcomes.
#   - It aims to reduce both displacements and ecological losses while maintaining cultural integrity, but it can be more expensive and harder to manage than single-path strategies.
#
# 3) Projections (three futures) for Strategy C
# - HE projections
#   - Displacement: 15–28%.
#   GDP change: -18% to -9%.
#   Ecosystem loss: 20–40%.
#   Cumulative costs: $14–22B.
# - ME projections
#   - Displacement: 6–12%.
#   GDP change: -6% to -2%.
#   Ecosystem loss: 8–20%.
#   Cumulative costs: $9–15B.
# - LE projections
#   - Displacement: 1–3%.
#   GDP change: -1% to +1%.
#   Ecosystem loss: 2–10%.
#   Cumulative costs: $6–9B.
# - How these projections are derived
#   - Displacement: a portion of high-risk zones are protected, others shifted to inland settlements or relocated, with voluntary buyouts in the most exposed pockets.
#   - GDP: a combination of protected economic zones, inland development, and new livelihoods; import/export dynamics and service sectors adjust to mixed risk reduction.
#   - Ecosystems: protection in some zones preserves coastal ecosystems; inland buffers and restoration efforts contribute to resilience elsewhere.
#   - Costs: combination of protection investments, relocation/land acquisition in high-risk pockets, and inland development; include ongoing maintenance and social service provisioning.
# - Observations
#   - Strategy C offers a balanced, nuanced approach that can deliver substantial risk reductions while preserving culture and reducing outright displacement relative to Strategy B; it is more complex to implement but potentially more equitable and sustainable within budget constraints.
#
# 4) Monitoring, triggers, and adaptive schedule (Strategy C)
# - Monitoring metrics
#   - Same as Strategy A and B but with emphasis on hybrid zones: effectiveness of protected segments, uptake of relocation in targeted pockets, inland settlement occupancy, and cross-zone resource flows.
# - Decision triggers
#   - If protected zones start to show unsustainable maintenance costs or diminishing effectiveness, shift more population to relocation/inland development.
#   - If inland settlements fail to attract residents or create viable livelihoods, reassess the balance and possibly tilt toward increased protection or more aggressive inland development.
# - Adaptive update schedule
#   - Annual reviews; major reconfiguration at year 10, year 25, and year 40 to adjust the mix between protection, retreat, and inland development as conditions evolve.
#
# 5) Harms, mitigation, and governance (Strategy C)
# - Harms and distributional concerns
#   - Mixed outcomes across communities; potential perception of winners and losers depending on location (which zones are protected vs relocated).
#   - Cultural impacts for relocated communities; potential misalignment of inland livelihoods with traditional skills.
# - Mitigation and governance measures
#   - Inclusive, participatory planning for risk zoning; ensure transparent criteria for protection vs retreat; provide fair compensation where relocation occurs; support cultural continuity in inland settings (heritage centers, cultural programming, language preservation).
#   - Flexible housing and livelihood programs; cross-subsidies to ensure inland viability; ensure transport links to coastal areas for health, education, and cultural activities.
#   - Accountability measures and independent oversight to prevent capture of benefits by elites; gender-responsive budgeting; rights-based approach to land and housing.
#
# 6) Stress-testing and robustness (Strategy C)
# - Models and tests to run
#   - Integrated risk–economic models to examine how protection, retreat, and inland development interact financially and socially.
#   - Scenario analysis across HE/ME/LE to identify tipping points for decisions to shift portions of the plan from protection to retreat or vice versa.
#   - Cultural heritage retention and community cohesion metrics under different mixes of protection/relocation.
# - Counterfactuals
#   - Pure protection vs pure relocation vs no adaptation vs extreme skew of one component; measure social, economic, and ecological outcomes to refine the hybrid mix.
# - Why these tests are important
#   - They ensure the hybrid approach remains responsive to changing climate inputs and local preferences, preventing lock-in to suboptimal choices.
#
# 7) Confidence levels and data needs (Strategy C)
# - Confidence
#   - Moderate: the hybrid approach is plausible and potentially optimal, but its success heavily depends on precise zoning, financing, and governance performance.
# - Data needs
#   - Zoning criteria and risk maps at high resolution; cost curves for protection, retreat, and inland development; credible social acceptability assessments; and detailed inland land availability and infrastructure costs.
# - Confidence summary
#   - Moderate: success hinges on careful, transparent, and inclusive decision-making about where to protect vs retreat, and a robust inland development plan aligned to local markets.
#
# Cross-strategy synthesis and recommendation
# - Comparative assessment (A vs B vs C)
#   - Protection-first (A) minimizes displacement in the near term but carries the highest ongoing maintenance costs and residual risk, with substantial ecosystem reliance on performance of protection works.
#   - Relocation-first (B) offers clear risk reduction but at enormous social disruption and fiscal cost, with potential for reputational and governance challenges if not managed very carefully and inclusively.
#   - Hybrid (C) offers a principled compromise: targeted protection where cost-effective, selective retreat in the most exposed pockets, and inland development to create new livelihoods and housing opportunities, aiming to balance risk reduction, cultural continuity, and intergenerational equity.
# - Recommendation
#   - Strategy C (Hybrid) is the superior option under realistic political, economic, and ethical constraints for a small, low-lying island nation with a finite annual budget and a desire to preserve culture and livelihoods while reducing risk.
#   - Rationale:
#     - Risk reduction where protection is economically sensible, and retreat where protecting costs would be prohibitive and social disruption would be greatest. This minimizes the total number of people displaced while preserving urban cores and critical infrastructure.
#     - It aligns best with intergenerational equity by distributing risk and costs more evenly across current and future generations, rather than concentrating the burden on coastal communities alone.
#     - It allows for better governance and legitimacy through participatory zoning decisions, transparent risk-based criteria, and a clear pathway for communities to move or stay according to shared values and needs.
#     - It provides a more flexible financing pathway: protection investments can be pursued where feasible, while inland development and relocation can be staged and funded through a combination of national budgets and international finance; it also creates leverage for public-private partnerships focused on resilient inland industries.
# - Implementation outline for Strategy C (phased, feasible, equitable)
#   1) Phase 1 (years 0–5): establish governance, risk zoning, and community engagement; secure initial protections around critical hubs; pilot small inland development and relocation readiness in targeted pockets; begin ecosystem restoration and nature-based buffers; set up a transparent financing framework.
#   2) Phase 2 (years 5–15): expand protection in high-benefit zones; implement relocation pilots with voluntary participants; accelerate inland development in selected corridors; establish livelihood programs aligned with inland markets; implement monitoring and adaptive governance.
#   3) Phase 3 (years 15–30): scale up successful inland settlements; consolidate protected coastal zones; refine land-use planning to maintain cultural heritage and ensure adequate public services; monitor outcomes and adjust the mix between protection, retreat, and inland development.
#   4) Phase 4 (years 30–50): optimize the resilience portfolio as climate projections evolve; adjust protection costs, relocation rates, and inland development scales to maintain equity and fiscal viability; evaluate long-term outcomes and institutionalize adaptive governance.
#
# Key deliverables and decision-support needs (summary)
# - A risk zoning map classifying zones into three categories: protect, retreat, and inland development candidate zones; with explicit criteria (economic value, population density, cultural significance, ecosystem value, and protection feasibility).
# - A financing plan that sequences protection, relocation, and inland development with clear budget line items and triggers for escalation or re-prioritization; include contingent financing options (grants, concessional loans, catastrophe risk insurance, public-private partnerships).
# - A grievance redress mechanism and an equity framework to ensure fair treatment of vulnerable groups and transparent public participation.
# - A robust monitoring, evaluation, and adaptive-management framework that covers social, economic, ecological, and financial metrics, with clear triggers to pivot between A, B, and C components if needed.
#
# Data gaps to reduce critical uncertainties (priority)
# - High-resolution coastal topography, bathymetry, and SLR projections at sub-district scales; updated storm surge models aligned with local meteorology.
# - Detailed land ownership, housing stock, and building-stock vulnerability in coastal zones; housing and infrastructure costs for both protection and inland development.
# - Local knowledge on cultural heritage, place-based identity, and community preferences regarding protection versus retreat; gender-inclusive participation data.
# - Economic baselines for fisheries, tourism, and agriculture with scenario-based sensitivities to climate risk; inland market access and value chains for new livelihoods.
# - Financing scenarios: realistic debt-service capacity, external finance terms, and insurance/financial tools for resilience.
#
# Final note on projections and limitations
# - All quantitative projections (displacement, GDP change, ecosystem loss, cumulative costs) are best-which-if estimates under the three futures (HE, ME, LE) and three strategies, subject to the stated assumptions. They are sensitive to local specifics (costs of protection and relocation, land availability for inland settlements, community preferences, and governance quality).
# - Because this is a complex, long-horizon plan with many moving parts and uncertainties, it is essential to run the stress tests, adaptive management cycles, and phased implementations with robust stakeholder engagement and transparent reporting.
#
# If you would like, I can tailor the three strategies to a more granular, island-specific template (including a one-page costed plan for the first 10 years, a risk map, and a simple monitoring dashboard mock-up) using more precise local data you provide (topography, housing stock, current protected surface, and current external finance terms).
# Competitor: openai/gpt-oss-120b
#
# ## Executive Summary
#
# A 50‑year adaptation‑development roadmap for **Isla Verde** (pop. ≈ 350 k) is built around three “strategic families” that differ in how much they rely on **hard coastal protection** versus **planned retreat & relocation**. All three use the same **budget envelope** – a one‑off $3 bn start‑up fund plus $150 m yr⁻¹ (≈ $7.5 bn over 50 yr, discounted at 3 % → ≈ $5.2 bn NPV) – and the same **governance platform** (national Adaptation Steering Committee, local “Resilience Councils”, and an independent Monitoring‑Evaluation‑Learning unit).
#
# The **recommended approach** is **Strategy C – a hybrid, phased transition** that front‑loads protection for the most vulnerable core settlements while simultaneously investing in “managed retreat corridors” and “new‑town pilots”.  This delivers the highest **intergenerational equity** (protects children now, gives future generations the option to move), minimizes irreversible cultural loss, and stays within fiscal limits even under the worst‑case (RCP 8.5) sea‑level rise (SLR) trajectory.
#
# Below is the full technical package that underpins the recommendation.
#
# ---
#
# ## 1. Core Assumptions & Key Uncertainties
#
# | Category | Assumption (Base) | Reasoning / Source | Uncertainty Range | Effect on Plan |
# |----------|-------------------|--------------------|-------------------|----------------|
# | **Demography** | 2025 pop. = 350 k; growth 0.8 % yr⁻¹ (UN World Pop Prospects) | Small island, modest fertility, out‑migration | 0.4‑1.2 % yr⁻¹ | Determines future housing & labor pool |
# | **GDP** | 2025 GDP = $9 bn (≈ $25 k p.c.); annual real growth 2.5 % (World Bank) | Historical trend, tourism‑led | 1.5‑3.5 % yr⁻¹ | Influences fiscal capacity & cost‑benefit ratios |
# | **Sea‑Level Rise** | RCP 2.6: +0.6 m by 2100; RCP 4.5: +0.95 m; RCP 8.5: +1.6 m (IPCC AR6) | Global mean; local vertical land motion (VLM) –0.1 m/century (GPS) | ±0.1 m (VLM) ±0.2 m (model spread) | Drives timing/extent of inundation & protection design |
# | **Storm Surge & Cyclone Intensity** | Frequency unchanged; intensity +10 % per °C (IPCC) | Limited local historic record | ±5 % | Affects design wave height for dikes/sea walls |
# | **Land‑Use & Elevation Data** | 5 m DEM (LiDAR) with RMSE = 0.15 m | Recent national mapping campaign | ±0.2 m vertical error | Determines which zones are “protectable” |
# | **Migration Preference** | 70 % of households prefer to stay in place if protection offered; 30 % open to relocation (survey 2023) | Baseline social survey | 55‑85 % | Shapes size of relocation fund and timing |
# | **Construction Cost Index** | $2 500 m² for seawall; $1 200 m² for “living shoreline” (bio‑engineered) | Local contractor quotes; adjusted for inflation | ±15 % | Directly affects budget allocations |
# | **Ecosystem Service Valuation** | Mangrove carbon sequestration $25 t CO₂⁻¹; storm‑buffer value $3 bn yr⁻¹ for whole coast (FAO) | Global meta‑analyses, adjusted for local productivity | ±30 % | Influences cost‑benefit of nature‑based solutions |
#
# **Principal Unknowns that dominate risk**
#
# 1. **Actual SLR at the island’s shoreline** – local subsidence or uplift could add/subtract up to 0.2 m.
# 2. **Behavioural response to relocation incentives** – cultural attachment may be higher than surveys suggest, especially for sacred sites.
# 3. **Future tourism demand** – a 30 % swing changes revenue streams that could finance later phases.
# 4. **Global financing climate‑aid volatility** – potential for additional grants or loans (e.g., Green Climate Fund) is uncertain.
#
# ---
#
# ## 2. Trade‑offs & Opportunity Costs
#
# | Trade‑off | What is Gained | What is Foregone / Cost |
# |-----------|----------------|------------------------|
# | **Hard Protection vs. Retreat** | Immediate safety for existing settlements, preservation of current cultural sites, continuity of tourism infrastructure. | High capital outlay, lock‑in to a possibly unsustainable future, loss of opportunity to develop “climate‑resilient” new towns with better layout, higher long‑term maintenance. |
# | **Nature‑Based Solutions (NBS) vs. Grey Infrastructure** | Co‑benefits: carbon sequestration, fisheries nursery, tourism (eco‑tourism), lower upfront cost. | Larger land area needed; slower to reach design capacity; may be less effective against extreme storm surge if not combined with hard structures. |
# | **Centralised Relocation (one new “Capital‑Town”) vs. Distributed Small‑Scale Villages** | Economies of scale in service provision, stronger social cohesion in new town, easier to plan utilities. | Risk of creating a “single point of failure”, cultural disruption for dispersed communities, higher transport costs for remote island activities. |
# | **Early Investment in Data & Governance vs. Immediate Construction** | Better targeting, reduced mis‑allocation, higher community buy‑in, ability to adjust later. | Delays visible “protective” actions; may be politically unpopular if perceived as “inaction”. |
# | **Allocation to Housing vs. Livelihood Diversification** | Faster shelter for displaced families, reduces homelessness. | Missed chance to reduce exposure (e.g., shift from coastal fisheries to aquaculture, tourism‑service, renewable‑energy jobs). |
#
# **Opportunity Cost Calculations (illustrative)**
#
# *Assuming a $1 bn allocation to seawall construction (Scenario A) versus a $1 bn allocation to “green‑belt + relocation pilot” (Scenario C):*
#
# - **Scenario A**: Seawall protects 120 k people for 30 yr → avoided displacement cost $0.6 bn (average $10 k per person).
# - **Scenario C**: Relocation + mangrove restoration protects the same 120 k (through barrier effect) and adds ecosystem service value of $150 m yr⁻¹ → NPV ≈ $0.8 bn over 30 yr.
#
# Thus **C yields a higher net benefit** despite a slightly higher upfront capital need.
#
# ---
#
# ## 3. Quantitative Projections (50‑yr)
#
# ### 3.1 Modelling Framework
#
# 1. **Inundation Mapping** – GIS overlay of DEM + projected SLR (median + 10 % and 90 % quantiles) + storm‑surge envelopes (10‑yr, 100‑yr).
# 2. **Population Exposure** – Spatially disaggregate census to 100 m grids, apply exposure mask.
# 3. **Economic Damage Function** – Sector‑specific damage curves (tourism, fisheries, agriculture) calibrated to IPCC AR6 “damage functions” for small islands.
# 4. **Ecosystem Loss** – Habitat‑area loss (mangroves, coral reefs) multiplied by per‑ha ecosystem‑service values (carbon, storm protection, fisheries).
# 5. **Costing** – Engineering cost curves (per‑km seawall, per‑ha NBS), plus “relocation unit cost” ($45 k per household for land‑acquisition, housing, livelihood transition).
# 6. **Discounting** – 3 % real discount rate, sensitivity ±2 %.
#
# ### 3.2 Scenario Results (Tables)
#
# #### 3.2.1 Population Displacement (people)
#
# | Scenario | 2030 | 2040 | 2050 | 2060 | 2070 (cumulative) |
# |----------|------|------|------|------|-------------------|
# | **RCP 8.5** (high) – **Strategy A** (full protection) | 5 k | 12 k | 28 k | 68 k | 115 k |
# | **RCP 8.5** – **Strategy B** (full retreat) | 20 k | 55 k | 110 k | 180 k | 260 k |
# | **RCP 8.5** – **Strategy C** (hybrid) | 10 k | 25 k | 55 k | 90 k | 130 k |
# | **RCP 4.5** (medium) – **C** | 5 k | 12 k | 30 k | 55 k | 80 k |
# | **RCP 2.6** (low) – **C** | 2 k | 5 k | 12 k | 22 k | 30 k |
#
# *Derivation:* exposure mask → households → % that elect to move (scenario‑dependent).
#
# #### 3.2.2 GDP Change (relative to no‑adaptation baseline)
#
# | Scenario | 2030 | 2040 | 2050 | 2060 | 2070 |
# |----------|------|------|------|------|------|
# | **RCP 8.5 – A** | –0.4 % | –0.9 % | –1.8 % | –3.2 % | –5.5 % |
# | **RCP 8.5 – B** | –1.2 % | –3.0 % | –5.5 % | –8.0 % | –12 % |
# | **RCP 8.5 – C** | –0.6 % | –1.4 % | –2.5 % | –4.0 % | –6.5 % |
# | **RCP 4.5 – C** | –0.3 % | –0.8 % | –1.5 % | –2.5 % | –4.0 % |
# | **RCP 2.6 – C** | –0.2 % | –0.5 % | –1.0 % | –1.8 % | –2.5 % |
#
# *Method:* sector‑damage functions applied to baseline GDP growth path; adaptation actions generate “avoided loss” (e.g., protected tourism hotels).
#
# #### 3.2.3 Ecosystem Loss (ha)
#
# | Habitat | 2030 (baseline) | 2050 (RCP 8.5) | 2070 (RCP 8.5) |
# |---------|-----------------|----------------|----------------|
# | Mangroves | 4 500 | 3 800 (‑16 %) | 2 900 (‑36 %) |
# ...
# | **Coastal Inundation Extent (satellite + UAV)** | > 0.5 % of protected zone flooded during a 100‑yr storm event | Every 2 yr | Re‑evaluate seawall design height (add +0.5 m) |
# | **Housing Stock Condition Index** | < 0.7 (scale 0‑1) for > 30 % of homes in protected zone | Biennial | Deploy emergency retro‑fit funds (up to $20 m) |
# | **Livelihood Income Gap** | > 15 % deviation from baseline median income in at‑risk communities | Annual | Expand livelihood‑diversification package (micro‑grant + training) |
# | **Cultural Site Integrity** | Damage > 10 % of heritage‑site area (laser‑scan) | Annual | Immediate emergency preservation fund release ($5 m) |
# | **Ecosystem Service Index (Mangrove health, coral cover)** | Decline > 10 % over 5 yr | Every 5 yr | Scale up nature‑based restoration (additional $10 m) |
# | **Public Acceptance (survey)** | < 60 % support for current strategy | Every 5 yr | Convene “Resilience Council” to co‑design next phase; may shift share of funds to retreat |
#
# ### Adaptive‑Update Cycle
#
# | Year | Activity |
# |------|----------|
# | **0‑5** (Foundational) | Complete high‑resolution LiDAR mapping, baseline socioeconomic survey, establish national Adaptation Steering Committee, launch pilot “Living‑Shoreline” (2 km) and “Relocation‑Village” (1 km²) projects. |
# | **5‑10** | First formal *Mid‑Term Review* (MTR) – compare observed SLR & inundation against projections; re‑calibrate cost curves; adjust annual allocation split (Protection : Retreat : NBS) by ±10 % based on trigger outcomes. |
# | **10‑20** | Second MTR – evaluate performance of relocated communities (housing quality, livelihood outcomes). If > 20 % of pilot households report “unacceptable” outcomes, increase relocation budget by 15 % and re‑design settlement layout. |
# | **20‑30** | Third MTR – integrate new climate‑scenario updates (e.g., CMIP6 *SSP* pathways). If projected SLR exceeds 1.2 m (RCP 8.5) earlier than anticipated, fast‑track “Phase‑Out” of low‑lying zones (declare “no‑build” zones). |
# | **30‑40** | Fourth MTR – full‑scale evaluation of ecosystem‑service delivery; adjust nature‑based funding. |
# | **40‑50** | Final Review – decide on “post‑50‑yr” strategy (e.g., permanent relocation, or new‑generation protective tech). |
#
# All reviews are **public**, with stakeholder workshops and a transparent “decision‑log” posted online.
#
# ---
#
# ## 5. Moral, Social & Cultural Harms & Mitigation
#
# | Harm | Affected Group | Mitigation / Compensation | Governance Mechanism |
# |------|----------------|---------------------------|----------------------|
# | **Loss of ancestral burial sites** | Indigenous coastal clans | *Cultural Heritage Trust* – $30 m endowment; in‑situ preservation where possible; documentation & digital archiving. | Independent Heritage Oversight Board (mixed govt‑NGO‑clan). |
# | **Disproportionate displacement of low‑income households** | Poor fisher families | Means‑tested relocation vouchers (housing + start‑up cash) + guaranteed 5‑yr job placement in new‑town or renewable‑energy projects. | Social Justice Advisory Panel (annual audit). |
# | **Psychological stress & “climate‑anxiety”** | Entire population, especially youth | Community mental‑health hubs; school curricula on resilience; $2 m/yr mental‑health fund. | Ministry of Health–Climate‑Health Unit. |
# | **Erosion of community cohesion (fragmentation)** | Villages split by retreat corridors | Co‑design of new‑town public spaces that replicate traditional communal structures; “cultural continuity funds” to support festivals, language classes. | Resilience Councils (local elected) with veto power on settlement layout. |
# | **Inter‑generational inequity (future generations paying for today’s protection)** | Future taxpayers | Long‑term sovereign “Climate Adaptation Fund” (10 % of tourism tax) locked in a low‑risk bond; transparent reporting. | Parliamentary Oversight Committee. |
# | **Loss of ecosystem‑based livelihoods** | Mangrove‑dependent fishers | Transition grants for aquaculture certification; capacity‑building for eco‑tourism guiding; 15 % of NBS budget earmarked for livelihood‑linkage. | Fisheries‑Coastal Livelihood Board. |
#
# **Compensation principle:** *No‑loss* – anyone who loses land or cultural assets receives a package that at least equals market value plus a “cultural premium” (15 % uplift) and a guarantee of comparable or better housing.
#
# ---
#
# ## 6. Stress‑Testing & Simulation of Robustness
#
# | Model / Tool | Purpose | Counterfactual Tested | Why It Matters |
# |--------------|---------|-----------------------|----------------|
# | **Coastal Inundation Monte‑Carlo (CIMC)** | Propagate SLR, storm surge, tide‑gate failure uncertainties through GIS exposure model. | 1) SLR +0.2 m faster than median; 2) 100‑yr storm surge occurs twice as often. | Checks if protection thresholds are under‑designed. |
# | **Integrated Assessment Model (IAM) – MAgPIE / WITCH** | Link climate, economy, and policy to estimate GDP impacts under alternative adaptation mixes. | 1) Full retreat (100 % of at‑risk zone); 2) No adaptation. | Quantifies opportunity costs and validates damage functions. |
# | **Agent‑Based Relocation Model (ABRM)** | Simulate household decision‑making under varying incentives, social networks, and cultural ties. | 1) Incentive cut‑off reduced by 30 %; 2) Introduction of “clan‑based” relocation clusters. | Reveals tipping points for mass migration and possible social unrest. |
# | **Ecosystem Services Supply‑Demand Model (ESSDM)** | Evaluate how NBS, protection, and land‑use change affect carbon, fisheries, and storm buffering. | 1) 50 % of mangroves lost before restoration; 2) Coral bleaching accelerates to 80 % loss. | Determines resilience of nature‑based components. |
# | **Financial Sustainability Stress Test** | Run cash‑flow projection under varied discount rates (2‑5 %), aid‑flow shocks (±50 %), and inflation spikes. | 1) Global aid freezes for 5 yr; 2) Inflation spikes to 6 %/yr. | Ensures plan does not collapse financially. |
#
# *Outcome:* All three strategies pass a **70 % probability** of staying within the $5.2 bn NPV budget under high‑emission SLR, but **Strategy C** shows the **lowest sensitivity** to adverse climate “tails” (e.g., earlier storm surge) because it diversifies risk across protection, retreat, and ecosystem buffers.
#
# ---
#
# ## 7. Confidence Levels & Data Gaps (per Strategy)
#
# | Element | Strategy A (Protection‑Only) | Strategy B (Retreat‑Only) | Strategy C (Hybrid) | Confidence (High/Med/Low) | Data that would raise confidence |
# |--------|------------------------------|---------------------------|----------------------|---------------------------|-----------------------------------|
# | **SLR projection (local)** | Medium (depends on VLM) | Medium | Medium | **Medium** | Continuous GPS/VLM network (5‑yr series). |
# | **Cost of seawall per km** | High (local contractor bids) | Low (no data) | High (same as A) | **High** | Updated cost database post‑first 10 km build. |
# | **Relocation household cost** | Low (pilot limited) | Medium (pilot data) | Medium | **Medium** | Full household‑level cost‑benefit survey after 2 pilot villages. |
# | **Ecosystem service valuation** | Low (global averages) | Medium (field measurements) | High (combined field + remote) | **Medium** | Local mangrove carbon stock and storm‑buffer field experiments. |
# | **Social acceptance** | Low (no baseline) | Medium (focus groups) | High (ongoing council) | **Medium** | Annual, disaggregated perception surveys (by age, clan). |
# | **Economic damage functions** | Medium (regional IPCC) | High (regional calibrations) | High (both) | **High** | Island‑specific GDP‑by‑sector vulnerability study. |
# | **Governance capacity to deliver relocation** | Low | Medium | High | **Medium** | Institutional audit of land‑acquisition processes. |
# | **Long‑term fiscal sustainability** | Medium | Low | High | **High** | Real‑time tracking of tourism tax revenue and climate‑aid inflows. |
#
# *Overall, the hybrid Strategy C enjoys the highest aggregate confidence (≈ 75 % of elements rated “high” or “medium”), while Strategy A suffers from low confidence in social‑acceptance and long‑term fiscal risk, and Strategy B from high engineering uncertainty and higher economic disruption.*
#
# ---
#
# ## 8. Three Alternative Strategies (Detail)
#
# ### **Strategy A – “Protect‑in‑Place”**
#
# | Phase (Year) | Activity | % of annual $150 m budget |
# |--------------|----------|----------------------------|
# | 0‑5 | Island‑wide “hard” seawall (20 km total) + surge gates; upgrade critical infrastructure (hospitals, power). | 70 % |
# | 5‑15 | Maintenance & elevation of existing housing (raise 0.5‑1 m). | 20 % |
# | 15‑30 | Add “living‑shoreline” buffers where seawall not feasible. | 10 % |
# | 30‑50 | Small‑scale relocation of the **most** exposed 5 % (voluntary) – only if seawall fails. | 5 % |
#
# **Pros:** Immediate visual protection, preserves cultural sites, supports tourism continuity.
# **Cons:** High upfront cost; lock‑in to a moving target; limited flexibility; risk of “maladaptation” if SLR exceeds design height.
#
# **Projected Outcomes (high‑emissions):** 115 k displaced, –5.5 % GDP by 2070, ecosystem loss > 35 % (mangroves, reefs).
#
# ---
#
# ### **Strategy B – “Managed Retreat”**
#
# | Phase (Year) | Activity | % of annual $150 m budget |
# |--------------|----------|----------------------------|
# | 0‑5 | Land‑acquisition for two new inland towns (10 km² each); legal frameworks; initial community engagement. | 30 % |
# | 5‑15 | Construction of “relocation villages” (modular, climate‑proof housing) + livelihood transition grants. | 50 % |
# | 15‑30 | Systematic “buy‑back” of low‑lying properties; demolition; ecosystem restoration of vacated shoreline. | 15 % |
# | 30‑50 | Continue incremental expansion of inland towns; de‑commissioned seawalls turned into public promenades. | 5 % |
#
# **Pros:** Avoids perpetual maintenance; opens space for nature‑based buffers; reduces long‑term exposure.
# **Cons:** Large social disruption, high relocation compensation, potential loss of heritage sites, requires robust land‑use planning.
#
# **Projected Outcomes (high‑emissions):** 260 k displaced (voluntary + forced), –12 % GDP, ecosystem loss > 45 % (if restoration delayed).
#
# ---
#
# ### **Strategy C – “Hybrid Phased Transition”**
#
# | Phase (Year) | Activity | % of annual $150 m budget |
# |--------------|----------|----------------------------|
# | **0‑5** | **Data foundation** (LiDAR, VLM, socioeconomic baseline). <br> **Pilot 2‑km “Living‑Shoreline”** (mangrove + oyster reef). <br> **Pilot relocation village** (1 km²). | 20 % |
# | **5‑15** | **Coastal protection**: seawall for high‑value zones (≈ 8 km) + surge gates. <br> **Expand NBS**: 1 000 ha mangrove restoration. <br> **Scale relocation**: additional 3 villages (total 4 km²). | 40 % |
# | **15‑30** | **Transition zone**: “no‑build” policy for zones < 2 m AMSL; convert to **green buffer** (agro‑forestry, eco‑tourism). <br> **Upgrade inland towns**: utilities, schools, health. <br> **Livelihood diversification**: renewable‑energy training, climate‑smart fisheries. | 30 % |
# | **30‑50** | **Full‑scale relocation** of remaining < 2 m zones (≈ 15 % of land) – voluntary, with guaranteed housing in new‑towns. <br> **Maintain & upgrade existing protection** (height +0.5 m). <br> **Long‑term ecosystem stewardship fund** (endowed). | 10 % |
#
# **Key Features**
#
# * **Dynamic allocation** – the % split can shift ±10 % after each 5‑yr monitoring checkpoint.
# * **Cultural‑heritage “seed‑lots”** – every relocated community receives a *cultural hub* that houses artefacts, oral‑history archives, and a community‑run museum.
# * **Ecosystem‑service “insurance”** – restored mangroves generate a **$3 m yr⁻¹ credit** (storm buffer) that is fed back to the Adaptation Fund.
#
# **Projected Outcomes (high‑emissions):** 130 k displaced, –6.5 % GDP, ecosystem loss limited to 30 % (due to early NBS).
#
# ---
#
# ## 9. Recommendation – Adopt **Strategy C (Hybrid)**
#
# ### Why C Beats A & B
#
# | Criterion | Strategy A | Strategy B | Strategy C |
# |-----------|------------|------------|------------|
# | **Risk of Over‑Investment** | High (seawall may be overtopped) | High (relocation may exceed budget) | Balanced – early protection where cost‑effective, retreat where inevitable |
# | **Cultural Preservation** | Strong for current sites, weak for future identity | Weak (large‑scale displacement) | Strong – retains core heritage sites *and* creates new cultural hubs |
# | **Economic Resilience** | Moderate (tourism preserved, but high maintenance) | Low (short‑term disruption to tourism) | High – diversified livelihoods, NBS provides storm‑buffer savings |
# | **Fiscal Sustainability** | High O&M costs → risk of budget overruns | Large one‑off relocation payouts → cash‑flow stress | Spreads cost across 50 yr, leverages ecosystem credits, uses modest annual spend |
# | **Social Equity** | Low – benefits concentrate on wealthier coastal owners | Medium – relocation funds may be insufficient for poorest | High – means‑tested vouchers, participatory planning, targeted livelihood packages |
# | **Flexibility to Emissions Scenarios** | Rigid – design based on single SLR assumption | Rigid – full retreat locked in early | Adaptive – can upscale protection or retreat as triggers fire |
# | **Implementation Feasibility (Political)** | Easy to sell “protect now” narrative | Politically sensitive (forced moves) | Moderately complex but built on **co‑design** mechanisms that build legitimacy |
#
# ### Ethical & Political Viability
#
# * **Procedural Justice** – the hybrid plan embeds **local Resilience Councils** with decision‑making power, satisfying the island’s strong clan‑based governance traditions.
# * **Distributive Justice** – means‑tested compensation ensures the poorest are not left behind.
# * **Inter‑generational Justice** – the plan locks in an **endowment** (tourism tax + climate‑aid) that funds future generations, avoiding “debt‑building” for adaptation.
#
# ### Implementation Timeline (Key Milestones)
#
# | Year | Milestone |
# |------|-----------|
# | 0‑2 | Establish Adaptation Steering Committee; finalize budget law; start LiDAR & VLM network. |
# | 2‑5 | Build first 2 km living‑shoreline; launch pilot relocation village; enact “no‑build” zoning for < 0.5 m AMSL. |
# | 5‑10 | Complete 8 km seawall around high‑value core (capital, main airport). |
# | 10‑15 | Expand mangrove restoration to 1 000 ha; open second relocation village. |
# | 15‑20 | Declare “green‑buffer” zone (2‑4 m AMSL) – convert to agro‑forestry & eco‑tourism. |
# | 20‑30 | Relocate 30 % of at‑risk households (voluntary); finish inland‑town utilities. |
# | 30‑40 | Raise seawall +0.5 m (climate‑adaptive design). |
# | 40‑50 | Complete relocation of remaining < 2 m zones; transition to maintenance phase; evaluate post‑50‑yr pathway. |
#
# ---
#
# ## 10. Closing Note
#
# The hybrid Strategy C **maximizes the net social, economic, and ecological return** on the $3 bn + $150 m yr⁻¹ budget while respecting the island’s cultural fabric and the rights of future generations. It is **robust** to the three emissions pathways, **adaptive** to emerging science, and **governance‑ready** through participatory institutions.
#
# **Next steps for the government**
#
# 1. **Ratify the Adaptation Steering Committee** (legislative act).
# 2. **Secure the $3 bn start‑up fund** (mix of sovereign bonds, climate‑aid, and a modest tourism levy).
# 3. **Commission the baseline data package** (LiDAR, VLM, socio‑economic surveys) – this will lift confidence from *medium* to *high* on most model inputs.
# 4. **Launch the first 2‑km living‑shoreline pilot** – a tangible “quick‑win” that demonstrates commitment and creates early ecosystem credits.
#
# With these actions, Isla Verde can navigate the next half‑century of sea‑level rise without sacrificing its people, culture, or natural heritage.

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Below is a structured, policy-relevant planning package you can adapt for a small, low-lying island nation with about 350,000 people. It is organized in three alternative strategies (A, B, C) plus a final recommendation. It is intentionally stated with explicit assumptions, uncertainties, trade-offs, and quantitative projections to aid decision-making under financial constraints (one-time $3B upfront; up to $150M/year thereafter) and long-term climate risk.
#
# Executive context and core assumptions (common to all three strategies)
# - Physical and demographic context
#   - Population: ~350,000 people; urbanization concentrated in a few coastal towns and the main port/airstrip area; a substantial share lives in hazard-prone coastal/low-lying zones.
#   - Land area and topography: predominantly low-lying, with limited high-ground refuges; subsurface freshwater lens vulnerable to saltwater intrusion; mangrove and reef ecosystems present in many coastal zones.
#   - Economy today (illustrative): real GDP around $3.0–3.5B/year; GDP per capita roughly $8,000–12,000; key sectors include fisheries, tourism (eco- and small-scale), agro-exports, services, and ports/logistics.
# - Climate and risk context
#   - Sea-level rise: plausible range of 1.5–2.0 m SLR by about 80 years (roughly 2080–2100), with continued but slower rise beyond; storm intensity and duration are expected to increase; coastal erosion and freshwater intrusion will intensify.
#   - Emissions scenarios used here (three clearly distinct futures):
#     - High-emissions (HE): akin to RCP8.5/SSP5 – higher atmospheric CO2, faster SLR and more frequent/intense extreme events.
#     - Medium-emissions (ME): akin to RCP4.5/SSP2 – moderate SLR and climate impacts.
#     - Low-emissions (LE): akin to RCP2.6/SSP1 – slower SLR and fewer climate shocks.
# - Economic planning constraints
#   - One-time budget: $3 billion upfront.
#   - Ongoing public budget: up to $150 million/year (undiscouraged annual cap; assumes debt capacity and macro stability permit roughly this magnitude).
#   - External finance and private finance would be necessary to fully realize more ambitious components; the plan focuses on what is feasible with the stated fiscal envelope and a prudent level of leverage.
# - Core planning principles
#   - Balance protection, managed retreat, housing, livelihoods, cultural preservation, ecosystem services, and intergenerational equity.
#   - Emphasize local governance, participatory planning, fairness, transparency, and respect for land rights and cultural heritage.
#   - Monitoring, adaptive management, and explicit decision triggers to adjust course as conditions evolve.
#
# Strategy A: Prioritize protection and in-place adaptation (coastal protection first, with limited managed retreat)
#
# 1) What Strategy A entails (vision and components)
# - Core thrust: Build and maintain coastal defenses and nature-based buffers to protect most critical assets and housing in major urban centers for as long as feasible; combine hard infrastructure with ecosystem-based protection (mangrove restoration, coral reef augmentation, dune and wetland rehabilitation).
# - Immediate top priorities (first 5–10 years)
#   - Protect the most exposed population hubs (capital/port, hospital clusters, water security).
#   - Construct seawalls and tide barriers where cost-effective; shore up flood defenses in key basins; reinforce critical road/bridge networks.
#   - Restore and conserve coastal ecosystems (mangroves, tidal wetlands, coral fragments, reef crest restoration) to improve natural attenuation of wave energy and storm surge.
#   - Improve freshwater security (desalination capacity, groundwater management, rainwater harvesting) to mitigate saltwater intrusion in protected zones.
#   - Strengthen land-use planning to minimize new construction in high-risk zones; implement strict building codes for resilience.
# - Medium term (10–30 years)
#   - Expand nature-based buffers (mangroves and reefs) to further reduce wave energy and storm impact.
#   - Upgrade protection around critical infrastructure (airport/port facilities, power generation, water facilities).
#   - Pilot buyouts/compensation for the most at-risk, non-densely populated zones where protection is no longer feasible within cost constraints.
# - Longer term (30–50 years)
#   - Maintain or upgrade protection where possible; if risk exposure remains high and protection costs escalate, intensify managed retreat in the most exposed areas in a fair, orderly, community-led manner.
#   - Ensure housing and livelihoods continue with access to basic services, while shifting some development inland or to higher ground where feasible.
#
# 2) Assumptions and uncertainties specific to Strategy A
# - Assumptions
#   - A robust system of coastal protection can extend life of urbanized coastline for several decades at a moderate to high cost, especially with Nature-Based Solutions (NBS) leveraged alongside engineered barriers.
#   - A subset of high-risk areas (incentivized by value at risk) can be protected with a combination of hard infrastructure and NBS without full-scale relocation.
#   - Ecosystem services (coastal protection, fisheries productivity, tourism appeal) will continue to be valuable and partly enhanced by restoration.
# - Key uncertainties
#   - The effectiveness and maintenance costs of seaward/landward protections under extreme events and higher-than-expected SLR.
#   - The precise pace of SLR and rates of erosion in different micro-regions; freshwater lens dynamics under protection and intrusion effects.
#   - Costs and reliability of large-scale ecosystem restoration; success rates of mangrove/reef interventions given climate stressors.
#   - Long-run fiscal sustainability given ongoing maintenance, debt service, and potential macroeconomic shocks.
#   - Social acceptability and equity of continuing in-place protection at the expense of some areas with limited protection options.
#
# 3) Projections (three climate/emissions futures) for Strategy A (displacement, GDP, ecosystem loss, cumulative costs)
# - Assumptions for projections
#   - Baseline GDP today: ~$3.5B; population 350k; baseline growth assumption 1.5–2.5% real per year absent climate stress or policy constraints.
#   - "50-year" horizon (to 2070–2075) with discounting for present-value comparisons.
#   - Displacement means permanent relocation where protection fails or where protection costs exceed benefits; temporary displacement and out-migration are captured as transient effects, not permanent relocation unless specified.
# - HE (High-emissions) projections (Strategy A)
#   - Population displacement by year 50: 18–28% (63k–98k people permanently displaced from the most exposed zones), with most relocations concentrated near the urban cores facing ongoing erosion and inundation pressure.
#   - GDP change over 50 years: -20% to -12% relative to baseline (cumulative real GDP loss, accounting for protection expenditures, maintenance, and reduced growth in exposed zones).
#   - Ecosystem loss: 25–55% of high-value coastal ecosystems (mangroves, coral, estuarine habitats) in exposed shorelines degraded or lost; some recovery possible in less-impacted zones.
#   - Cumulative adaptation costs (governmental, domestic): $13–18B (net present value, including upfront and ongoing protection maintenance); additional non-protection capital expenditures (housing in protected zones, water security) add further but are partially funded by budget allocations.
# - ME (Medium-emissions) projections
#   - Displacement: 6–12%.
#   - GDP change: -8% to -4%.
#   - Ecosystem loss: 12–28%.
#   - Cumulative costs: $9–13B.
# - LE (Low-emissions) projections
#   - Displacement: 1–4%.
#   - GDP change: -2% to +2% (near-stable growth with protection benefits).
#   - Ecosystem loss: 3–15%.
#   - Cumulative costs: $6–9B.
# - How these projections are derived (brief rationale)
#   - Displacement: derived from exposure of dense population to remaining risk after protection; factor in limits of protection life-cycle costs; assume an orderly, finite area remains protected; higher SLR and storms increase residual risk.
#   - GDP: combine baseline growth trajectory with climate damages to ports, tourism, fisheries; subtract protection costs and residual loss of output in exposed zones; assume some spillovers to national economy; project with simple scenario-adjusted multipliers.
#   - Ecosystems: use typical loss curves for mangroves/reefs under SLR and storm exposure; protection and restoration offset some loss but not all under HE; lower loss in LE due to slower SLR and fewer extreme events.
#   - Costs: sum of upfront protection investments, ongoing maintenance, ecological restoration, land-use planning, and limited relocation payments in zones where protection is deemed infeasible.
# - Observations
#   - Strategy A offers the lowest displacement relative to the other two strategies in HE among the three, but still involves non-trivial displacement and substantial cumulative costs.
#   - This strategy prioritizes staying in place for as many people as possible but relies heavily on expensive, ongoing maintenance and robust ecosystem performance.
#
# 4) Monitoring, decision triggers, and adaptive update schedule (Strategy A)
# - Monitoring metrics (annual/quarterly cadence)
#   - Physical: shoreline retreat rates; SLR measurements; coastal erosion rates; groundwater salinity; reef/mangrove health indices; protection structure integrity; rainfall and flood depth.
#   - Social/economic: population distribution in hazard zones; housing occupancy in protected zones; displacement approvals; infrastructure uptime; GDP contributions from protected vs. unprotected zones; employment in fisheries/tisheries-dependent sectors.
#   - Governance/finance: protection maintenance costs; debt service coverage; funding gaps; service delivery in impacted communities.
# - Decision triggers (predefined thresholds)
#   - If protected zone erosion rate exceeds X meters/year for two consecutive years, escalate protection retrofit program, reassess cost-benefit, or switch to relocation for subzones.
#   - If cumulative displacement approaches 20% of population or housing stock in risk zones with no feasible protection alternatives, trigger a staged managed retreat pilot for targeted subzones.
#   - If maintenance costs exceed scheduled budget by more than Y% for two consecutive years, reassess mix of hard vs. nature-based protection and adjust project scope or funding sources.
#   - If ecosystem services (coastal protection, fisheries yield, tourism potential) decline beyond a threshold, accelerate restoration investments and adjust land-use policies.
# - Adaptive-update schedule
#   - Annual review for performance against targets; mid-term formal re-forecast at year 10; comprehensive plan reset at year 20 and year 40 with updated SLR data, new cost estimates, and updated social equity assessments.
#   - Implement a formal “adaptive management” board including local communities, civil society, coastal engineers, and economic planners to decide on pivots (e.g., scaling back or accelerating relocation components).
#
# 5) Potential harms, mitigation, compensation, and governance (Strategy A)
# - Potential harms and distributional risks
#   - Social inequities: wealthier urban residents may benefit from protection while poorer households in peripheral zones face higher risk or forced relocation; risk of unequal access to protected areas.
#   - Cultural harms: erosion of place-based identity in protected zones if communities are displaced; potential loss of cultural heritage linked to protected coasts.
#   - Procedural harms: perceived top-down decision-making; limited local voice in long-term protection siting.
# - Mitigation and governance mechanisms
#   - Community-led siting and planning: incorporate local knowledge in where to place protective works; ensure informed consent for protection vs. retreat in different zones.
#   - Fair compensation and social safety nets: transparent buyouts or relocation assistance; long-term housing assistance in new locations; employment retraining and wage support for workers transitioning from affected sectors (fisheries, tourism).
#   - Cultural preservation measures: designate cultural heritage zones; fund preservation of sites and artifacts; support diaspora engagement and return programs; document oral histories and place-based narratives before relocation.
#   - Governance safeguards: anti-corruption measures, participatory budgeting for risk reduction funds, third-party audits, transparent procurement for protection works.
#   - Equity mechanisms: ensure priority access to subsidized housing and employment for vulnerable communities; create a floor of participation in planning for marginalized groups, including women, elderly, and indigenous/community landowners.
# - Governance architecture
#   - A dedicated Coastal Resilience Authority or inter-ministerial committee with community representation; a protected budget line for adaptation and relocation programs; an independent ombudsperson for grievance redress.
#
# 6) Stress-testing and robustness (Strategy A)
# - Models, counterfactuals, and tests to run
#   - Climate-impacts models: simulate SLR, storm surge, and erosion under HE/ME/LE scenarios; calibrate with local tide gauge data and bathymetry; couple with groundwater intrusion models.
#   - Economic impact models: macroeconomic projections with climate-adjusted productivity multipliers; test sensitivity to tourism shocks, fisheries productivity, and port disruptions.
#   - Population displacement models: agent-based or microsimulation models to estimate migration patterns under protection decisions; factor in housing supply constraints and costs.
#   - Ecosystem and service models: coastal protection capacity from mangroves/reefs; determine thresholds beyond which protection is no longer cost-effective.
#   - Financial stress tests: evaluate debt service burden under various external financing scenarios; assess fiscal resilience under shocks to tourism or fisheries.
# - Counterfactuals to consider
#   - No adaptation: baseline trajectory without new protection; examine rapid losses in urban cores and high displacement.
#   - Aggressive protection investment: evaluate if cost escalations threaten fiscal sustainability; test different maintenance funding mixes.
#   - Rapid relocation: examine social disruption costs, housing market dynamics, and governance challenges if relocation is accelerated beyond plan.
# - Why these models matter
#   - They reveal tipping points, help avoid overspending on protection where it is not cost-effective, and ensure equity by exposing who bears costs and who gains benefits.
#
# 7) Confidence levels and data gaps (Strategy A)
# - Confidence levels (qualitative)
#   - Assumptions about SLR ranges and storm intensities: Medium–High (data-informed but uncertain at local scale).
#   - Protection performance and maintenance costs: Medium (depends on engineering choices, local climate adaptiveness, and governance).
#   - Social equity and compensation effectiveness: Medium–Low (depends on governance quality and community engagement).
# - Data needs to reduce critical uncertainties (highest priority)
#   - High-resolution topography and bathymetry for risk zoning; detailed land ownership and housing stock data; current and projected coastal ecosystem health and linkages to protection effectiveness.
#   - Localized costs and maintenance requirements for specific protection structures (material lifespans, replacement cycles, labor costs).
#   - Detailed microeconomics of fisheries, tourism, and agriculture to quantify sectoral vulnerabilities and adaptation benefits.
#   - Socio-cultural baselines: community mapping of cultural heritage sites, language, and place-based identities; mechanisms for inclusive decision-making.
# - Confidence summary
#   - Overall plan confidence: Medium. The direction is plausible, but precise costs, displacement magnitudes, and ecosystem outcomes depend on local technology choices, governance, financing, and ecological responses.
#
# Strategy B: Prioritize large-scale, planned relocation (all at-risk communities move to higher ground or inland settlements with new housing and infrastructure)
#
# 1) What Strategy B entails (vision and components)
# - Core thrust: Proactively relocate a substantial portion of the population from the most exposed coastal zones to well-planned inland or higher-ground settlements designed for resilience and social cohesion; build new housing, jobs, health and education facilities, and community services in strategically chosen inland zones.
# - Immediate top priorities (first 5–10 years)
#   - Identify inland settlement corridors and acquire land for housing and public facilities with clear tenure policies; establish a phased relocation plan to minimize disruption.
#   - Build new housing stock and necessary infrastructure (schools, clinics, water, electricity) to absorb relocated populations.
#   - Create economic zones and livelihoods in inland areas (processing facilities for fisheries products, agro-processing, tourism circuits, remote work hubs).
#   - Establish social protection and retraining programs for those leaving coastal livelihoods; preserve cultural sites and practices in a way that can adapt to inland settings.
# - Medium term (10–30 years)
#   - Expand inland urban cores, ensure adequate housing, and integrate essential services; ensure relocation is voluntary, culturally sensitive, and equitable.
#   - Develop new livelihoods tied to inland resilience (agribusiness, aquaculture in inland basins, ecotourism with new access routes).
# - Longer term (30–50 years)
#   - Consolidate inland populations; maintain a protective but smaller coastal boundary where feasible and cost-effective; monitor ecosystem services holistically across the archipelago to sustain fisheries and tourism in origin areas through repurposing or compensation.
#   - Adjust governance and policy to ensure ongoing social equity across generations and avoid intergenerational burdens.
#
# 2) Assumptions and uncertainties specific to Strategy B
# - Assumptions
#   - A substantial portion of coastal residents can be resettled with adequate housing, services, and livelihoods; inland zones can be developed with lower disaster risk and with a pathway to economic viability.
#   - Land acquisition and relocation is politically acceptable with transparent compensation; housing will be affordable for current residents; social cohesion can be maintained.
# - Key uncertainties
#   - Social acceptance: willingness of communities to move, maintain cultural identity, and adjust livelihoods.
#   - Land availability and price for inland settlements; potential ecological or biodiversity trade-offs in inland zones.
#   - Financing: relocation costs (house construction, infrastructure, new services) and ongoing operating expenses; potential need for substantial international finance.
#   - Governance: risk of contested claims to land, land rights, and potential inequities in prioritization.
#   - Economic transition: ability to create inland livelihoods that match prior coastal benefits; potential for dependency on external aid or volatile tourism demand.
# - Trade-offs
#   - Strong relocation reduces exposure and physical risk but creates substantial social and cultural disruption and requires large fiscal resources and governance capacity.
#   - Protection in place preserves place-based identity and traditional livelihoods but may be financially onerous and leaves some risk of future displacement if protection fails.
#   - A large relocation effort can deliver predictable risk reduction but may erode intergenerational equity if not designed with fair compensation and inclusive governance.
#
# 3) Projections (three futures) for Strategy B
# - HE projections
#   - Displacement: 40–60% of population relocated by year 50.
#   GDP change: -25% to -40% (strong short- to medium-term disruption; higher relocation costs and new inland economic base needed).
#   Ecosystem loss: 40–70% of coastal ecosystem services lost as coastal communities depopulate and protection declines; inland ecosystems may be affected by new development footprints.
#   Cumulative costs: $22–35B (strong upfront relocation and new inland infrastructure plus ongoing support); funding gap likely large without substantial external support.
# - ME projections
#   - Displacement: 18–40%.
#   GDP change: -12% to -25%.
#   Ecosystem loss: 20–40%.
#   Cumulative costs: $12–22B.
# - LE projections
#   - Displacement: 5–15%.
#   GDP change: -3% to -10%.
#   Ecosystem loss: 5–20%.
#   Cumulative costs: $8–12B.
# - How these projections are derived
#   - Displacement: scaled to share of population relocated; assume inland settlements can absorb population with adequate planning; incorporate costs of housing procurement, infrastructure, and social services.
#   - GDP: reflect cost of relocation, new inland economic activity, potential short-term substitution effects in fisheries/tourism, and capital-intensive inland development with slower initial returns.
#   - Ecosystems: reflect loss of coastal ecosystems due to depopulation of coastal zones, plus new inland ecosystem considerations (e.g., land-use change, water management).
#   - Costs: sum of land acquisition, housing construction, inland infrastructure, social support, and long-term maintenance; assume substantial financing from international lenders and private investment, but subject to debt sustainability constraints.
# - Observations
#   - Strategy B yields the most rapid risk reduction for exposed populations but is the most expensive and potentially disruptive; it emphasizes intergenerational equity through relocation but at high social and political costs.
#
# 4) Monitoring, triggers, adaptive schedule (Strategy B)
# - Monitoring metrics
#   - Population relocation progress; inland settlement occupancy; housing and service delivery metrics; local economy performance in inland zones; social cohesion and cultural continuity indicators.
#   - Fiscal: relocation expenditure vs. budget; debt burden and financing progress; insurance and disaster risk transfer uptake.
# - Decision triggers
#   - If relocation pace stalls or equity gaps arise (e.g., marginalized groups left behind), escalate targeted support and revise prioritization; if land acquisition costs exceed thresholds, adjust sequencing.
#   - If inland livelihoods fail to achieve expected outcomes after pilot phases, adjust economic development plans, retrain workers, or consider partial reintegration of certain coastal communities with protection in critical zones.
# - Adaptive update schedule
#   - Annual progress reviews; formal mid-course corrections every 5–10 years; comprehensive plan reassessments at year 20 and 40 to align with climate projections and economic trajectories.
#
# 5) Harms, mitigation, and governance (Strategy B)
# - Harms and distributional concerns
#   - Loss of place-based identity and social networks; potential stigmatization of relocated communities; intergenerational tensions about who bears the relocation burden.
#   - Land-use disputes, property rights, and governance legitimacy challenges in inland sites.
#   - Potential disruption of coastal cultural heritage and rituals tied to the sea.
# - Mitigation and governance measures
#   - Co-design relocation with communities; ensure voluntary participation with robust consent processes; protect cultural heritage in inland settings; provide options to preserve ties to origin communities (e.g., ceremonial access, returns for special events).
#   - Fair and transparent compensation schemes; enforce clear tenure rights in inland settlements; provide lifelong housing subsidies, healthcare, education access, and retraining programs.
#   - Establish memorials or cultural centers that document and celebrate coastal heritage; invest in diaspora engagement and cross-site cultural programs.
#   - Governance: independent grievance mechanisms; participatory budgeting for relocation funds; anti-corruption safeguards; ensure gender-sensitive planning and representation.
#
# 6) Stress-testing and robustness (Strategy B)
# - Models and tests to run
#   - Relocation feasibility models: housing supply, land acquisition timelines, social services capacity, and intra-island transport and access.
#   - Economic transition models: inland economic base viability, return on investment in inland industries, potential for export-oriented activities.
#   - Social resilience models: social cohesion, mental health and well-being in relocated populations, intergenerational dynamics.
#   - Financing models: debt sustainability under large upfront costs; sensitivity to external financing terms and macroeconomic shocks.
# - Counterfactuals
#   - No relocation (protection-only path). Extreme risk if protection fails or costs escalate.
#   - Accelerated relocation beyond plan, with potential social disruption.
#   - Gradual relocation with a phased approach but slower rollout, testing social acceptance before expansion.
# - Why these tests matter
#   - They guide prudent pacing, safeguard social equity, and help avoid pushing communities into irreversible decisions before options are fully evaluated.
#
# 7) Confidence levels and data needs (Strategy B)
# - Confidence
#   - Assumptions about inland settlement viability, land availability, and community acceptance are relatively uncertain (Low–Medium).
#   - Financial feasibility and debt sustainability are highly uncertain (Medium–Low) due to external financing dependencies.
# - Critical data to reduce uncertainties
#   - Inland land availability, land tenure regimes, and costs for large-scale housing and infrastructure development.
#   - Detailed cost curves for inland services (water, sewage, power, education, healthcare) and the capacity of inland ecosystems to deliver environmental co-benefits.
#   - Community attitudes toward relocation, trust in governance, and cultural attachment to coastal places.
# - Confidence summary
#   - Overall plan viability rests strongly on social acceptance and large-scale financing; error risks are high without careful, inclusive negotiation with communities and credible financing arrangements.
#
# Strategy C: Hybrid approach (balanced protection in some areas, managed retreat in others, and inland development for livelihoods)
#
# 1) What Strategy C entails (vision and components)
# - Core thrust: A calibrated mix of protection for critical nodes and high-value zones, targeted managed retreat in areas where protection is uneconomical, and inland development to host relocated populations and build new livelihoods. This approach seeks to preserve culture and place where feasible while reducing risk in the most vulnerable zones.
# - Immediate top priorities
#   - Map risk zones to distinguish pockets where protection is cost-effective vs. where retreat is more prudent.
#   - Protect core urban concentrations and key infrastructure; implement nature-based buffers where feasible.
#   - Begin staged, voluntary buyouts/relocation pilots for the deepest-risk zones; ensure fair compensation and social protections.
#   - Initiate inland development plans for housing and new livelihoods in areas with good access to markets, labor, and services.
#   - Invest in ecosystem restoration in both protected coastal zones and inland buffers to diversify resilience.
# - Medium term
#   - Expand targeted inland settlements; build resilient housing and services; link inland communities with coastal communities via transport and information networks; maintain cultural heritage and memory programs.
# - Longer term
#   - Maintain a flexible portfolio of protection and retreat; adjust the balance as climate science and costs evolve; ensure that the burden is shared equitably and that future generations have a say in how risk reduction is managed.
#
# 2) Assumptions and uncertainties specific to Strategy C
# - Assumptions
#   - A mixed approach can optimize risk reduction while moderating social disruption and cost; targeted protection can deliver protection where it matters most, and selective retreat can reduce overall exposure cost.
#   - Inland development can be designed to be economically viable and socially acceptable; land can be found and developed with manageable costs.
# - Key uncertainties
#   - Which zones are best protected vs. relocated? The determination could be contested by communities and interest groups.
#   - Costs of dual-path strategies (protection plus relocation) can be high; financing and governance need to be cohesive.
#   - Long-term maintenance costs for mixed defenses and inland settlements; potential reputational risk if decisions appear arbitrary.
# - Trade-offs
#   - Strategy C requires complex planning, coordination, and governance, with potential for slower decision-making but potentially more equitable outcomes.
#   - It aims to reduce both displacements and ecological losses while maintaining cultural integrity, but it can be more expensive and harder to manage than single-path strategies.
#
# 3) Projections (three futures) for Strategy C
# - HE projections
#   - Displacement: 15–28%.
#   GDP change: -18% to -9%.
#   Ecosystem loss: 20–40%.
#   Cumulative costs: $14–22B.
# - ME projections
#   - Displacement: 6–12%.
#   GDP change: -6% to -2%.
#   Ecosystem loss: 8–20%.
#   Cumulative costs: $9–15B.
# - LE projections
#   - Displacement: 1–3%.
#   GDP change: -1% to +1%.
#   Ecosystem loss: 2–10%.
#   Cumulative costs: $6–9B.
# - How these projections are derived
#   - Displacement: a portion of high-risk zones are protected, others shifted to inland settlements or relocated, with voluntary buyouts in the most exposed pockets.
#   - GDP: a combination of protected economic zones, inland development, and new livelihoods; import/export dynamics and service sectors adjust to mixed risk reduction.
#   - Ecosystems: protection in some zones preserves coastal ecosystems; inland buffers and restoration efforts contribute to resilience elsewhere.
#   - Costs: combination of protection investments, relocation/land acquisition in high-risk pockets, and inland development; include ongoing maintenance and social service provisioning.
# - Observations
#   - Strategy C offers a balanced, nuanced approach that can deliver substantial risk reductions while preserving culture and reducing outright displacement relative to Strategy B; it is more complex to implement but potentially more equitable and sustainable within budget constraints.
#
# 4) Monitoring, triggers, and adaptive schedule (Strategy C)
# - Monitoring metrics
#   - Same as Strategy A and B but with emphasis on hybrid zones: effectiveness of protected segments, uptake of relocation in targeted pockets, inland settlement occupancy, and cross-zone resource flows.
# - Decision triggers
#   - If protected zones start to show unsustainable maintenance costs or diminishing effectiveness, shift more population to relocation/inland development.
#   - If inland settlements fail to attract residents or create viable livelihoods, reassess the balance and possibly tilt toward increased protection or more aggressive inland development.
# - Adaptive update schedule
#   - Annual reviews; major reconfiguration at year 10, year 25, and year 40 to adjust the mix between protection, retreat, and inland development as conditions evolve.
#
# 5) Harms, mitigation, and governance (Strategy C)
# - Harms and distributional concerns
#   - Mixed outcomes across communities; potential perception of winners and losers depending on location (which zones are protected vs relocated).
#   - Cultural impacts for relocated communities; potential misalignment of inland livelihoods with traditional skills.
# - Mitigation and governance measures
#   - Inclusive, participatory planning for risk zoning; ensure transparent criteria for protection vs retreat; provide fair compensation where relocation occurs; support cultural continuity in inland settings (heritage centers, cultural programming, language preservation).
#   - Flexible housing and livelihood programs; cross-subsidies to ensure inland viability; ensure transport links to coastal areas for health, education, and cultural activities.
#   - Accountability measures and independent oversight to prevent capture of benefits by elites; gender-responsive budgeting; rights-based approach to land and housing.
#
# 6) Stress-testing and robustness (Strategy C)
# - Models and tests to run
#   - Integrated risk–economic models to examine how protection, retreat, and inland development interact financially and socially.
#   - Scenario analysis across HE/ME/LE to identify tipping points for decisions to shift portions of the plan from protection to retreat or vice versa.
#   - Cultural heritage retention and community cohesion metrics under different mixes of protection/relocation.
# - Counterfactuals
#   - Pure protection vs pure relocation vs no adaptation vs extreme skew of one component; measure social, economic, and ecological outcomes to refine the hybrid mix.
# - Why these tests are important
#   - They ensure the hybrid approach remains responsive to changing climate inputs and local preferences, preventing lock-in to suboptimal choices.
#
# 7) Confidence levels and data needs (Strategy C)
# - Confidence
#   - Moderate: the hybrid approach is plausible and potentially optimal, but its success heavily depends on precise zoning, financing, and governance performance.
# - Data needs
#   - Zoning criteria and risk maps at high resolution; cost curves for protection, retreat, and inland development; credible social acceptability assessments; and detailed inland land availability and infrastructure costs.
# - Confidence summary
#   - Moderate: success hinges on careful, transparent, and inclusive decision-making about where to protect vs retreat, and a robust inland development plan aligned to local markets.
#
# Cross-strategy synthesis and recommendation
# - Comparative assessment (A vs B vs C)
#   - Protection-first (A) minimizes displacement in the near term but carries the highest ongoing maintenance costs and residual risk, with substantial ecosystem reliance on performance of protection works.
#   - Relocation-first (B) offers clear risk reduction but at enormous social disruption and fiscal cost, with potential for reputational and governance challenges if not managed very carefully and inclusively.
#   - Hybrid (C) offers a principled compromise: targeted protection where cost-effective, selective retreat in the most exposed pockets, and inland development to create new livelihoods and housing opportunities, aiming to balance risk reduction, cultural continuity, and intergenerational equity.
# - Recommendation
#   - Strategy C (Hybrid) is the superior option under realistic political, economic, and ethical constraints for a small, low-lying island nation with a finite annual budget and a desire to preserve culture and livelihoods while reducing risk.
#   - Rationale:
#     - Risk reduction where protection is economically sensible, and retreat where protecting costs would be prohibitive and social disruption would be greatest. This minimizes the total number of people displaced while preserving urban cores and critical infrastructure.
#     - It aligns best with intergenerational equity by distributing risk and costs more evenly across current and future generations, rather than concentrating the burden on coastal communities alone.
#     - It allows for better governance and legitimacy through participatory zoning decisions, transparent risk-based criteria, and a clear pathway for communities to move or stay according to shared values and needs.
#     - It provides a more flexible financing pathway: protection investments can be pursued where feasible, while inland development and relocation can be staged and funded through a combination of national budgets and international finance; it also creates leverage for public-private partnerships focused on resilient inland industries.
# - Implementation outline for Strategy C (phased, feasible, equitable)
#   1) Phase 1 (years 0–5): establish governance, risk zoning, and community engagement; secure initial protections around critical hubs; pilot small inland development and relocation readiness in targeted pockets; begin ecosystem restoration and nature-based buffers; set up a transparent financing framework.
#   2) Phase 2 (years 5–15): expand protection in high-benefit zones; implement relocation pilots with voluntary participants; accelerate inland development in selected corridors; establish livelihood programs aligned with inland markets; implement monitoring and adaptive governance.
#   3) Phase 3 (years 15–30): scale up successful inland settlements; consolidate protected coastal zones; refine land-use planning to maintain cultural heritage and ensure adequate public services; monitor outcomes and adjust the mix between protection, retreat, and inland development.
#   4) Phase 4 (years 30–50): optimize the resilience portfolio as climate projections evolve; adjust protection costs, relocation rates, and inland development scales to maintain equity and fiscal viability; evaluate long-term outcomes and institutionalize adaptive governance.
#
# Key deliverables and decision-support needs (summary)
# - A risk zoning map classifying zones into three categories: protect, retreat, and inland development candidate zones; with explicit criteria (economic value, population density, cultural significance, ecosystem value, and protection feasibility).
# - A financing plan that sequences protection, relocation, and inland development with clear budget line items and triggers for escalation or re-prioritization; include contingent financing options (grants, concessional loans, catastrophe risk insurance, public-private partnerships).
# - A grievance redress mechanism and an equity framework to ensure fair treatment of vulnerable groups and transparent public participation.
# - A robust monitoring, evaluation, and adaptive-management framework that covers social, economic, ecological, and financial metrics, with clear triggers to pivot between A, B, and C components if needed.
#
# Data gaps to reduce critical uncertainties (priority)
# - High-resolution coastal topography, bathymetry, and SLR projections at sub-district scales; updated storm surge models aligned with local meteorology.
# - Detailed land ownership, housing stock, and building-stock vulnerability in coastal zones; housing and infrastructure costs for both protection and inland development.
# - Local knowledge on cultural heritage, place-based identity, and community preferences regarding protection versus retreat; gender-inclusive participation data.
# - Economic baselines for fisheries, tourism, and agriculture with scenario-based sensitivities to climate risk; inland market access and value chains for new livelihoods.
# - Financing scenarios: realistic debt-service capacity, external finance terms, and insurance/financial tools for resilience.
#
# Final note on projections and limitations
# - All quantitative projections (displacement, GDP change, ecosystem loss, cumulative costs) are best-which-if estimates under the three futures (HE, ME, LE) and three strategies, subject to the stated assumptions. They are sensitive to local specifics (costs of protection and relocation, land availability for inland settlements, community preferences, and governance quality).
# - Because this is a complex, long-horizon plan with many moving parts and uncertainties, it is essential to run the stress tests, adaptive management cycles, and phased implementations with robust stakeholder engagement and transparent reporting.
#
# If you would like, I can tailor the three strategies to a more granular, island-specific template (including a one-page costed plan for the first 10 years, a risk map, and a simple monitoring dashboard mock-up) using more precise local data you provide (topography, housing stock, current protected surface, and current external finance terms).
#
# # Response from competitor 2
#
# ## Executive Summary
#
# A 50‑year adaptation‑development roadmap for **Isla Verde** (pop. ≈ 350 k) is built around three “strategic families” that differ in how much they rely on **hard coastal protection** versus **planned retreat & relocation**. All three use the same **budget envelope** – a one‑off $3 bn start‑up fund plus $150 m yr⁻¹ (≈ $7.5 bn over 50 yr, discounted at 3 % → ≈ $5.2 bn NPV) – and the same **governance platform** (national Adaptation Steering Committee, local “Resilience Councils”, and an independent Monitoring‑Evaluation‑Learning unit).
#
# The **recommended approach** is **Strategy C – a hybrid, phased transition** that front‑loads protection for the most vulnerable core settlements while simultaneously investing in “managed retreat corridors” and “new‑town pilots”.  This delivers the highest **intergenerational equity** (protects children now, gives future generations the option to move), minimizes irreversible cultural loss, and stays within fiscal limits even under the worst‑case (RCP 8.5) sea‑level rise (SLR) trajectory.
#
# Below is the full technical package that underpins the recommendation.
#
# ---
#
# ## 1. Core Assumptions & Key Uncertainties
#
# | Category | Assumption (Base) | Reasoning / Source | Uncertainty Range | Effect on Plan |
# |----------|-------------------|--------------------|-------------------|----------------|
# | **Demography** | 2025 pop. = 350 k; growth 0.8 % yr⁻¹ (UN World Pop Prospects) | Small island, modest fertility, out‑migration | 0.4‑1.2 % yr⁻¹ | Determines future housing & labor pool |
# | **GDP** | 2025 GDP = $9 bn (≈ $25 k p.c.); annual real growth 2.5 % (World Bank) | Historical trend, tourism‑led | 1.5‑3.5 % yr⁻¹ | Influences fiscal capacity & cost‑benefit ratios |
# | **Sea‑Level Rise** | RCP 2.6: +0.6 m by 2100; RCP 4.5: +0.95 m; RCP 8.5: +1.6 m (IPCC AR6) | Global mean; local vertical land motion (VLM) –0.1 m/century (GPS) | ±0.1 m (VLM) ±0.2 m (model spread) | Drives timing/extent of inundation & protection design |
# | **Storm Surge & Cyclone Intensity** | Frequency unchanged; intensity +10 % per °C (IPCC) | Limited local historic record | ±5 % | Affects design wave height for dikes/sea walls |
# | **Land‑Use & Elevation Data** | 5 m DEM (LiDAR) with RMSE = 0.15 m | Recent national mapping campaign | ±0.2 m vertical error | Determines which zones are “protectable” |
# | **Migration Preference** | 70 % of households prefer to stay in place if protection offered; 30 % open to relocation (survey 2023) | Baseline social survey | 55‑85 % | Shapes size of relocation fund and timing |
# | **Construction Cost Index** | $2 500 m² for seawall; $1 200 m² for “living shoreline” (bio‑engineered) | Local contractor quotes; adjusted for inflation | ±15 % | Directly affects budget allocations |
# | **Ecosystem Service Valuation** | Mangrove carbon sequestration $25 t CO₂⁻¹; storm‑buffer value $3 bn yr⁻¹ for whole coast (FAO) | Global meta‑analyses, adjusted for local productivity | ±30 % | Influences cost‑benefit of nature‑based solutions |
#
# **Principal Unknowns that dominate risk**
#
# 1. **Actual SLR at the island’s shoreline** – local subsidence or uplift could add/subtract up to 0.2 m.
# 2. **Behavioural response to relocation incentives** – cultural attachment may be higher than surveys suggest, especially for sacred sites.
# 3. **Future tourism demand** – a 30 % swing changes revenue streams that could finance later phases.
# 4. **Global financing climate‑aid volatility** – potential for additional grants or loans (e.g., Green Climate Fund) is uncertain.
#
# ---
#
# ## 2. Trade‑offs & Opportunity Costs
#
# | Trade‑off | What is Gained | What is Foregone / Cost |
# |-----------|----------------|------------------------|
# | **Hard Protection vs. Retreat** | Immediate safety for existing settlements, preservation of current cultural sites, continuity of tourism infrastructure. | High capital outlay, lock‑in to a possibly unsustainable future, loss of opportunity to develop “climate‑resilient” new towns with better layout, higher long‑term maintenance. |
# | **Nature‑Based Solutions (NBS) vs. Grey Infrastructure** | Co‑benefits: carbon sequestration, fisheries nursery, tourism (eco‑tourism), lower upfront cost. | Larger land area needed; slower to reach design capacity; may be less effective against extreme storm surge if not combined with hard structures. |
# | **Centralised Relocation (one new “Capital‑Town”) vs. Distributed Small‑Scale Villages** | Economies of scale in service provision, stronger social cohesion in new town, easier to plan utilities. | Risk of creating a “single point of failure”, cultural disruption for dispersed communities, higher transport costs for remote island activities. |
# | **Early Investment in Data & Governance vs. Immediate Construction** | Better targeting, reduced mis‑allocation, higher community buy‑in, ability to adjust later. | Delays visible “protective” actions; may be politically unpopular if perceived as “inaction”. |
# | **Allocation to Housing vs. Livelihood Diversification** | Faster shelter for displaced families, reduces homelessness. | Missed chance to reduce exposure (e.g., shift from coastal fisheries to aquaculture, tourism‑service, renewable‑energy jobs). |
#
# **Opportunity Cost Calculations (illustrative)**
#
# *Assuming a $1 bn allocation to seawall construction (Scenario A) versus a $1 bn allocation to “green‑belt + relocation pilot” (Scenario C):*
#
# - **Scenario A**: Seawall protects 120 k people for 30 yr → avoided displacement cost $0.6 bn (average $10 k per person).
# - **Scenario C**: Relocation + mangrove restoration protects the same 120 k (through barrier effect) and adds ecosystem service value of $150 m yr⁻¹ → NPV ≈ $0.8 bn over 30 yr.
#
# Thus **C yields a higher net benefit** despite a slightly higher upfront capital need.
#
# ---
#
# ## 3. Quantitative Projections (50‑yr)
#
# ### 3.1 Modelling Framework
#
# 1. **Inundation Mapping** – GIS overlay of DEM + projected SLR (median + 10 % and 90 % quantiles) + storm‑surge envelopes (10‑yr, 100‑yr).
# 2. **Population Exposure** – Spatially disaggregate census to 100 m grids, apply exposure mask.
# 3. **Economic Damage Function** – Sector‑specific damage curves (tourism, fisheries, agriculture) calibrated to IPCC AR6 “damage functions” for small islands.
# 4. **Ecosystem Loss** – Habitat‑area loss (mangroves, coral reefs) multiplied by per‑ha ecosystem‑service values (carbon, storm protection, fisheries).
# 5. **Costing** – Engineering cost curves (per‑km seawall, per‑ha NBS), plus “relocation unit cost” ($45 k per household for land‑acquisition, housing, livelihood transition).
# 6. **Discounting** – 3 % real discount rate, sensitivity ±2 %.
#
# ### 3.2 Scenario Results (Tables)
#
# #### 3.2.1 Population Displacement (people)
#
# | Scenario | 2030 | 2040 | 2050 | 2060 | 2070 (cumulative) |
# |----------|------|------|------|------|-------------------|
# | **RCP 8.5** (high) – **Strategy A** (full protection) | 5 k | 12 k | 28 k | 68 k | 115 k |
# | **RCP 8.5** – **Strategy B** (full retreat) | 20 k | 55 k | 110 k | 180 k | 260 k |
# | **RCP 8.5** – **Strategy C** (hybrid) | 10 k | 25 k | 55 k | 90 k | 130 k |
# | **RCP 4.5** (medium) – **C** | 5 k | 12 k | 30 k | 55 k | 80 k |
# | **RCP 2.6** (low) – **C** | 2 k | 5 k | 12 k | 22 k | 30 k |
#
# *Derivation:* exposure mask → households → % that elect to move (scenario‑dependent).
#
# #### 3.2.2 GDP Change (relative to no‑adaptation baseline)
#
# | Scenario | 2030 | 2040 | 2050 | 2060 | 2070 |
# |----------|------|------|------|------|------|
# | **RCP 8.5 – A** | –0.4 % | –0.9 % | –1.8 % | –3.2 % | –5.5 % |
# | **RCP 8.5 – B** | –1.2 % | –3.0 % | –5.5 % | –8.0 % | –12 % |
# | **RCP 8.5 – C** | –0.6 % | –1.4 % | –2.5 % | –4.0 % | –6.5 % |
# | **RCP 4.5 – C** | –0.3 % | –0.8 % | –1.5 % | –2.5 % | –4.0 % |
# | **RCP 2.6 – C** | –0.2 % | –0.5 % | –1.0 % | –1.8 % | –2.5 % |
#
# *Method:* sector‑damage functions applied to baseline GDP growth path; adaptation actions generate “avoided loss” (e.g., protected tourism hotels).
#
# #### 3.2.3 Ecosystem Loss (ha)
#
# | Habitat | 2030 (baseline) | 2050 (RCP 8.5) | 2070 (RCP 8.5) |
# |---------|-----------------|----------------|----------------|
# | Mangroves | 4 500 | 3 800 (‑16 %) | 2 900 (‑36 %) |
# ...
# | **Coastal Inundation Extent (satellite + UAV)** | > 0.5 % of protected zone flooded during a 100‑yr storm event | Every 2 yr | Re‑evaluate seawall design height (add +0.5 m) |
# | **Housing Stock Condition Index** | < 0.7 (scale 0‑1) for > 30 % of homes in protected zone | Biennial | Deploy emergency retro‑fit funds (up to $20 m) |
# | **Livelihood Income Gap** | > 15 % deviation from baseline median income in at‑risk communities | Annual | Expand livelihood‑diversification package (micro‑grant + training) |
# | **Cultural Site Integrity** | Damage > 10 % of heritage‑site area (laser‑scan) | Annual | Immediate emergency preservation fund release ($5 m) |
# | **Ecosystem Service Index (Mangrove health, coral cover)** | Decline > 10 % over 5 yr | Every 5 yr | Scale up nature‑based restoration (additional $10 m) |
# | **Public Acceptance (survey)** | < 60 % support for current strategy | Every 5 yr | Convene “Resilience Council” to co‑design next phase; may shift share of funds to retreat |
#
# ### Adaptive‑Update Cycle
#
# | Year | Activity |
# |------|----------|
# | **0‑5** (Foundational) | Complete high‑resolution LiDAR mapping, baseline socioeconomic survey, establish national Adaptation Steering Committee, launch pilot “Living‑Shoreline” (2 km) and “Relocation‑Village” (1 km²) projects. |
# | **5‑10** | First formal *Mid‑Term Review* (MTR) – compare observed SLR & inundation against projections; re‑calibrate cost curves; adjust annual allocation split (Protection : Retreat : NBS) by ±10 % based on trigger outcomes. |
# | **10‑20** | Second MTR – evaluate performance of relocated communities (housing quality, livelihood outcomes). If > 20 % of pilot households report “unacceptable” outcomes, increase relocation budget by 15 % and re‑design settlement layout. |
# | **20‑30** | Third MTR – integrate new climate‑scenario updates (e.g., CMIP6 *SSP* pathways). If projected SLR exceeds 1.2 m (RCP 8.5) earlier than anticipated, fast‑track “Phase‑Out” of low‑lying zones (declare “no‑build” zones). |
# | **30‑40** | Fourth MTR – full‑scale evaluation of ecosystem‑service delivery; adjust nature‑based funding. |
# | **40‑50** | Final Review – decide on “post‑50‑yr” strategy (e.g., permanent relocation, or new‑generation protective tech). |
#
# All reviews are **public**, with stakeholder workshops and a transparent “decision‑log” posted online.
#
# ---
#
# ## 5. Moral, Social & Cultural Harms & Mitigation
#
# | Harm | Affected Group | Mitigation / Compensation | Governance Mechanism |
# |------|----------------|---------------------------|----------------------|
# | **Loss of ancestral burial sites** | Indigenous coastal clans | *Cultural Heritage Trust* – $30 m endowment; in‑situ preservation where possible; documentation & digital archiving. | Independent Heritage Oversight Board (mixed govt‑NGO‑clan). |
# | **Disproportionate displacement of low‑income households** | Poor fisher families | Means‑tested relocation vouchers (housing + start‑up cash) + guaranteed 5‑yr job placement in new‑town or renewable‑energy projects. | Social Justice Advisory Panel (annual audit). |
# | **Psychological stress & “climate‑anxiety”** | Entire population, especially youth | Community mental‑health hubs; school curricula on resilience; $2 m/yr mental‑health fund. | Ministry of Health–Climate‑Health Unit. |
# | **Erosion of community cohesion (fragmentation)** | Villages split by retreat corridors | Co‑design of new‑town public spaces that replicate traditional communal structures; “cultural continuity funds” to support festivals, language classes. | Resilience Councils (local elected) with veto power on settlement layout. |
# | **Inter‑generational inequity (future generations paying for today’s protection)** | Future taxpayers | Long‑term sovereign “Climate Adaptation Fund” (10 % of tourism tax) locked in a low‑risk bond; transparent reporting. | Parliamentary Oversight Committee. |
# | **Loss of ecosystem‑based livelihoods** | Mangrove‑dependent fishers | Transition grants for aquaculture certification; capacity‑building for eco‑tourism guiding; 15 % of NBS budget earmarked for livelihood‑linkage. | Fisheries‑Coastal Livelihood Board. |
#
# **Compensation principle:** *No‑loss* – anyone who loses land or cultural assets receives a package that at least equals market value plus a “cultural premium” (15 % uplift) and a guarantee of comparable or better housing.
#
# ---
#
# ## 6. Stress‑Testing & Simulation of Robustness
#
# | Model / Tool | Purpose | Counterfactual Tested | Why It Matters |
# |--------------|---------|-----------------------|----------------|
# | **Coastal Inundation Monte‑Carlo (CIMC)** | Propagate SLR, storm surge, tide‑gate failure uncertainties through GIS exposure model. | 1) SLR +0.2 m faster than median; 2) 100‑yr storm surge occurs twice as often. | Checks if protection thresholds are under‑designed. |
# | **Integrated Assessment Model (IAM) – MAgPIE / WITCH** | Link climate, economy, and policy to estimate GDP impacts under alternative adaptation mixes. | 1) Full retreat (100 % of at‑risk zone); 2) No adaptation. | Quantifies opportunity costs and validates damage functions. |
# | **Agent‑Based Relocation Model (ABRM)** | Simulate household decision‑making under varying incentives, social networks, and cultural ties. | 1) Incentive cut‑off reduced by 30 %; 2) Introduction of “clan‑based” relocation clusters. | Reveals tipping points for mass migration and possible social unrest. |
# | **Ecosystem Services Supply‑Demand Model (ESSDM)** | Evaluate how NBS, protection, and land‑use change affect carbon, fisheries, and storm buffering. | 1) 50 % of mangroves lost before restoration; 2) Coral bleaching accelerates to 80 % loss. | Determines resilience of nature‑based components. |
# | **Financial Sustainability Stress Test** | Run cash‑flow projection under varied discount rates (2‑5 %), aid‑flow shocks (±50 %), and inflation spikes. | 1) Global aid freezes for 5 yr; 2) Inflation spikes to 6 %/yr. | Ensures plan does not collapse financially. |
#
# *Outcome:* All three strategies pass a **70 % probability** of staying within the $5.2 bn NPV budget under high‑emission SLR, but **Strategy C** shows the **lowest sensitivity** to adverse climate “tails” (e.g., earlier storm surge) because it diversifies risk across protection, retreat, and ecosystem buffers.
#
# ---
#
# ## 7. Confidence Levels & Data Gaps (per Strategy)
#
# | Element | Strategy A (Protection‑Only) | Strategy B (Retreat‑Only) | Strategy C (Hybrid) | Confidence (High/Med/Low) | Data that would raise confidence |
# |--------|------------------------------|---------------------------|----------------------|---------------------------|-----------------------------------|
# | **SLR projection (local)** | Medium (depends on VLM) | Medium | Medium | **Medium** | Continuous GPS/VLM network (5‑yr series). |
# | **Cost of seawall per km** | High (local contractor bids) | Low (no data) | High (same as A) | **High** | Updated cost database post‑first 10 km build. |
# | **Relocation household cost** | Low (pilot limited) | Medium (pilot data) | Medium | **Medium** | Full household‑level cost‑benefit survey after 2 pilot villages. |
# | **Ecosystem service valuation** | Low (global averages) | Medium (field measurements) | High (combined field + remote) | **Medium** | Local mangrove carbon stock and storm‑buffer field experiments. |
# | **Social acceptance** | Low (no baseline) | Medium (focus groups) | High (ongoing council) | **Medium** | Annual, disaggregated perception surveys (by age, clan). |
# | **Economic damage functions** | Medium (regional IPCC) | High (regional calibrations) | High (both) | **High** | Island‑specific GDP‑by‑sector vulnerability study. |
# | **Governance capacity to deliver relocation** | Low | Medium | High | **Medium** | Institutional audit of land‑acquisition processes. |
# | **Long‑term fiscal sustainability** | Medium | Low | High | **High** | Real‑time tracking of tourism tax revenue and climate‑aid inflows. |
#
# *Overall, the hybrid Strategy C enjoys the highest aggregate confidence (≈ 75 % of elements rated “high” or “medium”), while Strategy A suffers from low confidence in social‑acceptance and long‑term fiscal risk, and Strategy B from high engineering uncertainty and higher economic disruption.*
#
# ---
#
# ## 8. Three Alternative Strategies (Detail)
#
# ### **Strategy A – “Protect‑in‑Place”**
#
# | Phase (Year) | Activity | % of annual $150 m budget |
# |--------------|----------|----------------------------|
# | 0‑5 | Island‑wide “hard” seawall (20 km total) + surge gates; upgrade critical infrastructure (hospitals, power). | 70 % |
# | 5‑15 | Maintenance & elevation of existing housing (raise 0.5‑1 m). | 20 % |
# | 15‑30 | Add “living‑shoreline” buffers where seawall not feasible. | 10 % |
# | 30‑50 | Small‑scale relocation of the **most** exposed 5 % (voluntary) – only if seawall fails. | 5 % |
#
# **Pros:** Immediate visual protection, preserves cultural sites, supports tourism continuity.
# **Cons:** High upfront cost; lock‑in to a moving target; limited flexibility; risk of “maladaptation” if SLR exceeds design height.
#
# **Projected Outcomes (high‑emissions):** 115 k displaced, –5.5 % GDP by 2070, ecosystem loss > 35 % (mangroves, reefs).
#
# ---
#
# ### **Strategy B – “Managed Retreat”**
#
# | Phase (Year) | Activity | % of annual $150 m budget |
# |--------------|----------|----------------------------|
# | 0‑5 | Land‑acquisition for two new inland towns (10 km² each); legal frameworks; initial community engagement. | 30 % |
# | 5‑15 | Construction of “relocation villages” (modular, climate‑proof housing) + livelihood transition grants. | 50 % |
# | 15‑30 | Systematic “buy‑back” of low‑lying properties; demolition; ecosystem restoration of vacated shoreline. | 15 % |
# | 30‑50 | Continue incremental expansion of inland towns; de‑commissioned seawalls turned into public promenades. | 5 % |
#
# **Pros:** Avoids perpetual maintenance; opens space for nature‑based buffers; reduces long‑term exposure.
# **Cons:** Large social disruption, high relocation compensation, potential loss of heritage sites, requires robust land‑use planning.
#
# **Projected Outcomes (high‑emissions):** 260 k displaced (voluntary + forced), –12 % GDP, ecosystem loss > 45 % (if restoration delayed).
#
# ---
#
# ### **Strategy C – “Hybrid Phased Transition”**
#
# | Phase (Year) | Activity | % of annual $150 m budget |
# |--------------|----------|----------------------------|
# | **0‑5** | **Data foundation** (LiDAR, VLM, socioeconomic baseline). <br> **Pilot 2‑km “Living‑Shoreline”** (mangrove + oyster reef). <br> **Pilot relocation village** (1 km²). | 20 % |
# | **5‑15** | **Coastal protection**: seawall for high‑value zones (≈ 8 km) + surge gates. <br> **Expand NBS**: 1 000 ha mangrove restoration. <br> **Scale relocation**: additional 3 villages (total 4 km²). | 40 % |
# | **15‑30** | **Transition zone**: “no‑build” policy for zones < 2 m AMSL; convert to **green buffer** (agro‑forestry, eco‑tourism). <br> **Upgrade inland towns**: utilities, schools, health. <br> **Livelihood diversification**: renewable‑energy training, climate‑smart fisheries. | 30 % |
# | **30‑50** | **Full‑scale relocation** of remaining < 2 m zones (≈ 15 % of land) – voluntary, with guaranteed housing in new‑towns. <br> **Maintain & upgrade existing protection** (height +0.5 m). <br> **Long‑term ecosystem stewardship fund** (endowed). | 10 % |
#
# **Key Features**
#
# * **Dynamic allocation** – the % split can shift ±10 % after each 5‑yr monitoring checkpoint.
# * **Cultural‑heritage “seed‑lots”** – every relocated community receives a *cultural hub* that houses artefacts, oral‑history archives, and a community‑run museum.
# * **Ecosystem‑service “insurance”** – restored mangroves generate a **$3 m yr⁻¹ credit** (storm buffer) that is fed back to the Adaptation Fund.
#
# **Projected Outcomes (high‑emissions):** 130 k displaced, –6.5 % GDP, ecosystem loss limited to 30 % (due to early NBS).
#
# ---
#
# ## 9. Recommendation – Adopt **Strategy C (Hybrid)**
#
# ### Why C Beats A & B
#
# | Criterion | Strategy A | Strategy B | Strategy C |
# |-----------|------------|------------|------------|
# | **Risk of Over‑Investment** | High (seawall may be overtopped) | High (relocation may exceed budget) | Balanced – early protection where cost‑effective, retreat where inevitable |
# | **Cultural Preservation** | Strong for current sites, weak for future identity | Weak (large‑scale displacement) | Strong – retains core heritage sites *and* creates new cultural hubs |
# | **Economic Resilience** | Moderate (tourism preserved, but high maintenance) | Low (short‑term disruption to tourism) | High – diversified livelihoods, NBS provides storm‑buffer savings |
# | **Fiscal Sustainability** | High O&M costs → risk of budget overruns | Large one‑off relocation payouts → cash‑flow stress | Spreads cost across 50 yr, leverages ecosystem credits, uses modest annual spend |
# | **Social Equity** | Low – benefits concentrate on wealthier coastal owners | Medium – relocation funds may be insufficient for poorest | High – means‑tested vouchers, participatory planning, targeted livelihood packages |
# | **Flexibility to Emissions Scenarios** | Rigid – design based on single SLR assumption | Rigid – full retreat locked in early | Adaptive – can upscale protection or retreat as triggers fire |
# | **Implementation Feasibility (Political)** | Easy to sell “protect now” narrative | Politically sensitive (forced moves) | Moderately complex but built on **co‑design** mechanisms that build legitimacy |
#
# ### Ethical & Political Viability
#
# * **Procedural Justice** – the hybrid plan embeds **local Resilience Councils** with decision‑making power, satisfying the island’s strong clan‑based governance traditions.
# * **Distributive Justice** – means‑tested compensation ensures the poorest are not left behind.
# * **Inter‑generational Justice** – the plan locks in an **endowment** (tourism tax + climate‑aid) that funds future generations, avoiding “debt‑building” for adaptation.
#
# ### Implementation Timeline (Key Milestones)
#
# | Year | Milestone |
# |------|-----------|
# | 0‑2 | Establish Adaptation Steering Committee; finalize budget law; start LiDAR & VLM network. |
# | 2‑5 | Build first 2 km living‑shoreline; launch pilot relocation village; enact “no‑build” zoning for < 0.5 m AMSL. |
# | 5‑10 | Complete 8 km seawall around high‑value core (capital, main airport). |
# | 10‑15 | Expand mangrove restoration to 1 000 ha; open second relocation village. |
# | 15‑20 | Declare “green‑buffer” zone (2‑4 m AMSL) – convert to agro‑forestry & eco‑tourism. |
# | 20‑30 | Relocate 30 % of at‑risk households (voluntary); finish inland‑town utilities. |
# | 30‑40 | Raise seawall +0.5 m (climate‑adaptive design). |
# | 40‑50 | Complete relocation of remaining < 2 m zones; transition to maintenance phase; evaluate post‑50‑yr pathway. |
#
# ---
#
# ## 10. Closing Note
#
# The hybrid Strategy C **maximizes the net social, economic, and ecological return** on the $3 bn + $150 m yr⁻¹ budget while respecting the island’s cultural fabric and the rights of future generations. It is **robust** to the three emissions pathways, **adaptive** to emerging science, and **governance‑ready** through participatory institutions.
#
# **Next steps for the government**
#
# 1. **Ratify the Adaptation Steering Committee** (legislative act).
# 2. **Secure the $3 bn start‑up fund** (mix of sovereign bonds, climate‑aid, and a modest tourism levy).
# 3. **Commission the baseline data package** (LiDAR, VLM, socio‑economic surveys) – this will lift confidence from *medium* to *high* on most model inputs.
# 4. **Launch the first 2‑km living‑shoreline pilot** – a tangible “quick‑win” that demonstrates commitment and creates early ecosystem credits.
#
# With these actions, Isla Verde can navigate the next half‑century of sea‑level rise without sacrificing its people, culture, or natural heritage.

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}
After the JSON response, include a brief explanation of your rankings.

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 2 competitors.
# Each model has been given this question:
#
# Imagine you are advising the government of a low-lying island nation of 350,000 people that faces an expected 1.5–2.0 m sea-level rise within 80 years; the government has an immediate one-time budget of $3 billion and can commit up to $150 million per year thereafter. Propose a detailed, prioritized 50-year climate adaptation and development plan that balances coastal protection, managed retreat, housing, livelihoods, cultural preservation, ecosystem services, and intergenerational equity — and for that plan: (1) clearly state and justify your assumptions and the main uncertainties; (2) explain the key trade-offs and opportunity costs behind your priorities; (3) provide quantitative projections (with ranges) for population displacement, GDP change, ecosystem loss, and cumulative costs under three scenarios (high-, medium-, and low-emissions) and describe how those projections were derived; (4) specify monitoring metrics, decision triggers, and an adaptive-update schedule for when and how to change course; (5) identify potential moral, social, and cultural harms (including distributional harms) and propose concrete mitigation, compensation, and governance mechanisms to address them; (6) describe how you would stress-test and simulate the robustness of the plan (what models or counterfactuals you would run and why); and (7) provide a confidence level for each major element and list the specific additional data that would most reduce critical uncertainties — do this for three alternative strategies (A: prioritize protection and in-place adaptation; B: prioritize large-scale, planned relocation; C: a hybrid approach), then recommend one strategy, explaining in detail why it is superior to the other two under realistic political, economic, and ethical constraints?
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
# After the JSON response, include a brief explanation of your rankings.
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# Below is a structured, policy-relevant planning package you can adapt for a small, low-lying island nation with about 350,000 people. It is organized in three alternative strategies (A, B, C) plus a final recommendation. It is intentionally stated with explicit assumptions, uncertainties, trade-offs, and quantitative projections to aid decision-making under financial constraints (one-time $3B upfront; up to $150M/year thereafter) and long-term climate risk.
#
# Executive context and core assumptions (common to all three strategies)
# - Physical and demographic context
#   - Population: ~350,000 people; urbanization concentrated in a few coastal towns and the main port/airstrip area; a substantial share lives in hazard-prone coastal/low-lying zones.
#   - Land area and topography: predominantly low-lying, with limited high-ground refuges; subsurface freshwater lens vulnerable to saltwater intrusion; mangrove and reef ecosystems present in many coastal zones.
#   - Economy today (illustrative): real GDP around $3.0–3.5B/year; GDP per capita roughly $8,000–12,000; key sectors include fisheries, tourism (eco- and small-scale), agro-exports, services, and ports/logistics.
# - Climate and risk context
#   - Sea-level rise: plausible range of 1.5–2.0 m SLR by about 80 years (roughly 2080–2100), with continued but slower rise beyond; storm intensity and duration are expected to increase; coastal erosion and freshwater intrusion will intensify.
#   - Emissions scenarios used here (three clearly distinct futures):
#     - High-emissions (HE): akin to RCP8.5/SSP5 – higher atmospheric CO2, faster SLR and more frequent/intense extreme events.
#     - Medium-emissions (ME): akin to RCP4.5/SSP2 – moderate SLR and climate impacts.
#     - Low-emissions (LE): akin to RCP2.6/SSP1 – slower SLR and fewer climate shocks.
# - Economic planning constraints
#   - One-time budget: $3 billion upfront.
#   - Ongoing public budget: up to $150 million/year (undiscouraged annual cap; assumes debt capacity and macro stability permit roughly this magnitude).
#   - External finance and private finance would be necessary to fully realize more ambitious components; the plan focuses on what is feasible with the stated fiscal envelope and a prudent level of leverage.
# - Core planning principles
#   - Balance protection, managed retreat, housing, livelihoods, cultural preservation, ecosystem services, and intergenerational equity.
#   - Emphasize local governance, participatory planning, fairness, transparency, and respect for land rights and cultural heritage.
#   - Monitoring, adaptive management, and explicit decision triggers to adjust course as conditions evolve.
#
# Strategy A: Prioritize protection and in-place adaptation (coastal protection first, with limited managed retreat)
#
# 1) What Strategy A entails (vision and components)
# - Core thrust: Build and maintain coastal defenses and nature-based buffers to protect most critical assets and housing in major urban centers for as long as feasible; combine hard infrastructure with ecosystem-based protection (mangrove restoration, coral reef augmentation, dune and wetland rehabilitation).
# - Immediate top priorities (first 5–10 years)
#   - Protect the most exposed population hubs (capital/port, hospital clusters, water security).
#   - Construct seawalls and tide barriers where cost-effective; shore up flood defenses in key basins; reinforce critical road/bridge networks.
#   - Restore and conserve coastal ecosystems (mangroves, tidal wetlands, coral fragments, reef crest restoration) to improve natural attenuation of wave energy and storm surge.
#   - Improve freshwater security (desalination capacity, groundwater management, rainwater harvesting) to mitigate saltwater intrusion in protected zones.
#   - Strengthen land-use planning to minimize new construction in high-risk zones; implement strict building codes for resilience.
# - Medium term (10–30 years)
#   - Expand nature-based buffers (mangroves and reefs) to further reduce wave energy and storm impact.
#   - Upgrade protection around critical infrastructure (airport/port facilities, power generation, water facilities).
#   - Pilot buyouts/compensation for the most at-risk, non-densely populated zones where protection is no longer feasible within cost constraints.
# - Longer term (30–50 years)
#   - Maintain or upgrade protection where possible; if risk exposure remains high and protection costs escalate, intensify managed retreat in the most exposed areas in a fair, orderly, community-led manner.
#   - Ensure housing and livelihoods continue with access to basic services, while shifting some development inland or to higher ground where feasible.
#
# 2) Assumptions and uncertainties specific to Strategy A
# - Assumptions
#   - A robust system of coastal protection can extend life of urbanized coastline for several decades at a moderate to high cost, especially with Nature-Based Solutions (NBS) leveraged alongside engineered barriers.
#   - A subset of high-risk areas (incentivized by value at risk) can be protected with a combination of hard infrastructure and NBS without full-scale relocation.
#   - Ecosystem services (coastal protection, fisheries productivity, tourism appeal) will continue to be valuable and partly enhanced by restoration.
# - Key uncertainties
#   - The effectiveness and maintenance costs of seaward/landward protections under extreme events and higher-than-expected SLR.
#   - The precise pace of SLR and rates of erosion in different micro-regions; freshwater lens dynamics under protection and intrusion effects.
#   - Costs and reliability of large-scale ecosystem restoration; success rates of mangrove/reef interventions given climate stressors.
#   - Long-run fiscal sustainability given ongoing maintenance, debt service, and potential macroeconomic shocks.
#   - Social acceptability and equity of continuing in-place protection at the expense of some areas with limited protection options.
#
# 3) Projections (three climate/emissions futures) for Strategy A (displacement, GDP, ecosystem loss, cumulative costs)
# - Assumptions for projections
#   - Baseline GDP today: ~$3.5B; population 350k; baseline growth assumption 1.5–2.5% real per year absent climate stress or policy constraints.
#   - "50-year" horizon (to 2070–2075) with discounting for present-value comparisons.
#   - Displacement means permanent relocation where protection fails or where protection costs exceed benefits; temporary displacement and out-migration are captured as transient effects, not permanent relocation unless specified.
# - HE (High-emissions) projections (Strategy A)
#   - Population displacement by year 50: 18–28% (63k–98k people permanently displaced from the most exposed zones), with most relocations concentrated near the urban cores facing ongoing erosion and inundation pressure.
#   - GDP change over 50 years: -20% to -12% relative to baseline (cumulative real GDP loss, accounting for protection expenditures, maintenance, and reduced growth in exposed zones).
#   - Ecosystem loss: 25–55% of high-value coastal ecosystems (mangroves, coral, estuarine habitats) in exposed shorelines degraded or lost; some recovery possible in less-impacted zones.
#   - Cumulative adaptation costs (governmental, domestic): $13–18B (net present value, including upfront and ongoing protection maintenance); additional non-protection capital expenditures (housing in protected zones, water security) add further but are partially funded by budget allocations.
# - ME (Medium-emissions) projections
#   - Displacement: 6–12%.
#   - GDP change: -8% to -4%.
#   - Ecosystem loss: 12–28%.
#   - Cumulative costs: $9–13B.
# - LE (Low-emissions) projections
#   - Displacement: 1–4%.
#   - GDP change: -2% to +2% (near-stable growth with protection benefits).
#   - Ecosystem loss: 3–15%.
#   - Cumulative costs: $6–9B.
# - How these projections are derived (brief rationale)
#   - Displacement: derived from exposure of dense population to remaining risk after protection; factor in limits of protection life-cycle costs; assume an orderly, finite area remains protected; higher SLR and storms increase residual risk.
#   - GDP: combine baseline growth trajectory with climate damages to ports, tourism, fisheries; subtract protection costs and residual loss of output in exposed zones; assume some spillovers to national economy; project with simple scenario-adjusted multipliers.
#   - Ecosystems: use typical loss curves for mangroves/reefs under SLR and storm exposure; protection and restoration offset some loss but not all under HE; lower loss in LE due to slower SLR and fewer extreme events.
#   - Costs: sum of upfront protection investments, ongoing maintenance, ecological restoration, land-use planning, and limited relocation payments in zones where protection is deemed infeasible.
# - Observations
#   - Strategy A offers the lowest displacement relative to the other two strategies in HE among the three, but still involves non-trivial displacement and substantial cumulative costs.
#   - This strategy prioritizes staying in place for as many people as possible but relies heavily on expensive, ongoing maintenance and robust ecosystem performance.
#
# 4) Monitoring, decision triggers, and adaptive update schedule (Strategy A)
# - Monitoring metrics (annual/quarterly cadence)
#   - Physical: shoreline retreat rates; SLR measurements; coastal erosion rates; groundwater salinity; reef/mangrove health indices; protection structure integrity; rainfall and flood depth.
#   - Social/economic: population distribution in hazard zones; housing occupancy in protected zones; displacement approvals; infrastructure uptime; GDP contributions from protected vs. unprotected zones; employment in fisheries/tisheries-dependent sectors.
#   - Governance/finance: protection maintenance costs; debt service coverage; funding gaps; service delivery in impacted communities.
# - Decision triggers (predefined thresholds)
#   - If protected zone erosion rate exceeds X meters/year for two consecutive years, escalate protection retrofit program, reassess cost-benefit, or switch to relocation for subzones.
#   - If cumulative displacement approaches 20% of population or housing stock in risk zones with no feasible protection alternatives, trigger a staged managed retreat pilot for targeted subzones.
#   - If maintenance costs exceed scheduled budget by more than Y% for two consecutive years, reassess mix of hard vs. nature-based protection and adjust project scope or funding sources.
#   - If ecosystem services (coastal protection, fisheries yield, tourism potential) decline beyond a threshold, accelerate restoration investments and adjust land-use policies.
# - Adaptive-update schedule
#   - Annual review for performance against targets; mid-term formal re-forecast at year 10; comprehensive plan reset at year 20 and year 40 with updated SLR data, new cost estimates, and updated social equity assessments.
#   - Implement a formal “adaptive management” board including local communities, civil society, coastal engineers, and economic planners to decide on pivots (e.g., scaling back or accelerating relocation components).
#
# 5) Potential harms, mitigation, compensation, and governance (Strategy A)
# - Potential harms and distributional risks
#   - Social inequities: wealthier urban residents may benefit from protection while poorer households in peripheral zones face higher risk or forced relocation; risk of unequal access to protected areas.
#   - Cultural harms: erosion of place-based identity in protected zones if communities are displaced; potential loss of cultural heritage linked to protected coasts.
#   - Procedural harms: perceived top-down decision-making; limited local voice in long-term protection siting.
# - Mitigation and governance mechanisms
#   - Community-led siting and planning: incorporate local knowledge in where to place protective works; ensure informed consent for protection vs. retreat in different zones.
#   - Fair compensation and social safety nets: transparent buyouts or relocation assistance; long-term housing assistance in new locations; employment retraining and wage support for workers transitioning from affected sectors (fisheries, tourism).
#   - Cultural preservation measures: designate cultural heritage zones; fund preservation of sites and artifacts; support diaspora engagement and return programs; document oral histories and place-based narratives before relocation.
#   - Governance safeguards: anti-corruption measures, participatory budgeting for risk reduction funds, third-party audits, transparent procurement for protection works.
#   - Equity mechanisms: ensure priority access to subsidized housing and employment for vulnerable communities; create a floor of participation in planning for marginalized groups, including women, elderly, and indigenous/community landowners.
# - Governance architecture
#   - A dedicated Coastal Resilience Authority or inter-ministerial committee with community representation; a protected budget line for adaptation and relocation programs; an independent ombudsperson for grievance redress.
#
# 6) Stress-testing and robustness (Strategy A)
# - Models, counterfactuals, and tests to run
#   - Climate-impacts models: simulate SLR, storm surge, and erosion under HE/ME/LE scenarios; calibrate with local tide gauge data and bathymetry; couple with groundwater intrusion models.
#   - Economic impact models: macroeconomic projections with climate-adjusted productivity multipliers; test sensitivity to tourism shocks, fisheries productivity, and port disruptions.
#   - Population displacement models: agent-based or microsimulation models to estimate migration patterns under protection decisions; factor in housing supply constraints and costs.
#   - Ecosystem and service models: coastal protection capacity from mangroves/reefs; determine thresholds beyond which protection is no longer cost-effective.
#   - Financial stress tests: evaluate debt service burden under various external financing scenarios; assess fiscal resilience under shocks to tourism or fisheries.
# - Counterfactuals to consider
#   - No adaptation: baseline trajectory without new protection; examine rapid losses in urban cores and high displacement.
#   - Aggressive protection investment: evaluate if cost escalations threaten fiscal sustainability; test different maintenance funding mixes.
#   - Rapid relocation: examine social disruption costs, housing market dynamics, and governance challenges if relocation is accelerated beyond plan.
# - Why these models matter
#   - They reveal tipping points, help avoid overspending on protection where it is not cost-effective, and ensure equity by exposing who bears costs and who gains benefits.
#
# 7) Confidence levels and data gaps (Strategy A)
# - Confidence levels (qualitative)
#   - Assumptions about SLR ranges and storm intensities: Medium–High (data-informed but uncertain at local scale).
#   - Protection performance and maintenance costs: Medium (depends on engineering choices, local climate adaptiveness, and governance).
#   - Social equity and compensation effectiveness: Medium–Low (depends on governance quality and community engagement).
# - Data needs to reduce critical uncertainties (highest priority)
#   - High-resolution topography and bathymetry for risk zoning; detailed land ownership and housing stock data; current and projected coastal ecosystem health and linkages to protection effectiveness.
#   - Localized costs and maintenance requirements for specific protection structures (material lifespans, replacement cycles, labor costs).
#   - Detailed microeconomics of fisheries, tourism, and agriculture to quantify sectoral vulnerabilities and adaptation benefits.
#   - Socio-cultural baselines: community mapping of cultural heritage sites, language, and place-based identities; mechanisms for inclusive decision-making.
# - Confidence summary
#   - Overall plan confidence: Medium. The direction is plausible, but precise costs, displacement magnitudes, and ecosystem outcomes depend on local technology choices, governance, financing, and ecological responses.
#
# Strategy B: Prioritize large-scale, planned relocation (all at-risk communities move to higher ground or inland settlements with new housing and infrastructure)
#
# 1) What Strategy B entails (vision and components)
# - Core thrust: Proactively relocate a substantial portion of the population from the most exposed coastal zones to well-planned inland or higher-ground settlements designed for resilience and social cohesion; build new housing, jobs, health and education facilities, and community services in strategically chosen inland zones.
# - Immediate top priorities (first 5–10 years)
#   - Identify inland settlement corridors and acquire land for housing and public facilities with clear tenure policies; establish a phased relocation plan to minimize disruption.
#   - Build new housing stock and necessary infrastructure (schools, clinics, water, electricity) to absorb relocated populations.
#   - Create economic zones and livelihoods in inland areas (processing facilities for fisheries products, agro-processing, tourism circuits, remote work hubs).
#   - Establish social protection and retraining programs for those leaving coastal livelihoods; preserve cultural sites and practices in a way that can adapt to inland settings.
# - Medium term (10–30 years)
#   - Expand inland urban cores, ensure adequate housing, and integrate essential services; ensure relocation is voluntary, culturally sensitive, and equitable.
#   - Develop new livelihoods tied to inland resilience (agribusiness, aquaculture in inland basins, ecotourism with new access routes).
# - Longer term (30–50 years)
#   - Consolidate inland populations; maintain a protective but smaller coastal boundary where feasible and cost-effective; monitor ecosystem services holistically across the archipelago to sustain fisheries and tourism in origin areas through repurposing or compensation.
#   - Adjust governance and policy to ensure ongoing social equity across generations and avoid intergenerational burdens.
#
# 2) Assumptions and uncertainties specific to Strategy B
# - Assumptions
#   - A substantial portion of coastal residents can be resettled with adequate housing, services, and livelihoods; inland zones can be developed with lower disaster risk and with a pathway to economic viability.
#   - Land acquisition and relocation is politically acceptable with transparent compensation; housing will be affordable for current residents; social cohesion can be maintained.
# - Key uncertainties
#   - Social acceptance: willingness of communities to move, maintain cultural identity, and adjust livelihoods.
#   - Land availability and price for inland settlements; potential ecological or biodiversity trade-offs in inland zones.
#   - Financing: relocation costs (house construction, infrastructure, new services) and ongoing operating expenses; potential need for substantial international finance.
#   - Governance: risk of contested claims to land, land rights, and potential inequities in prioritization.
#   - Economic transition: ability to create inland livelihoods that match prior coastal benefits; potential for dependency on external aid or volatile tourism demand.
# - Trade-offs
#   - Strong relocation reduces exposure and physical risk but creates substantial social and cultural disruption and requires large fiscal resources and governance capacity.
#   - Protection in place preserves place-based identity and traditional livelihoods but may be financially onerous and leaves some risk of future displacement if protection fails.
#   - A large relocation effort can deliver predictable risk reduction but may erode intergenerational equity if not designed with fair compensation and inclusive governance.
#
# 3) Projections (three futures) for Strategy B
# - HE projections
#   - Displacement: 40–60% of population relocated by year 50.
#   GDP change: -25% to -40% (strong short- to medium-term disruption; higher relocation costs and new inland economic base needed).
#   Ecosystem loss: 40–70% of coastal ecosystem services lost as coastal communities depopulate and protection declines; inland ecosystems may be affected by new development footprints.
#   Cumulative costs: $22–35B (strong upfront relocation and new inland infrastructure plus ongoing support); funding gap likely large without substantial external support.
# - ME projections
#   - Displacement: 18–40%.
#   GDP change: -12% to -25%.
#   Ecosystem loss: 20–40%.
#   Cumulative costs: $12–22B.
# - LE projections
#   - Displacement: 5–15%.
#   GDP change: -3% to -10%.
#   Ecosystem loss: 5–20%.
#   Cumulative costs: $8–12B.
# - How these projections are derived
#   - Displacement: scaled to share of population relocated; assume inland settlements can absorb population with adequate planning; incorporate costs of housing procurement, infrastructure, and social services.
#   - GDP: reflect cost of relocation, new inland economic activity, potential short-term substitution effects in fisheries/tourism, and capital-intensive inland development with slower initial returns.
#   - Ecosystems: reflect loss of coastal ecosystems due to depopulation of coastal zones, plus new inland ecosystem considerations (e.g., land-use change, water management).
#   - Costs: sum of land acquisition, housing construction, inland infrastructure, social support, and long-term maintenance; assume substantial financing from international lenders and private investment, but subject to debt sustainability constraints.
# - Observations
#   - Strategy B yields the most rapid risk reduction for exposed populations but is the most expensive and potentially disruptive; it emphasizes intergenerational equity through relocation but at high social and political costs.
#
# 4) Monitoring, triggers, adaptive schedule (Strategy B)
# - Monitoring metrics
#   - Population relocation progress; inland settlement occupancy; housing and service delivery metrics; local economy performance in inland zones; social cohesion and cultural continuity indicators.
#   - Fiscal: relocation expenditure vs. budget; debt burden and financing progress; insurance and disaster risk transfer uptake.
# - Decision triggers
#   - If relocation pace stalls or equity gaps arise (e.g., marginalized groups left behind), escalate targeted support and revise prioritization; if land acquisition costs exceed thresholds, adjust sequencing.
#   - If inland livelihoods fail to achieve expected outcomes after pilot phases, adjust economic development plans, retrain workers, or consider partial reintegration of certain coastal communities with protection in critical zones.
# - Adaptive update schedule
#   - Annual progress reviews; formal mid-course corrections every 5–10 years; comprehensive plan reassessments at year 20 and 40 to align with climate projections and economic trajectories.
#
# 5) Harms, mitigation, and governance (Strategy B)
# - Harms and distributional concerns
#   - Loss of place-based identity and social networks; potential stigmatization of relocated communities; intergenerational tensions about who bears the relocation burden.
#   - Land-use disputes, property rights, and governance legitimacy challenges in inland sites.
#   - Potential disruption of coastal cultural heritage and rituals tied to the sea.
# - Mitigation and governance measures
#   - Co-design relocation with communities; ensure voluntary participation with robust consent processes; protect cultural heritage in inland settings; provide options to preserve ties to origin communities (e.g., ceremonial access, returns for special events).
#   - Fair and transparent compensation schemes; enforce clear tenure rights in inland settlements; provide lifelong housing subsidies, healthcare, education access, and retraining programs.
#   - Establish memorials or cultural centers that document and celebrate coastal heritage; invest in diaspora engagement and cross-site cultural programs.
#   - Governance: independent grievance mechanisms; participatory budgeting for relocation funds; anti-corruption safeguards; ensure gender-sensitive planning and representation.
#
# 6) Stress-testing and robustness (Strategy B)
# - Models and tests to run
#   - Relocation feasibility models: housing supply, land acquisition timelines, social services capacity, and intra-island transport and access.
#   - Economic transition models: inland economic base viability, return on investment in inland industries, potential for export-oriented activities.
#   - Social resilience models: social cohesion, mental health and well-being in relocated populations, intergenerational dynamics.
#   - Financing models: debt sustainability under large upfront costs; sensitivity to external financing terms and macroeconomic shocks.
# - Counterfactuals
#   - No relocation (protection-only path). Extreme risk if protection fails or costs escalate.
#   - Accelerated relocation beyond plan, with potential social disruption.
#   - Gradual relocation with a phased approach but slower rollout, testing social acceptance before expansion.
# - Why these tests matter
#   - They guide prudent pacing, safeguard social equity, and help avoid pushing communities into irreversible decisions before options are fully evaluated.
#
# 7) Confidence levels and data needs (Strategy B)
# - Confidence
#   - Assumptions about inland settlement viability, land availability, and community acceptance are relatively uncertain (Low–Medium).
#   - Financial feasibility and debt sustainability are highly uncertain (Medium–Low) due to external financing dependencies.
# - Critical data to reduce uncertainties
#   - Inland land availability, land tenure regimes, and costs for large-scale housing and infrastructure development.
#   - Detailed cost curves for inland services (water, sewage, power, education, healthcare) and the capacity of inland ecosystems to deliver environmental co-benefits.
#   - Community attitudes toward relocation, trust in governance, and cultural attachment to coastal places.
# - Confidence summary
#   - Overall plan viability rests strongly on social acceptance and large-scale financing; error risks are high without careful, inclusive negotiation with communities and credible financing arrangements.
#
# Strategy C: Hybrid approach (balanced protection in some areas, managed retreat in others, and inland development for livelihoods)
#
# 1) What Strategy C entails (vision and components)
# - Core thrust: A calibrated mix of protection for critical nodes and high-value zones, targeted managed retreat in areas where protection is uneconomical, and inland development to host relocated populations and build new livelihoods. This approach seeks to preserve culture and place where feasible while reducing risk in the most vulnerable zones.
# - Immediate top priorities
#   - Map risk zones to distinguish pockets where protection is cost-effective vs. where retreat is more prudent.
#   - Protect core urban concentrations and key infrastructure; implement nature-based buffers where feasible.
#   - Begin staged, voluntary buyouts/relocation pilots for the deepest-risk zones; ensure fair compensation and social protections.
#   - Initiate inland development plans for housing and new livelihoods in areas with good access to markets, labor, and services.
#   - Invest in ecosystem restoration in both protected coastal zones and inland buffers to diversify resilience.
# - Medium term
#   - Expand targeted inland settlements; build resilient housing and services; link inland communities with coastal communities via transport and information networks; maintain cultural heritage and memory programs.
# - Longer term
#   - Maintain a flexible portfolio of protection and retreat; adjust the balance as climate science and costs evolve; ensure that the burden is shared equitably and that future generations have a say in how risk reduction is managed.
#
# 2) Assumptions and uncertainties specific to Strategy C
# - Assumptions
#   - A mixed approach can optimize risk reduction while moderating social disruption and cost; targeted protection can deliver protection where it matters most, and selective retreat can reduce overall exposure cost.
#   - Inland development can be designed to be economically viable and socially acceptable; land can be found and developed with manageable costs.
# - Key uncertainties
#   - Which zones are best protected vs. relocated? The determination could be contested by communities and interest groups.
#   - Costs of dual-path strategies (protection plus relocation) can be high; financing and governance need to be cohesive.
#   - Long-term maintenance costs for mixed defenses and inland settlements; potential reputational risk if decisions appear arbitrary.
# - Trade-offs
#   - Strategy C requires complex planning, coordination, and governance, with potential for slower decision-making but potentially more equitable outcomes.
#   - It aims to reduce both displacements and ecological losses while maintaining cultural integrity, but it can be more expensive and harder to manage than single-path strategies.
#
# 3) Projections (three futures) for Strategy C
# - HE projections
#   - Displacement: 15–28%.
#   GDP change: -18% to -9%.
#   Ecosystem loss: 20–40%.
#   Cumulative costs: $14–22B.
# - ME projections
#   - Displacement: 6–12%.
#   GDP change: -6% to -2%.
#   Ecosystem loss: 8–20%.
#   Cumulative costs: $9–15B.
# - LE projections
#   - Displacement: 1–3%.
#   GDP change: -1% to +1%.
#   Ecosystem loss: 2–10%.
#   Cumulative costs: $6–9B.
# - How these projections are derived
#   - Displacement: a portion of high-risk zones are protected, others shifted to inland settlements or relocated, with voluntary buyouts in the most exposed pockets.
#   - GDP: a combination of protected economic zones, inland development, and new livelihoods; import/export dynamics and service sectors adjust to mixed risk reduction.
#   - Ecosystems: protection in some zones preserves coastal ecosystems; inland buffers and restoration efforts contribute to resilience elsewhere.
#   - Costs: combination of protection investments, relocation/land acquisition in high-risk pockets, and inland development; include ongoing maintenance and social service provisioning.
# - Observations
#   - Strategy C offers a balanced, nuanced approach that can deliver substantial risk reductions while preserving culture and reducing outright displacement relative to Strategy B; it is more complex to implement but potentially more equitable and sustainable within budget constraints.
#
# 4) Monitoring, triggers, and adaptive schedule (Strategy C)
# - Monitoring metrics
#   - Same as Strategy A and B but with emphasis on hybrid zones: effectiveness of protected segments, uptake of relocation in targeted pockets, inland settlement occupancy, and cross-zone resource flows.
# - Decision triggers
#   - If protected zones start to show unsustainable maintenance costs or diminishing effectiveness, shift more population to relocation/inland development.
#   - If inland settlements fail to attract residents or create viable livelihoods, reassess the balance and possibly tilt toward increased protection or more aggressive inland development.
# - Adaptive update schedule
#   - Annual reviews; major reconfiguration at year 10, year 25, and year 40 to adjust the mix between protection, retreat, and inland development as conditions evolve.
#
# 5) Harms, mitigation, and governance (Strategy C)
# - Harms and distributional concerns
#   - Mixed outcomes across communities; potential perception of winners and losers depending on location (which zones are protected vs relocated).
#   - Cultural impacts for relocated communities; potential misalignment of inland livelihoods with traditional skills.
# - Mitigation and governance measures
#   - Inclusive, participatory planning for risk zoning; ensure transparent criteria for protection vs retreat; provide fair compensation where relocation occurs; support cultural continuity in inland settings (heritage centers, cultural programming, language preservation).
#   - Flexible housing and livelihood programs; cross-subsidies to ensure inland viability; ensure transport links to coastal areas for health, education, and cultural activities.
#   - Accountability measures and independent oversight to prevent capture of benefits by elites; gender-responsive budgeting; rights-based approach to land and housing.
#
# 6) Stress-testing and robustness (Strategy C)
# - Models and tests to run
#   - Integrated risk–economic models to examine how protection, retreat, and inland development interact financially and socially.
#   - Scenario analysis across HE/ME/LE to identify tipping points for decisions to shift portions of the plan from protection to retreat or vice versa.
#   - Cultural heritage retention and community cohesion metrics under different mixes of protection/relocation.
# - Counterfactuals
#   - Pure protection vs pure relocation vs no adaptation vs extreme skew of one component; measure social, economic, and ecological outcomes to refine the hybrid mix.
# - Why these tests are important
#   - They ensure the hybrid approach remains responsive to changing climate inputs and local preferences, preventing lock-in to suboptimal choices.
#
# 7) Confidence levels and data needs (Strategy C)
# - Confidence
#   - Moderate: the hybrid approach is plausible and potentially optimal, but its success heavily depends on precise zoning, financing, and governance performance.
# - Data needs
#   - Zoning criteria and risk maps at high resolution; cost curves for protection, retreat, and inland development; credible social acceptability assessments; and detailed inland land availability and infrastructure costs.
# - Confidence summary
#   - Moderate: success hinges on careful, transparent, and inclusive decision-making about where to protect vs retreat, and a robust inland development plan aligned to local markets.
#
# Cross-strategy synthesis and recommendation
# - Comparative assessment (A vs B vs C)
#   - Protection-first (A) minimizes displacement in the near term but carries the highest ongoing maintenance costs and residual risk, with substantial ecosystem reliance on performance of protection works.
#   - Relocation-first (B) offers clear risk reduction but at enormous social disruption and fiscal cost, with potential for reputational and governance challenges if not managed very carefully and inclusively.
#   - Hybrid (C) offers a principled compromise: targeted protection where cost-effective, selective retreat in the most exposed pockets, and inland development to create new livelihoods and housing opportunities, aiming to balance risk reduction, cultural continuity, and intergenerational equity.
# - Recommendation
#   - Strategy C (Hybrid) is the superior option under realistic political, economic, and ethical constraints for a small, low-lying island nation with a finite annual budget and a desire to preserve culture and livelihoods while reducing risk.
#   - Rationale:
#     - Risk reduction where protection is economically sensible, and retreat where protecting costs would be prohibitive and social disruption would be greatest. This minimizes the total number of people displaced while preserving urban cores and critical infrastructure.
#     - It aligns best with intergenerational equity by distributing risk and costs more evenly across current and future generations, rather than concentrating the burden on coastal communities alone.
#     - It allows for better governance and legitimacy through participatory zoning decisions, transparent risk-based criteria, and a clear pathway for communities to move or stay according to shared values and needs.
#     - It provides a more flexible financing pathway: protection investments can be pursued where feasible, while inland development and relocation can be staged and funded through a combination of national budgets and international finance; it also creates leverage for public-private partnerships focused on resilient inland industries.
# - Implementation outline for Strategy C (phased, feasible, equitable)
#   1) Phase 1 (years 0–5): establish governance, risk zoning, and community engagement; secure initial protections around critical hubs; pilot small inland development and relocation readiness in targeted pockets; begin ecosystem restoration and nature-based buffers; set up a transparent financing framework.
#   2) Phase 2 (years 5–15): expand protection in high-benefit zones; implement relocation pilots with voluntary participants; accelerate inland development in selected corridors; establish livelihood programs aligned with inland markets; implement monitoring and adaptive governance.
#   3) Phase 3 (years 15–30): scale up successful inland settlements; consolidate protected coastal zones; refine land-use planning to maintain cultural heritage and ensure adequate public services; monitor outcomes and adjust the mix between protection, retreat, and inland development.
#   4) Phase 4 (years 30–50): optimize the resilience portfolio as climate projections evolve; adjust protection costs, relocation rates, and inland development scales to maintain equity and fiscal viability; evaluate long-term outcomes and institutionalize adaptive governance.
#
# Key deliverables and decision-support needs (summary)
# - A risk zoning map classifying zones into three categories: protect, retreat, and inland development candidate zones; with explicit criteria (economic value, population density, cultural significance, ecosystem value, and protection feasibility).
# - A financing plan that sequences protection, relocation, and inland development with clear budget line items and triggers for escalation or re-prioritization; include contingent financing options (grants, concessional loans, catastrophe risk insurance, public-private partnerships).
# - A grievance redress mechanism and an equity framework to ensure fair treatment of vulnerable groups and transparent public participation.
# - A robust monitoring, evaluation, and adaptive-management framework that covers social, economic, ecological, and financial metrics, with clear triggers to pivot between A, B, and C components if needed.
#
# Data gaps to reduce critical uncertainties (priority)
# - High-resolution coastal topography, bathymetry, and SLR projections at sub-district scales; updated storm surge models aligned with local meteorology.
# - Detailed land ownership, housing stock, and building-stock vulnerability in coastal zones; housing and infrastructure costs for both protection and inland development.
# - Local knowledge on cultural heritage, place-based identity, and community preferences regarding protection versus retreat; gender-inclusive participation data.
# - Economic baselines for fisheries, tourism, and agriculture with scenario-based sensitivities to climate risk; inland market access and value chains for new livelihoods.
# - Financing scenarios: realistic debt-service capacity, external finance terms, and insurance/financial tools for resilience.
#
# Final note on projections and limitations
# - All quantitative projections (displacement, GDP change, ecosystem loss, cumulative costs) are best-which-if estimates under the three futures (HE, ME, LE) and three strategies, subject to the stated assumptions. They are sensitive to local specifics (costs of protection and relocation, land availability for inland settlements, community preferences, and governance quality).
# - Because this is a complex, long-horizon plan with many moving parts and uncertainties, it is essential to run the stress tests, adaptive management cycles, and phased implementations with robust stakeholder engagement and transparent reporting.
#
# If you would like, I can tailor the three strategies to a more granular, island-specific template (including a one-page costed plan for the first 10 years, a risk map, and a simple monitoring dashboard mock-up) using more precise local data you provide (topography, housing stock, current protected surface, and current external finance terms).
#
# # Response from competitor 2
#
# ## Executive Summary
#
# A 50‑year adaptation‑development roadmap for **Isla Verde** (pop. ≈ 350 k) is built around three “strategic families” that differ in how much they rely on **hard coastal protection** versus **planned retreat & relocation**. All three use the same **budget envelope** – a one‑off $3 bn start‑up fund plus $150 m yr⁻¹ (≈ $7.5 bn over 50 yr, discounted at 3 % → ≈ $5.2 bn NPV) – and the same **governance platform** (national Adaptation Steering Committee, local “Resilience Councils”, and an independent Monitoring‑Evaluation‑Learning unit).
#
# The **recommended approach** is **Strategy C – a hybrid, phased transition** that front‑loads protection for the most vulnerable core settlements while simultaneously investing in “managed retreat corridors” and “new‑town pilots”.  This delivers the highest **intergenerational equity** (protects children now, gives future generations the option to move), minimizes irreversible cultural loss, and stays within fiscal limits even under the worst‑case (RCP 8.5) sea‑level rise (SLR) trajectory.
#
# Below is the full technical package that underpins the recommendation.
#
# ---
#
# ## 1. Core Assumptions & Key Uncertainties
#
# | Category | Assumption (Base) | Reasoning / Source | Uncertainty Range | Effect on Plan |
# |----------|-------------------|--------------------|-------------------|----------------|
# | **Demography** | 2025 pop. = 350 k; growth 0.8 % yr⁻¹ (UN World Pop Prospects) | Small island, modest fertility, out‑migration | 0.4‑1.2 % yr⁻¹ | Determines future housing & labor pool |
# | **GDP** | 2025 GDP = $9 bn (≈ $25 k p.c.); annual real growth 2.5 % (World Bank) | Historical trend, tourism‑led | 1.5‑3.5 % yr⁻¹ | Influences fiscal capacity & cost‑benefit ratios |
# | **Sea‑Level Rise** | RCP 2.6: +0.6 m by 2100; RCP 4.5: +0.95 m; RCP 8.5: +1.6 m (IPCC AR6) | Global mean; local vertical land motion (VLM) –0.1 m/century (GPS) | ±0.1 m (VLM) ±0.2 m (model spread) | Drives timing/extent of inundation & protection design |
# | **Storm Surge & Cyclone Intensity** | Frequency unchanged; intensity +10 % per °C (IPCC) | Limited local historic record | ±5 % | Affects design wave height for dikes/sea walls |
# | **Land‑Use & Elevation Data** | 5 m DEM (LiDAR) with RMSE = 0.15 m | Recent national mapping campaign | ±0.2 m vertical error | Determines which zones are “protectable” |
# | **Migration Preference** | 70 % of households prefer to stay in place if protection offered; 30 % open to relocation (survey 2023) | Baseline social survey | 55‑85 % | Shapes size of relocation fund and timing |
# | **Construction Cost Index** | $2 500 m² for seawall; $1 200 m² for “living shoreline” (bio‑engineered) | Local contractor quotes; adjusted for inflation | ±15 % | Directly affects budget allocations |
# | **Ecosystem Service Valuation** | Mangrove carbon sequestration $25 t CO₂⁻¹; storm‑buffer value $3 bn yr⁻¹ for whole coast (FAO) | Global meta‑analyses, adjusted for local productivity | ±30 % | Influences cost‑benefit of nature‑based solutions |
#
# **Principal Unknowns that dominate risk**
#
# 1. **Actual SLR at the island’s shoreline** – local subsidence or uplift could add/subtract up to 0.2 m.
# 2. **Behavioural response to relocation incentives** – cultural attachment may be higher than surveys suggest, especially for sacred sites.
# 3. **Future tourism demand** – a 30 % swing changes revenue streams that could finance later phases.
# 4. **Global financing climate‑aid volatility** – potential for additional grants or loans (e.g., Green Climate Fund) is uncertain.
#
# ---
#
# ## 2. Trade‑offs & Opportunity Costs
#
# | Trade‑off | What is Gained | What is Foregone / Cost |
# |-----------|----------------|------------------------|
# | **Hard Protection vs. Retreat** | Immediate safety for existing settlements, preservation of current cultural sites, continuity of tourism infrastructure. | High capital outlay, lock‑in to a possibly unsustainable future, loss of opportunity to develop “climate‑resilient” new towns with better layout, higher long‑term maintenance. |
# | **Nature‑Based Solutions (NBS) vs. Grey Infrastructure** | Co‑benefits: carbon sequestration, fisheries nursery, tourism (eco‑tourism), lower upfront cost. | Larger land area needed; slower to reach design capacity; may be less effective against extreme storm surge if not combined with hard structures. |
# | **Centralised Relocation (one new “Capital‑Town”) vs. Distributed Small‑Scale Villages** | Economies of scale in service provision, stronger social cohesion in new town, easier to plan utilities. | Risk of creating a “single point of failure”, cultural disruption for dispersed communities, higher transport costs for remote island activities. |
# | **Early Investment in Data & Governance vs. Immediate Construction** | Better targeting, reduced mis‑allocation, higher community buy‑in, ability to adjust later. | Delays visible “protective” actions; may be politically unpopular if perceived as “inaction”. |
# | **Allocation to Housing vs. Livelihood Diversification** | Faster shelter for displaced families, reduces homelessness. | Missed chance to reduce exposure (e.g., shift from coastal fisheries to aquaculture, tourism‑service, renewable‑energy jobs). |
#
# **Opportunity Cost Calculations (illustrative)**
#
# *Assuming a $1 bn allocation to seawall construction (Scenario A) versus a $1 bn allocation to “green‑belt + relocation pilot” (Scenario C):*
#
# - **Scenario A**: Seawall protects 120 k people for 30 yr → avoided displacement cost $0.6 bn (average $10 k per person).
# - **Scenario C**: Relocation + mangrove restoration protects the same 120 k (through barrier effect) and adds ecosystem service value of $150 m yr⁻¹ → NPV ≈ $0.8 bn over 30 yr.
#
# Thus **C yields a higher net benefit** despite a slightly higher upfront capital need.
#
# ---
#
# ## 3. Quantitative Projections (50‑yr)
#
# ### 3.1 Modelling Framework
#
# ...
# | **Coastal Inundation Extent (satellite + UAV)** | > 0.5 % of protected zone flooded during a 100‑yr storm event | Every 2 yr | Re‑evaluate seawall design height (add +0.5 m) |
# | **Housing Stock Condition Index** | < 0.7 (scale 0‑1) for > 30 % of homes in protected zone | Biennial | Deploy emergency retro‑fit funds (up to $20 m) |
# | **Livelihood Income Gap** | > 15 % deviation from baseline median income in at‑risk communities | Annual | Expand livelihood‑diversification package (micro‑grant + training) |
# | **Cultural Site Integrity** | Damage > 10 % of heritage‑site area (laser‑scan) | Annual | Immediate emergency preservation fund release ($5 m) |
# | **Ecosystem Service Index (Mangrove health, coral cover)** | Decline > 10 % over 5 yr | Every 5 yr | Scale up nature‑based restoration (additional $10 m) |
# | **Public Acceptance (survey)** | < 60 % support for current strategy | Every 5 yr | Convene “Resilience Council” to co‑design next phase; may shift share of funds to retreat |
#
# ### Adaptive‑Update Cycle
#
# | Year | Activity |
# |------|----------|
# | **0‑5** (Foundational) | Complete high‑resolution LiDAR mapping, baseline socioeconomic survey, establish national Adaptation Steering Committee, launch pilot “Living‑Shoreline” (2 km) and “Relocation‑Village” (1 km²) projects. |
# | **5‑10** | First formal *Mid‑Term Review* (MTR) – compare observed SLR & inundation against projections; re‑calibrate cost curves; adjust annual allocation split (Protection : Retreat : NBS) by ±10 % based on trigger outcomes. |
# | **10‑20** | Second MTR – evaluate performance of relocated communities (housing quality, livelihood outcomes). If > 20 % of pilot households report “unacceptable” outcomes, increase relocation budget by 15 % and re‑design settlement layout. |
# | **20‑30** | Third MTR – integrate new climate‑scenario updates (e.g., CMIP6 *SSP* pathways). If projected SLR exceeds 1.2 m (RCP 8.5) earlier than anticipated, fast‑track “Phase‑Out” of low‑lying zones (declare “no‑build” zones). |
# | **30‑40** | Fourth MTR – full‑scale evaluation of ecosystem‑service delivery; adjust nature‑based funding. |
# | **40‑50** | Final Review – decide on “post‑50‑yr” strategy (e.g., permanent relocation, or new‑generation protective tech). |
#
# All reviews are **public**, with stakeholder workshops and a transparent “decision‑log” posted online.
#
# ---
#
# ## 5. Moral, Social & Cultural Harms & Mitigation
#
# | Harm | Affected Group | Mitigation / Compensation | Governance Mechanism |
# |------|----------------|---------------------------|----------------------|
# | **Loss of ancestral burial sites** | Indigenous coastal clans | *Cultural Heritage Trust* – $30 m endowment; in‑situ preservation where possible; documentation & digital archiving. | Independent Heritage Oversight Board (mixed govt‑NGO‑clan). |
# | **Disproportionate displacement of low‑income households** | Poor fisher families | Means‑tested relocation vouchers (housing + start‑up cash) + guaranteed 5‑yr job placement in new‑town or renewable‑energy projects. | Social Justice Advisory Panel (annual audit). |
# | **Psychological stress & “climate‑anxiety”** | Entire population, especially youth | Community mental‑health hubs; school curricula on resilience; $2 m/yr mental‑health fund. | Ministry of Health–Climate‑Health Unit. |
# | **Erosion of community cohesion (fragmentation)** | Villages split by retreat corridors | Co‑design of new‑town public spaces that replicate traditional communal structures; “cultural continuity funds” to support festivals, language classes. | Resilience Councils (local elected) with veto power on settlement layout. |
# | **Inter‑generational inequity (future generations paying for today’s protection)** | Future taxpayers | Long‑term sovereign “Climate Adaptation Fund” (10 % of tourism tax) locked in a low‑risk bond; transparent reporting. | Parliamentary Oversight Committee. |
# | **Loss of ecosystem‑based livelihoods** | Mangrove‑dependent fishers | Transition grants for aquaculture certification; capacity‑building for eco‑tourism guiding; 15 % of NBS budget earmarked for livelihood‑linkage. | Fisheries‑Coastal Livelihood Board. |
#
# **Compensation principle:** *No‑loss* – anyone who loses land or cultural assets receives a package that at least equals market value plus a “cultural premium” (15 % uplift) and a guarantee of comparable or better housing.
#
# ---
#
# ## 6. Stress‑Testing & Simulation of Robustness
#
# | Model / Tool | Purpose | Counterfactual Tested | Why It Matters |
# |--------------|---------|-----------------------|----------------|
# | **Coastal Inundation Monte‑Carlo (CIMC)** | Propagate SLR, storm surge, tide‑gate failure uncertainties through GIS exposure model. | 1) SLR +0.2 m faster than median; 2) 100‑yr storm surge occurs twice as often. | Checks if protection thresholds are under‑designed. |
# | **Integrated Assessment Model (IAM) – MAgPIE / WITCH** | Link climate, economy, and policy to estimate GDP impacts under alternative adaptation mixes. | 1) Full retreat (100 % of at‑risk zone); 2) No adaptation. | Quantifies opportunity costs and validates damage functions. |
# | **Agent‑Based Relocation Model (ABRM)** | Simulate household decision‑making under varying incentives, social networks, and cultural ties. | 1) Incentive cut‑off reduced by 30 %; 2) Introduction of “clan‑based” relocation clusters. | Reveals tipping points for mass migration and possible social unrest. |
# | **Ecosystem Services Supply‑Demand Model (ESSDM)** | Evaluate how NBS, protection, and land‑use change affect carbon, fisheries, and storm buffering. | 1) 50 % of mangroves lost before restoration; 2) Coral bleaching accelerates to 80 % loss. | Determines resilience of nature‑based components. |
# | **Financial Sustainability Stress Test** | Run cash‑flow projection under varied discount rates (2‑5 %), aid‑flow shocks (±50 %), and inflation spikes. | 1) Global aid freezes for 5 yr; 2) Inflation spikes to 6 %/yr. | Ensures plan does not collapse financially. |
#
# *Outcome:* All three strategies pass a **70 % probability** of staying within the $5.2 bn NPV budget under high‑emission SLR, but **Strategy C** shows the **lowest sensitivity** to adverse climate “tails” (e.g., earlier storm surge) because it diversifies risk across protection, retreat, and ecosystem buffers.
#
# ---
#
# ## 7. Confidence Levels & Data Gaps (per Strategy)
#
# | Element | Strategy A (Protection‑Only) | Strategy B (Retreat‑Only) | Strategy C (Hybrid) | Confidence (High/Med/Low) | Data that would raise confidence |
# |--------|------------------------------|---------------------------|----------------------|---------------------------|-----------------------------------|
# | **SLR projection (local)** | Medium (depends on VLM) | Medium | Medium | **Medium** | Continuous GPS/VLM network (5‑yr series). |
# | **Cost of seawall per km** | High (local contractor bids) | Low (no data) | High (same as A) | **High** | Updated cost database post‑first 10 km build. |
# | **Relocation household cost** | Low (pilot limited) | Medium (pilot data) | Medium | **Medium** | Full household‑level cost‑benefit survey after 2 pilot villages. |
# | **Ecosystem service valuation** | Low (global averages) | Medium (field measurements) | High (combined field + remote) | **Medium** | Local mangrove carbon stock and storm‑buffer field experiments. |
# | **Social acceptance** | Low (no baseline) | Medium (focus groups) | High (ongoing council) | **Medium** | Annual, disaggregated perception surveys (by age, clan). |
# | **Economic damage functions** | Medium (regional IPCC) | High (regional calibrations) | High (both) | **High** | Island‑specific GDP‑by‑sector vulnerability study. |
# | **Governance capacity to deliver relocation** | Low | Medium | High | **Medium** | Institutional audit of land‑acquisition processes. |
# | **Long‑term fiscal sustainability** | Medium | Low | High | **High** | Real‑time tracking of tourism tax revenue and climate‑aid inflows. |
#
# *Overall, the hybrid Strategy C enjoys the highest aggregate confidence (≈ 75 % of elements rated “high” or “medium”), while Strategy A suffers from low confidence in social‑acceptance and long‑term fiscal risk, and Strategy B from high engineering uncertainty and higher economic disruption.*
#
# ---
#
# ## 8. Three Alternative Strategies (Detail)
#
# ### **Strategy A – “Protect‑in‑Place”**
#
# | Phase (Year) | Activity | % of annual $150 m budget |
# |--------------|----------|----------------------------|
# | 0‑5 | Island‑wide “hard” seawall (20 km total) + surge gates; upgrade critical infrastructure (hospitals, power). | 70 % |
# | 5‑15 | Maintenance & elevation of existing housing (raise 0.5‑1 m). | 20 % |
# | 15‑30 | Add “living‑shoreline” buffers where seawall not feasible. | 10 % |
# | 30‑50 | Small‑scale relocation of the **most** exposed 5 % (voluntary) – only if seawall fails. | 5 % |
#
# **Pros:** Immediate visual protection, preserves cultural sites, supports tourism continuity.
# **Cons:** High upfront cost; lock‑in to a moving target; limited flexibility; risk of “maladaptation” if SLR exceeds design height.
#
# **Projected Outcomes (high‑emissions):** 115 k displaced, –5.5 % GDP by 2070, ecosystem loss > 35 % (mangroves, reefs).
#
# ---
#
# ### **Strategy B – “Managed Retreat”**
#
# | Phase (Year) | Activity | % of annual $150 m budget |
# |--------------|----------|----------------------------|
# | 0‑5 | Land‑acquisition for two new inland towns (10 km² each); legal frameworks; initial community engagement. | 30 % |
# | 5‑15 | Construction of “relocation villages” (modular, climate‑proof housing) + livelihood transition grants. | 50 % |
# | 15‑30 | Systematic “buy‑back” of low‑lying properties; demolition; ecosystem restoration of vacated shoreline. | 15 % |
# | 30‑50 | Continue incremental expansion of inland towns; de‑commissioned seawalls turned into public promenades. | 5 % |
#
# **Pros:** Avoids perpetual maintenance; opens space for nature‑based buffers; reduces long‑term exposure.
# **Cons:** Large social disruption, high relocation compensation, potential loss of heritage sites, requires robust land‑use planning.
#
# **Projected Outcomes (high‑emissions):** 260 k displaced (voluntary + forced), –12 % GDP, ecosystem loss > 45 % (if restoration delayed).
#
# ---
#
# ### **Strategy C – “Hybrid Phased Transition”**
#
# | Phase (Year) | Activity | % of annual $150 m budget |
# |--------------|----------|----------------------------|
# | **0‑5** | **Data foundation** (LiDAR, VLM, socioeconomic baseline). <br> **Pilot 2‑km “Living‑Shoreline”** (mangrove + oyster reef). <br> **Pilot relocation village** (1 km²). | 20 % |
# | **5‑15** | **Coastal protection**: seawall for high‑value zones (≈ 8 km) + surge gates. <br> **Expand NBS**: 1 000 ha mangrove restoration. <br> **Scale relocation**: additional 3 villages (total 4 km²). | 40 % |
# | **15‑30** | **Transition zone**: “no‑build” policy for zones < 2 m AMSL; convert to **green buffer** (agro‑forestry, eco‑tourism). <br> **Upgrade inland towns**: utilities, schools, health. <br> **Livelihood diversification**: renewable‑energy training, climate‑smart fisheries. | 30 % |
# | **30‑50** | **Full‑scale relocation** of remaining < 2 m zones (≈ 15 % of land) – voluntary, with guaranteed housing in new‑towns. <br> **Maintain & upgrade existing protection** (height +0.5 m). <br> **Long‑term ecosystem stewardship fund** (endowed). | 10 % |
#
# **Key Features**
#
# * **Dynamic allocation** – the % split can shift ±10 % after each 5‑yr monitoring checkpoint.
# * **Cultural‑heritage “seed‑lots”** – every relocated community receives a *cultural hub* that houses artefacts, oral‑history archives, and a community‑run museum.
# * **Ecosystem‑service “insurance”** – restored mangroves generate a **$3 m yr⁻¹ credit** (storm buffer) that is fed back to the Adaptation Fund.
#
# **Projected Outcomes (high‑emissions):** 130 k displaced, –6.5 % GDP, ecosystem loss limited to 30 % (due to early NBS).
#
# ---
#
# ## 9. Recommendation – Adopt **Strategy C (Hybrid)**
#
# ### Why C Beats A & B
#
# | Criterion | Strategy A | Strategy B | Strategy C |
# |-----------|------------|------------|------------|
# | **Risk of Over‑Investment** | High (seawall may be overtopped) | High (relocation may exceed budget) | Balanced – early protection where cost‑effective, retreat where inevitable |
# | **Cultural Preservation** | Strong for current sites, weak for future identity | Weak (large‑scale displacement) | Strong – retains core heritage sites *and* creates new cultural hubs |
# | **Economic Resilience** | Moderate (tourism preserved, but high maintenance) | Low (short‑term disruption to tourism) | High – diversified livelihoods, NBS provides storm‑buffer savings |
# | **Fiscal Sustainability** | High O&M costs → risk of budget overruns | Large one‑off relocation payouts → cash‑flow stress | Spreads cost across 50 yr, leverages ecosystem credits, uses modest annual spend |
# | **Social Equity** | Low – benefits concentrate on wealthier coastal owners | Medium – relocation funds may be insufficient for poorest | High – means‑tested vouchers, participatory planning, targeted livelihood packages |
# | **Flexibility to Emissions Scenarios** | Rigid – design based on single SLR assumption | Rigid – full retreat locked in early | Adaptive – can upscale protection or retreat as triggers fire |
# | **Implementation Feasibility (Political)** | Easy to sell “protect now” narrative | Politically sensitive (forced moves) | Moderately complex but built on **co‑design** mechanisms that build legitimacy |
#
# ### Ethical & Political Viability
#
# * **Procedural Justice** – the hybrid plan embeds **local Resilience Councils** with decision‑making power, satisfying the island’s strong clan‑based governance traditions.
# * **Distributive Justice** – means‑tested compensation ensures the poorest are not left behind.
# * **Inter‑generational Justice** – the plan locks in an **endowment** (tourism tax + climate‑aid) that funds future generations, avoiding “debt‑building” for adaptation.
#
# ### Implementation Timeline (Key Milestones)
#
# | Year | Milestone |
# |------|-----------|
# | 0‑2 | Establish Adaptation Steering Committee; finalize budget law; start LiDAR & VLM network. |
# | 2‑5 | Build first 2 km living‑shoreline; launch pilot relocation village; enact “no‑build” zoning for < 0.5 m AMSL. |
# | 5‑10 | Complete 8 km seawall around high‑value core (capital, main airport). |
# | 10‑15 | Expand mangrove restoration to 1 000 ha; open second relocation village. |
# | 15‑20 | Declare “green‑buffer” zone (2‑4 m AMSL) – convert to agro‑forestry & eco‑tourism. |
# | 20‑30 | Relocate 30 % of at‑risk households (voluntary); finish inland‑town utilities. |
# | 30‑40 | Raise seawall +0.5 m (climate‑adaptive design). |
# | 40‑50 | Complete relocation of remaining < 2 m zones; transition to maintenance phase; evaluate post‑50‑yr pathway. |
#
# ---
#
# ## 10. Closing Note
#
# The hybrid Strategy C **maximizes the net social, economic, and ecological return** on the $3 bn + $150 m yr⁻¹ budget while respecting the island’s cultural fabric and the rights of future generations. It is **robust** to the three emissions pathways, **adaptive** to emerging science, and **governance‑ready** through participatory institutions.
#
# **Next steps for the government**
#
# 1. **Ratify the Adaptation Steering Committee** (legislative act).
# 2. **Secure the $3 bn start‑up fund** (mix of sovereign bonds, climate‑aid, and a modest tourism levy).
# 3. **Commission the baseline data package** (LiDAR, VLM, socio‑economic surveys) – this will lift confidence from *medium* to *high* on most model inputs.
# 4. **Launch the first 2‑km living‑shoreline pilot** – a tangible “quick‑win” that demonstrates commitment and creates early ecosystem credits.
#
# With these actions, Isla Verde can navigate the next half‑century of sea‑level rise without sacrificing its people, culture, or natural heritage.
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["2", "1"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: openai/gpt-oss-120b
# Rank 2: gpt-5-nano

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
